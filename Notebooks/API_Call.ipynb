# %%
""" Pip Commands """
# !pip install google-generativeai
# Out:
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.5-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-ai-generativelanguage==0.6.15 (from google-generativeai)
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core (from google-generativeai)
#   Downloading google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai)
#   Downloading google_api_python_client-2.169.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai)
#   Downloading google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: protobuf in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from google-generativeai) (6.30.2)
# Requirement already satisfied: pydantic in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from google-generativeai) (2.11.3)
# Requirement already satisfied: tqdm in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from google-generativeai) (4.12.2)
# Collecting google-api-core (from google-generativeai)
#   Downloading google_api_core-2.25.0rc0-py3-none-any.whl.metadata (3.0 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf (from google-generativeai)
#   Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core->google-generativeai)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from google-api-core->google-generativeai) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client->google-generativeai)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from pydantic->google-generativeai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from pydantic->google-generativeai) (0.4.0)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading grpcio-1.71.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/saishruti/miniconda3/envs/research1/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)
# Downloading google_generativeai-0.8.5-py3-none-any.whl (155 kB)
# Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.7 MB/s eta 0:00:00:00:01
# Downloading google_api_core-2.25.0rc0-py3-none-any.whl (160 kB)
# Downloading google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
# Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading google_api_python_client-2.169.0-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.5 MB/s eta 0:00:0000:0100:01
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading grpcio-1.71.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 16.5 MB/s eta 0:00:0000:01
# Downloading grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: uritemplate, pyasn1, protobuf, httplib2, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.30.2
#     Uninstalling protobuf-6.30.2:
#       Successfully uninstalled protobuf-6.30.2
# Successfully installed cachetools-5.5.2 google-ai-generativelanguage-0.6.15 google-api-core-2.25.0rc0 google-api-python-client-2.169.0 google-auth-2.39.0 google-auth-httplib2-0.2.0 google-generativeai-0.8.5 googleapis-common-protos-1.70.0 grpcio-1.71.0 grpcio-status-1.71.0 httplib2-0.22.0 proto-plus-1.26.1 protobuf-5.29.4 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 uritemplate-4.1.1

# %%
""" Imports """
import pandas as pd
import random
import os
from PIL import Image
import json
import glob
import google.generativeai as genai
import time

# %%
""" Sample API Call """
# Set your Gemini API key
api_key = "AIzaSyCk-3tjAx3U33d0hdXiYmKP-7m0_kHOFqk"
genai.configure(api_key=api_key)

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Sample a random row
sample = merged_df.sample(1).iloc[0]
image_id = sample["image_id"]
image_dir = "Datasets/small"
image_path = os.path.join(image_dir, sample["path"])
item_id = sample["item_id"]

# Load the image
image = Image.open(image_path)

# Search all JSON files for metadata of the sampled item_id
metadata = None
for json_file in glob.glob("Datasets/listings_*.json"):
    with open(json_file, "r", encoding="utf-8") as f:
        for line in f:
            doc = json.loads(line)
            if doc.get("item_id") == item_id:
                metadata = doc
                break
    if metadata:
        break

if metadata is None:
    raise ValueError(f"Metadata for item_id {item_id} not found.")

# Prepare prompt for question and single-word answer generation
prompt = f"""Based on the provided product image and metadata, generate:
1. A specific question about this product that can be answered with a single word
2. The single word answer to that question

Format your response exactly like this:
Question: [your question here]
Answer: [single word answer]

Metadata: {json.dumps(metadata, indent=2)}"""

# Gemini API call
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content(
    [prompt, image],
    stream=False
)

# Show response
print(f"Image ID: {image_id}")
print(f"Item ID: {item_id}")
print(f"Image Path: {image_path}")
print("Gemini Response:")
print(response.text)

# Extract question and answer if needed for further processing
response_text = response.text
question = None
answer = None

for line in response_text.split("\n"):
    if line.startswith("Question:"):
        question = line[len("Question:"):].strip()
    elif line.startswith("Answer:"):
        answer = line[len("Answer:"):].strip()

if question and answer:
    print("\nExtracted:")
    print(f"Question: {question}")
    print(f"Answer: {answer}")
    
    # Create a dictionary with the data to save
    data = {
        'Image_ID': [image_id],
        'Item_ID': [item_id],
        'Question': [question],
        'Answer': [answer]
    }
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Check if file exists
    file_exists = os.path.isfile('qna.csv')
    
    # Save to CSV (append if file exists, create with header if it doesn't)
    if file_exists:
        df.to_csv('qna.csv', mode='a', header=False, index=False)
        print("Data appended to qna.csv")
    else:
        df.to_csv('qna.csv', index=False)
        print("Created qna.csv with the data")
# Out:
# Image ID: 81mEuveXFVL
# Item ID: B07PW6XQY8
# Image Path: Datasets/small/5a/5a1fe2c8.jpg
# Gemini Response:
# Question: What is the bed's finish?
# Answer: Wenge
#
# Extracted:
# Question: What is the bed's finish?
# Answer: Wenge
# Created qna.csv with the data

# %%
# Set your Gemini API key
api_key = "AIzaSyCk-3tjAx3U33d0hdXiYmKP-7m0_kHOFqk"
genai.configure(api_key=api_key)

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Sample a random row
sample = merged_df.sample(1).iloc[0]
image_id = sample["image_id"]
item_id = sample["item_id"]

# Search all JSON files for metadata of the sampled item_id
metadata = None
for json_file in glob.glob("Datasets/listings_*.json"):
    with open(json_file, "r", encoding="utf-8") as f:
        for line in f:
            doc = json.loads(line)
            if doc.get("item_id") == item_id:
                metadata = doc
                break
    if metadata:
        break

if metadata is None:
    raise ValueError(f"Metadata for item_id {item_id} not found.")

# Print metadata
print("Metadata:")
print(json.dumps(metadata, indent=2))

# Prepare prompt
prompt = f"""You are given the metadata of a product listed online. Based only on this metadata, generate:
1. A specific question that a user might ask about this product, which can be answered with a single word
2. The single-word answer to that question

Format:
Question: [your question here]
Answer: [single word answer]

Metadata: {json.dumps(metadata, indent=2)}"""

# Gemini API call
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content(prompt, stream=False)

# Print full API output
print("\nAPI Output:")
print(response.text)

# Extract question and answer
response_text = response.text
question = None
answer = None

for line in response_text.split("\n"):
    if line.startswith("Question:"):
        question = line[len("Question:"):].strip()
    elif line.startswith("Answer:"):
        answer = line[len("Answer:"):].strip()

# Print extracted question and answer
print("\nExtracted:")
print(f"Question: {question}")
print(f"Answer: {answer}")
# Out:
# Metadata:
# {
#   "item_dimensions": {
#     "height": {
#       "normalized_value": {
#         "unit": "inches",
#         "value": 4.5
#       },
#       "unit": "inches",
#       "value": 4.5
#     },
#     "length": {
#       "normalized_value": {
#         "unit": "inches",
#         "value": 2.375
#       },
#       "unit": "inches",
#       "value": 2.375
#     },
#     "width": {
#       "normalized_value": {
#         "unit": "inches",
#         "value": 2.375
#       },
#       "unit": "inches",
#       "value": 2.375
#     }
#   },
#   "brand": [
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements"
#     }
#   ],
#   "bullet_point": [
#     {
#       "language_tag": "en_SG",
#       "value": "This food product is manufactured to United States standards and may differ from similar products sold locally in its ingredients, labeling and allergen warnings"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "500mg turmeric root extract per serving"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "65 capsules, a 2 month supply (taken daily at listed serving size)"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "No artificial colors, flavors or chemical preservatives"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Vegan and gluten free;Discover the certificate of analysis for this product by scanning your bottle code using the Amazon app;Made in a Good Manufacturing Practices (GMP) facility;Satisfaction Guarantee: We're proud of our products. If you aren't satisfied, we'll refund you for any reason within a year of purchase. 1-877-485-0395;An Amazon brand"
#     }
#   ],
#   "item_id": "B01L081OFK",
#   "item_name": [
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements Turmeric Root Extract 500 mg, 65 Capsules, 2 month supply"
#     }
#   ],
#   "product_type": [
#     {
#       "value": "HEALTH_PERSONAL_CARE"
#     }
#   ],
#   "main_image_id": "51SWJgOt-OL",
#   "other_image_id": [
#     "61ByTUbfHdL",
#     "61EOfEn+JkL",
#     "81jhBEVg6AL",
#     "51M39MBAwDL",
#     "61TNj2UcjzL",
#     "81FUxNP8d1L",
#     "51w06iOCl0L",
#     "71-z9rstM8L",
#     "315UJTqEiKL"
#   ],
#   "item_keywords": [
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free,\ntumeric curcumin supplement"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     },
#     {
#       "language_tag": "en_SG",
#       "value": "Amazon Elements, Amazon Elements vitamins, Amazon Elements supplements, Amazon Brand, Made by Amazon, AE, AE vitamins, AE supplements, turmeric, turmeric curcumin,turmeric curcumin supplement, curcumin, turmeric supplement, turmeric capsules, turmeric pills, turmeric root extract, turmeric extract, vegan, gluten free"
#     }
#   ],
#   "country": "SG",
#   "marketplace": "PrimeNow",
#   "domain_name": "amazon.sg"
# }
#
# API Output:
# Question: Is this product vegan?
# Answer: Yes
#
#
# Extracted:
# Question: Is this product vegan?
# Answer: Yes

# %%
""" Main API Call with Start Index Support """

# Set your Gemini API key
api_key = "AIzaSyC70OLGkkGuIwHnMzjPTOt2Bd44MHu9tAA"
genai.configure(api_key=api_key)

# Define the starting index (can be changed before running)
start_index = 3000  # Change this value to continue from where you left off

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Filter to get one image per product, preferring "main" role
unique_products_df = pd.DataFrame()

# Group by item_id
grouped = merged_df.groupby("item_id")

# For each product, get the "main" image or the first one if no main exists
for item_id, group in grouped:
    main_images = group[group["role"] == "main"]
    if len(main_images) > 0:
        # Take the first main image
        unique_products_df = pd.concat([unique_products_df, main_images.iloc[[0]]])
    else:
        # If no main image, take the first image
        unique_products_df = pd.concat([unique_products_df, group.iloc[[0]]])

# Reset index
unique_products_df = unique_products_df.reset_index(drop=True)

# Initialize model
model = genai.GenerativeModel("gemini-1.5-flash")

# Create counter for progress tracking
total_products = len(unique_products_df)
processed_count = 0
error_count = 0
max_api_calls = 1000  # Limit to 1000 API calls

print(f"Found {total_products} unique products")
print(f"Starting processing from index {start_index} up to {max_api_calls} products...")

# Process each row in the filtered DataFrame, starting from the specified index
for index, row in unique_products_df.iloc[start_index:].iterrows():
    # Check if we've reached the API call limit
    if processed_count + error_count >= max_api_calls:
        print(f"\nReached limit of {max_api_calls} API calls.")
        print(f"Stopped at index {index}, Item_ID: {row['item_id']}")
        print(f"To continue processing, set start_index = {index}")
        break
        
    try:
        # Extract image information
        image_id = row["image_id"]
        image_dir = "Datasets/small"
        image_path = os.path.join(image_dir, row["path"])
        item_id = row["item_id"]
        
        # Load the image
        image = Image.open(image_path)
        
        # Search all JSON files for metadata of the item_id
        metadata = None
        for json_file in glob.glob("Datasets/listings_*.json"):
            with open(json_file, "r", encoding="utf-8") as f:
                for line in f:
                    doc = json.loads(line)
                    if doc.get("item_id") == item_id:
                        metadata = doc
                        break
            if metadata:
                break
        
        if metadata is None:
            print(f"Warning: Metadata for item_id {item_id} not found. Skipping.")
            error_count += 1
            continue
        
        # Prepare prompt for question and single-word answer generation
        prompt = f"""Based on the provided product image and metadata, generate:
1. A specific question about this product that can be answered with a single word
2. The single word answer to that question

Format your response exactly like this:
Question: [your question here]
Answer: [single word answer]

Metadata: {json.dumps(metadata, indent=2)}"""
        
        # Gemini API call
        response = model.generate_content(
            [prompt, image],
            stream=False
        )
        
        # Extract question and answer
        response_text = response.text
        question = None
        answer = None
        
        for line in response_text.split("\n"):
            if line.startswith("Question:"):
                question = line[len("Question:"):].strip()
            elif line.startswith("Answer:"):
                answer = line[len("Answer:"):].strip()
        
        if question and answer:
            # Create a dictionary with the data to save
            data = {
                'Image_ID': [image_id],
                'Item_ID': [item_id],
                'Question': [question],
                'Answer': [answer]
            }
            
            # Convert to DataFrame
            df = pd.DataFrame(data)
            
            # Check if file exists
            file_exists = os.path.isfile('qna.csv')
            
            # Save to CSV (append if file exists, create with header if it doesn't)
            if file_exists:
                df.to_csv('qna.csv', mode='a', header=False, index=False)
            else:
                df.to_csv('qna.csv', index=False)
        
        # Update progress
        processed_count += 1
        if processed_count % 10 == 0:
            print(f"Processed {processed_count}/{max_api_calls} products")
        
        # Short summary of the current item
        print(f"Processed: Item_ID: {item_id} | Image_ID: {image_id} | Question: {question} | Answer: {answer}")
        
        # Pause between API calls to avoid rate limits
        time.sleep(1.0)  # 1 second pause between calls
        
    except Exception as e:
        error_count += 1
        print(f"Error processing row {index}: {str(e)}")
        # Continue with the next image even if there's an error
        continue

print(f"\nProcessing complete!")
print(f"Total products processed: {processed_count}")
print(f"Errors: {error_count}")
print(f"Results saved to qna.csv")
print(f"Next start_index to continue: {start_index + processed_count + error_count}")
# Out:
# Found 4923 unique products
# Starting processing from index 3000 up to 1000 products...
# Processed: Item_ID: B07TH3BQLV | Image_ID: 71w29SzrRFL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3BQM3 | Image_ID: 713qycYoerL | Question: Is this case for a Vivo Y53? | Answer: Yes
# Processed: Item_ID: B07TH3BQPL | Image_ID: 71ghdUA-qtL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3003: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f46657c5.jpg'
# Error processing row 3004: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 3005: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f7d3b8b5.jpg'
# Processed: Item_ID: B07TH3CC4Y | Image_ID: 71rMACNyHtL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3CC5J | Image_ID: 71BbPKf4xIL | Question: Is this case for the Samsung Galaxy J7 Duo? | Answer: Yes
# Processed: Item_ID: B07TH3CC6P | Image_ID: 71G3uscH86L | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3CCFJ | Image_ID: 71pJv7U6rOL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3CCLD | Image_ID: 71Bckj2zoPL | Question: Is this case for a Samsung Galaxy J4 Plus? | Answer: Yes
# Processed: Item_ID: B07TH3CCMV | Image_ID: 8164U3asHKL | Question: Is this case 3D printed? | Answer: Yes
# Processed 10/1000 products
# Processed: Item_ID: B07TH3CCRT | Image_ID: 61FFtGrULzL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3CD4F | Image_ID: 81lFPljXtbL | Question: What is the phone model this case fits? | Answer: Motorola
# Processed: Item_ID: B07TH3D4VB | Image_ID: 71idH49jIsL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3DNHB | Image_ID: 71IENkIgqrL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3DNJR | Image_ID: 71bSpbS0tBL | Question: Is this case for a Vivo Y31? | Answer: Yes
# Error processing row 3017: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH3DNQF | Image_ID: 71+XDZVIgrL | Question: Is this case for an InFocus M350? | Answer: Yes
# Processed: Item_ID: B07TH3DNYR | Image_ID: 81-dp2udFJL | Question: Is this case for an InFocus M350? | Answer: Yes
# Processed: Item_ID: B07TH3G18X | Image_ID: 71zg8WFnhCL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3G1DH | Image_ID: 71-3ES575bL | Question: Is this case hard or soft? | Answer: Hard
# Processed: Item_ID: B07TH3G1LF | Image_ID: 81uGjkOEAWL | Question: Is this case 3D printed? | Answer: Yes
# Processed 20/1000 products
# Processed: Item_ID: B07TH3G1TJ | Image_ID: 81eoV6VvZkL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3JPKL | Image_ID: 713cPTpR2cL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3JPTB | Image_ID: 81e0AxpzFCL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3LYPL | Image_ID: 71AGExIkdhL | Question: What material is the phone case made of? | Answer: Wood
# Processed: Item_ID: B07TH3LYSB | Image_ID: 61jYQOvLnLL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3LYXS | Image_ID: 61ZLW3Z+X0L | Question: Is the case for a Micromax phone? | Answer: Yes
# Processed: Item_ID: B07TH3LYXZ | Image_ID: 61XastAZsNL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3T8W6 | Image_ID: 81+zhUyovbL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3T8YC | Image_ID: 813ErrJq4ML | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3T8YS | Image_ID: 81IIHtkI7RL | Question: Is this case for a Nokia 5? | Answer: Yes
# Processed 30/1000 products
# Processed: Item_ID: B07TH3T99Q | Image_ID: 71Wm5z0mUEL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3T9GQ | Image_ID: 71-BbElHaYL | Question: Is this case for a Huawei G8? | Answer: Yes
# Processed: Item_ID: B07TH3T9HN | Image_ID: 717eFIey+xL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3T9JR | Image_ID: 81faegtVBVL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3ZYQM | Image_ID: 71IaPGaGpTL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3ZZ49 | Image_ID: 81JrEbrruTL | Question: Is this case for a Xiaomi Redmi 3S? | Answer: Yes
# Processed: Item_ID: B07TH3ZZBY | Image_ID: 81jSvLSBqQL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH3ZZG5 | Image_ID: 615h+iZ61DL | Question: What animal is depicted on the phone case? | Answer: Cat
# Processed: Item_ID: B07TH41SSC | Image_ID: 71LE7Hled-L | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TH41SZR | Image_ID: 71MhpUHTrsL | Question: Is this case 3D printed? | Answer: Yes
# Processed 40/1000 products
# Processed: Item_ID: B07TH41T58 | Image_ID: 71TfjaJ1xKL | Question: What is the phone model this case fits? | Answer: Gionee
# Processed: Item_ID: B07TH9K2Z4 | Image_ID: 71-zGxMRejL | Question: Is this case for an Oppo F1s? | Answer: Yes
# Processed: Item_ID: B07TH9QPWX | Image_ID: 71ZbjKty3cL | Question: Is the case predominantly black or white? | Answer: Black
# Error processing row 3046: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07THBZ1NL | Image_ID: 81T1CzhDXNL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3048: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07THC2QB2 | Image_ID: 61NBhFwMG9L | Question: Is the case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THC7R79 | Image_ID: 81otYIYClBL | Question: What is the case's material? | Answer: Wood
# Processed: Item_ID: B07THC86YP | Image_ID: 61gErEqXaoL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THC87V4 | Image_ID: 71N3Qa8n+yL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THCM2QC | Image_ID: 715gl5xyUvL | Question: What is the color of the bar stools? | Answer: Gray
# Processed: Item_ID: B07THKW5MK | Image_ID: 81o1H+3RStL | Question: What is the color of the shoes? | Answer: Brown
# Processed 50/1000 products
# Processed: Item_ID: B07THQY3CF | Image_ID: 61O+zPYa5AL | Question: What is the depicted object on the phone case? | Answer: Candle
# Error processing row 3056: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07THRL5VL | Image_ID: 71qiBVFuuvL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THRNQN4 | Image_ID: 71BQMI9iFOL | Question: What is the depicted flower on the phone case? | Answer: Tulips
# Processed: Item_ID: B07THRVR1V | Image_ID: 81bVe4UE+pL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THRZ9YW | Image_ID: 71JR5dBgTdL | Question: What is the phone model compatibility? | Answer: Xperia L1
# Processed: Item_ID: B07THS343C | Image_ID: 61fF8VLGqjL | Question: What word is printed on the case? | Answer: Sad
# Error processing row 3062: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07THS6KBR | Image_ID: 81dk6w2OVYL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THS96Y5 | Image_ID: 710fUt7WEEL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THSC77W | Image_ID: 71G-Db0LayL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THSGJHL | Image_ID: 61DlBtadcYL | Question: Is the case 3D printed? | Answer: Yes
# Processed 60/1000 products
# Processed: Item_ID: B07THSL1S8 | Image_ID: 819On5k+uSL | Question: Is the case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THSM928 | Image_ID: 7141j-WIzFL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07THSMWST | Image_ID: 717cSsZLN2L | Question: Is this case for a Xiaomi Redmi Y1 Lite? | Answer: Yes
# Processed: Item_ID: B07THV4NVR | Image_ID: 51u7CRSqBGL | Question: How many tuk tuks are in a pack? | Answer: Five
# Processed: Item_ID: B07THY2QG1 | Image_ID: 71rzNKH-DPL | Question: What is the weight of this hammer? | Answer: 16
# Processed: Item_ID: B07THY3W7P | Image_ID: 81lneMKqWsL | Question: What is the hammer's weight in ounces? | Answer: 8
# Processed: Item_ID: B07THYL7VN | Image_ID: 71eggkPdmML | Question: What color are the boots? | Answer: Schwarz
# Processed: Item_ID: B07TJDWSK6 | Image_ID: 61huqvryD+L | Question: What is the color of the curtains? | Answer: Royal
# Processed: Item_ID: B07TJGTL14 | Image_ID: 812Pqgq+WZL | Question: Is this a UPS? | Answer: Yes
# Processed: Item_ID: B07TJVQ7YP | Image_ID: 61kQsmdSKlL | Question: Is this case 3D printed? | Answer: Yes
# Processed 70/1000 products
# Processed: Item_ID: B07TJW2TMV | Image_ID: 71JeOfdEptL | Question: Is this case for the Sony Xperia L1? | Answer: Yes
# Processed: Item_ID: B07TK4HPDT | Image_ID: 61DTnwocdgL | Question: What is the color of the loafers? | Answer: Brown
# Processed: Item_ID: B07TK4MWFK | Image_ID: 716FPNzyAqL | Question: What color are the shoes? | Answer: Brown
# Processed: Item_ID: B07TK4MYCQ | Image_ID: 71EO47FMR7L | Question: What is the color of the boots? | Answer: Black
# Processed: Item_ID: B07TK4MYLC | Image_ID: 61DTnwocdgL | Question: What is the color of these loafers? | Answer: Brown
# Processed: Item_ID: B07TKL4QP7 | Image_ID: 71jS2hGtUlL | Question: What is the tablecloth's color? | Answer: Green
# Processed: Item_ID: B07TL3T5Y6 | Image_ID: 61HAuP4FZOL | Question: What color are the shoes? | Answer: Black
# Processed: Item_ID: B07TLLRVZH | Image_ID: 51IBu3CKxTL | Question: What is the size of these file folders? | Answer: Letter
# Error processing row 3085: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f77df0ab.jpg'
# Processed: Item_ID: B07TM5SHWH | Image_ID: 71fAvwCSa6L | Question: What color are the shoes? | Answer: Black
# Processed: Item_ID: B07TN1ZT1N | Image_ID: 71Qx3UDNXVL | Question: What color is the bean bag chair? | Answer: Black
# Processed 80/1000 products
# Processed: Item_ID: B07TN8WW83 | Image_ID: 61xebErbZBL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3089: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TN8ZQ9V | Image_ID: 81yQPdUyB-L | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TNKZM8H | Image_ID: 711wS4CEzeL | Question: What is the desk's color? | Answer: White
# Processed: Item_ID: B07TNL72CK | Image_ID: 71-bjsdx6GL | Question: Is this a single bottle of hand soap? | Answer: No
# Processed: Item_ID: B07TPCP7TN | Image_ID: 71Lb+VzcYFL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TPCQJ3P | Image_ID: 71lik-ivVaL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TQ7M4QR | Image_ID: 81W4vuWWyEL | Question: What is the chair's primary material? | Answer: Fabric
# Processed: Item_ID: B07TQH73QZ | Image_ID: 71-jiK8zldL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3097: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TQH7YG6 | Image_ID: 71jlhc37uHL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3099: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 3100: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe0ca3a7.jpg'
# Processed: Item_ID: B07TQH9VTG | Image_ID: 71Z+iYgGXVL | Question: Is this case for a Samsung Galaxy S10? | Answer: Yes
# Processed 90/1000 products
# Processed: Item_ID: B07TQH9VYJ | Image_ID: 71Eg1UwsASL | Question: What color is the bird depicted on the case? | Answer: Red
# Processed: Item_ID: B07TQH9XMQ | Image_ID: 81vCfTyBE9L | Question: Is this case for Xiaomi Redmi Go? | Answer: Yes
# Processed: Item_ID: B07TQH9YRX | Image_ID: 71fhRpQez8L | Question: Is this case for a Samsung Galaxy S10e? | Answer: Yes
# Processed: Item_ID: B07TQHB671 | Image_ID: 71qJ7Xj+O3L | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TQHB743 | Image_ID: 71wemTqSUoL | Question: Is this case hard or soft? | Answer: Hard
# Processed: Item_ID: B07TQHBDNT | Image_ID: 811MyBKUuAL | Question: Is this case hard or soft? | Answer: Hard
# Processed: Item_ID: B07TQHBG6C | Image_ID: 81nYf1817LL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TQM977B | Image_ID: 71BDa7NVacL | Question: What is the shape of the table? | Answer: Round
# Processed: Item_ID: B07TRFP8KY | Image_ID: 71g7FQ38SrL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRFV2V5 | Image_ID: 7104L+62P2L | Question: Is this case 3D printed? | Answer: Yes
# Processed 100/1000 products
# Processed: Item_ID: B07TRG39HR | Image_ID: 71Bw1NeanAL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRG5TNK | Image_ID: 71wDfiFXRkL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRG8FFJ | Image_ID: 61E1dIttEEL | Question: Is this case hard or soft? | Answer: Hard
# Processed: Item_ID: B07TRG8TDF | Image_ID: 7138zOV87aL | Question: Is this case for Gionee P7 Max? | Answer: Yes
# Processed: Item_ID: B07TRMBRWB | Image_ID: 71YiPdPJWuL | Question: What is the light strip's color? | Answer: White
# Processed: Item_ID: B07TRVJS7H | Image_ID: 71OCGi+VmPL | Question: Is this case hard or soft? | Answer: Hard
# Processed: Item_ID: B07TRVLYZB | Image_ID: 71L1u8c2vOL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRVLYZH | Image_ID: 71aTrv6mRLL | Question: Is this case hard or soft? | Answer: Hard
# Processed: Item_ID: B07TRVLZ5K | Image_ID: 71NKL6vmaAL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRVMDYX | Image_ID: 716JJvWNqVL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3122: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f1/f1442c4f.jpg'
# Processed 110/1000 products
# Processed: Item_ID: B07TRVN9WQ | Image_ID: 71VzwcfpYAL | Question: Is this case for a Samsung Galaxy S10 Plus? | Answer: Yes
# Processed: Item_ID: B07TRVN9ZF | Image_ID: 71O03Mvi-nL | Question: What material is the phone case made of? | Answer: Wood
# Processed: Item_ID: B07TRVQDMY | Image_ID: 81eoU11i1jL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRVQDNX | Image_ID: 81lp11hLPDL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRVQHK8 | Image_ID: 71CvEFCmJOL | Question: Is the case hard? | Answer: Yes
# Error processing row 3128: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f88437ff.jpg'
# Processed: Item_ID: B07TRVT34D | Image_ID: 81CnyY1EMDL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3130: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TRVX41Q | Image_ID: 7104L+62P2L | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRW4XXN | Image_ID: 71dilvH5QML | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRW6PCK | Image_ID: 81NnXaDCUIL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRWBXZG | Image_ID: 71p8PV8WpOL | Question: Is this case 3D printed? | Answer: Yes
# Processed 120/1000 products
# Processed: Item_ID: B07TRWJTS2 | Image_ID: 71v31IAWg8L | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3136: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TRWLVNT | Image_ID: 81lFYFR0ATL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRWPZXV | Image_ID: 71cskaw+tKL | Question: Is this case hard or soft? | Answer: Hard
# Error processing row 3139: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TRWRC8B | Image_ID: 81TdF4wvGVL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRWRQKZ | Image_ID: 81hwzDGUnSL | Question: Is this case for the Vivo Y81i? | Answer: Yes
# Processed: Item_ID: B07TRWSRW3 | Image_ID: 71uxvf3B81L | Question: What number is depicted on the case? | Answer: Two
# Processed: Item_ID: B07TRWSYH2 | Image_ID: 61BZI8wCcjL | Question: What is the phone model this case is for? | Answer: Redmi
# Processed: Item_ID: B07TRWTD13 | Image_ID: 716SrRaD21L | Question: Is the case for an Oppo F9? | Answer: Yes
# Processed: Item_ID: B07TRWTQKQ | Image_ID: 81O3Wqs2drL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRWVXP8 | Image_ID: 71b9e2ZBEqL | Question: Is this case 3D printed? | Answer: Yes
# Processed 130/1000 products
# Processed: Item_ID: B07TRWW4HS | Image_ID: 71rOwHHwzLL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRWW4J4 | Image_ID: 71XTZgtz56L | Question: Is this case for a Xiaomi Redmi Note 7 Pro? | Answer: Yes
# Processed: Item_ID: B07TRWW4JT | Image_ID: 71pPyt-9O0L | Question: Is this case for a Samsung Galaxy S10 Plus? | Answer: Yes
# Processed: Item_ID: B07TRWW4K3 | Image_ID: 61tYUC6qyHL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3151: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 3152: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f60bbcfa.jpg'
# Error processing row 3153: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TRWZ3N2 | Image_ID: 71u7QAUnzkL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRX1BTQ | Image_ID: 71T6aqgml+L | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TRX1BX9 | Image_ID: 71mdJqia8fL | Question: Is this case for a Samsung Galaxy S10 Plus? | Answer: Yes
# Error processing row 3157: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TSWND4N | Image_ID: 81XpgpugsRL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3159: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TSWNDB7 | Image_ID: 71otEiPhU-L | Question: Is the case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TSY99HK | Image_ID: 71tAApbBuXL | Question: What is the primary design element on this phone case? | Answer: Tree
# Processed 140/1000 products
# Processed: Item_ID: B07TSY99LF | Image_ID: 81oKcJpKwzL | Question: Is this case 3D printed? | Answer: Yes
# Error processing row 3163: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 3164: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 3165: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TSYQ4LY | Image_ID: 71fDVRwXybL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TSYQ4M1 | Image_ID: 619-WBV8MFL | Question: Is this case 3D printed? | Answer: Yes
# Processed: Item_ID: B07TTBBT49 | Image_ID: 51ut8Nu6o6L | Question: Is the squeegee extendable? | Answer: Yes
# Processed: Item_ID: B07TTCK717 | Image_ID: 91V2GzL4ldL | Question: What is the shape of this rug? | Answer: Rectangular
# Processed: Item_ID: B07TTCS9M7 | Image_ID: 71KYke9S5fL | Question: How many organizers are included? | Answer: Three
# Processed: Item_ID: B07TTN59ZW | Image_ID: 91Tqd25BFvL | Question: What is the color of the organizer? | Answer: Black
# Processed: Item_ID: B07TVPG13T | Image_ID: 81d20dOiQbL | Question: What is the bed size? | Answer: King
# Processed: Item_ID: B07TXD56J4 | Image_ID: 819GfZ30i2L | Question: What is the length of the rope light? | Answer: Twenty
# Error processing row 3174: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fbd3de5d.jpg'
# Processed: Item_ID: B07TYPSB9G | Image_ID: 71hmoe+ppfL | Question: What is the color of the shoes? | Answer: White
# Processed 150/1000 products
# Processed: Item_ID: B07TZFV7N5 | Image_ID: 61Cj59D9oRL | Question: Is this a USB-C to HDMI adapter? | Answer: Yes
# Processed: Item_ID: B07TZMWJ3B | Image_ID: 81KnkOpo1nL | Question: What is the closure type of these shoes? | Answer: Lace-Up
# Processed: Item_ID: B07V126F2S | Image_ID: 71OAqgfCojL | Question: What is the number of tiers on this cart? | Answer: Three
# Processed: Item_ID: B07V1N7W2V | Image_ID: 51TilJ04n4L | Question: Is this product fragrance-free? | Answer: Yes
# Processed: Item_ID: B07V248XSH | Image_ID: 6145S991WWL | Question: Is the case clear? | Answer: Yes
# Processed: Item_ID: B07V2CGB91 | Image_ID: 719oQW-oY2L | Question: Is this storage bag waterproof? | Answer: Yes
# Processed: Item_ID: B07V34JJ9W | Image_ID: 91-ptzfXoDL | Question: Is this a handbag? | Answer: No
# Processed: Item_ID: B07V36W17M | Image_ID: 81ae22GlrzL | Question: How many microphones are included? | Answer: Two
# Processed: Item_ID: B07V3TD5Q7 | Image_ID: 91zXQfZeptL | Question: How many pieces are in this tool set? | Answer: 173
# Processed: Item_ID: B07V4877CT | Image_ID: 41tpfA+l9lL | Question: Is rinsing required after use? | Answer: No
# Processed 160/1000 products
# Processed: Item_ID: B07V593X86 | Image_ID: 71qT9Eyj+IL | Question: What is the microphone's pickup pattern? | Answer: Omnidirectional
# Processed: Item_ID: B07V5BT4FJ | Image_ID: 418KhoYVdyL | Question: Is this product a peel-off mask? | Answer: No
# Processed: Item_ID: B07V5G2KG4 | Image_ID: 61IGCC3k1mL | Question: What is the pack size? | Answer: Six
# Processed: Item_ID: B07V5JLD9K | Image_ID: 71w6t3Soj9L | Question: What is the color temperature of this work light? | Answer: 5000K
# Processed: Item_ID: B07V5P57VM | Image_ID: 51KalXzJnHL | Question: Is this product new? | Answer: No
# Processed: Item_ID: B07V6D7BTB | Image_ID: 81HDxW0v29L | Question: Is this cat food grain-free? | Answer: Yes
# Processed: Item_ID: B07V6F1CCV | Image_ID: 61CSXwGy4EL | Question: What phone model does this case fit? | Answer: OnePlus 7
# Processed: Item_ID: B07V8N689N | Image_ID: 51LxSa194RL | Question: How many USB ports does this hub have? | Answer: Four
# Processed: Item_ID: B07V9MNLW9 | Image_ID: 51-Hu-kGggL | Question: Is assembly required? | Answer: No
# Processed: Item_ID: B07VCHL5HN | Image_ID: 61fKQoq4zML | Question: What color are the slippers? | Answer: Black
# Processed 170/1000 products
# Processed: Item_ID: B07VD8MB71 | Image_ID: 81bXGs0lDGL | Question: What is the shape of this Dutch oven? | Answer: Oval
# Processed: Item_ID: B07VDD6B6S | Image_ID: 416OnkU3QgL | Question: What is the shape of the coffee table? | Answer: Rectangular
# Processed: Item_ID: B07VDHHHNM | Image_ID: 51MafQY4hQL | Question: What is the color of the shoes? | Answer: Rose
# Processed: Item_ID: B07VFH61MN | Image_ID: 51AbsqTnMpL | Question: Is this item rectangular? | Answer: Yes
# Processed: Item_ID: B07VFLJXQ5 | Image_ID: 71SdXzr8lfL | Question: What is the material of the shoe's sole? | Answer: Synthetic
# Processed: Item_ID: B07VFYRJKF | Image_ID: 812-FFkhEyL | Question: What is the brand of these lifting straps? | Answer: UMI
# Error processing row 3202: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f2/f229413d.jpg'
# Processed: Item_ID: B07VHGBZJF | Image_ID: 81-uFPWCieL | Question: Is this item renewed? | Answer: Yes
# Processed: Item_ID: B07VJFP3PN | Image_ID: 61xs0cOTE+L | Question: What color is the headset? | Answer: Blue
# Processed: Item_ID: B07VJH1B5N | Image_ID: 81X5a4I1ofL | Question: What is the serving size in cups? | Answer: Half
# Processed: Item_ID: B07VJK1MBT | Image_ID: 71Dzz66wCKL | Question: What is the belt's color? | Answer: Brown
# Processed 180/1000 products
# Processed: Item_ID: B07VJNV8SF | Image_ID: 61IobkkgK5L | Question: What is the color of the slippers? | Answer: Black
# Processed: Item_ID: B07VK9F686 | Image_ID: 61hvuMMLB0L | Question: What color is the umbrella shown in the main image? | Answer: Claret
# Processed: Item_ID: B07VM4MZS6 | Image_ID: 71YbMoAdbiL | Question: Is this product vegetarian? | Answer: Yes
# Processed: Item_ID: B07VMRRH2B | Image_ID: 61eaPb7XQwL | Question: What is the case's primary color? | Answer: Clear
# Processed: Item_ID: B07VP49RPP | Image_ID: 71B7kT9JiZL | Question: What is the color of the shoes? | Answer: Maroon
# Processed: Item_ID: B07VPDF9H5 | Image_ID: 61bb0ksCNOL | Question: What is the shape of this toilet seat? | Answer: Elongated
# Processed: Item_ID: B07VPTQ5R6 | Image_ID: 71s0bNv8WrL | Question: What is the closure type of these sneakers? | Answer: Lace-Up
# Error processing row 3214: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0c12fea.jpg'
# Processed: Item_ID: B07VRBVX71 | Image_ID: 91pJbz4A0DL | Question: What is the screen protector's material? | Answer: Plastic
# Processed: Item_ID: B07VRBWLVM | Image_ID: 51ZLixSK0FL | Question: What is the color of the screen protector? | Answer: Black
# Processed: Item_ID: B07VSFK6M6 | Image_ID: 81Lj8T5duUL | Question: What is the toe style? | Answer: Round
# Processed 190/1000 products
# Processed: Item_ID: B07VSFL73D | Image_ID: 81Lj8T5duUL | Question: What is the toe style? | Answer: Round
# Processed: Item_ID: B07VSGZZYY | Image_ID: 81QBiPtMJlL | Question: What is the color of the boots? | Answer: Black
# Processed: Item_ID: B07VSTTSSC | Image_ID: 71zIV-qxbQL | Question: What is the color of the Movian Galga footstool? | Answer: Lightgrey
# Processed: Item_ID: B07VSV1346 | Image_ID: 71ZLG+TZSUL | Question: What is the battery type? | Answer: AA
# Processed: Item_ID: B07VT9JC54 | Image_ID: 51tCQ-uGsXL | Question: What is the color of this screen protector? | Answer: Black
# Processed: Item_ID: B07VTC4WTH | Image_ID: 91jYEXHJPqL | Question: What is the closure type of these sneakers? | Answer: SlipOn
# Processed: Item_ID: B07VTCMYHB | Image_ID: 71++z2b8RGL | Question: What is the closure type of these shoes? | Answer: SlipOn
# Processed: Item_ID: B07VTN8SXH | Image_ID: 71zxMZ82-oL | Question: What is the primary material of this phone case? | Answer: Plastic
# Processed: Item_ID: B07VTN8T76 | Image_ID: 51AbYbblgmL | Question: Is this a single snap case? | Answer: Yes
# Processed: Item_ID: B07VTN8XD4 | Image_ID: 61s7mNzY7OL | Question: Is this case 3D printed? | Answer: Yes
# Processed 200/1000 products
# Processed: Item_ID: B07VTQ6F6W | Image_ID: 91V7mTcSQEL | Question: Is this product a single map? | Answer: No
# Processed: Item_ID: B07VTS66WG | Image_ID: 81lBzjGLByL | Question: What is the color of these hangers? | Answer: Grey
# Processed: Item_ID: B07VVBRRFX | Image_ID: A15xaQiVC9L | Question: What is the number of compartments in this organizer? | Answer: Six
# Processed: Item_ID: B07VVBRTS8 | Image_ID: 81HkYxgxifL | Question: What is the color of the pencil cup? | Answer: Black
# Processed: Item_ID: B07VVPZ958 | Image_ID: 91VrySYjNRL | Question: What is the cooler's color? | Answer: Red
# Processed: Item_ID: B07VX5VC9D | Image_ID: 71OSRIOeOGL | Question: What is the color of the string lights? | Answer: Black
# Processed: Item_ID: B07VX6BDRM | Image_ID: 713H8gZjphL | Question: Is the fry pan dishwasher safe? | Answer: Yes
# Processed: Item_ID: B07VX74LXN | Image_ID: 51AbYbblgmL | Question: What is the case's primary material? | Answer: Plastic
# Processed: Item_ID: B07VX75CH8 | Image_ID: 61nmE3v9IAL | Question: What word is prominently displayed on the case? | Answer: Queen
# Processed: Item_ID: B07VX78WBZ | Image_ID: 51AbYbblgmL | Question: Is this case compatible with Realme 3i? | Answer: Yes
# Processed 210/1000 products
# Processed: Item_ID: B07VX7DQY4 | Image_ID: 61MZwLcH6BL | Question: What is the case material? | Answer: Plastic
# Processed: Item_ID: B07VX7JPRB | Image_ID: 61KGb2jQfiL | Question: Is this case compatible with the Realme 3i? | Answer: Yes
# Error processing row 3240: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f00940b1.jpg'
# Processed: Item_ID: B07VXFYCBV | Image_ID: 81sWBeUni0L | Question: What is the color of the binders? | Answer: Black
# Processed: Item_ID: B07VXH63BY | Image_ID: 71tD4vWCtYL | Question: How many pieces are in this BBQ tool set? | Answer: Two
# Processed: Item_ID: B07VXQXBKV | Image_ID: 619C-TyD1aL | Question: How many USB ports does this hub have? | Answer: Seven
# Processed: Item_ID: B07VXQYLDB | Image_ID: 61su5btZlYL | Question: How many hooks are on this rack? | Answer: Three
# Processed: Item_ID: B07VXTRGYJ | Image_ID: 71tePUSH83L | Question: How many colors are included? | Answer: Forty
# Processed: Item_ID: B07VXTX4PC | Image_ID: 61RfQZzsJaL | Question: Is the bulb dimmable? | Answer: Yes
# Processed: Item_ID: B07VY41R8M | Image_ID: 81rGS24VyrL | Question: Is this a clamp meter? | Answer: Yes
# Processed: Item_ID: B07VY853GT | Image_ID: 81M5-o3SHvL | Question: What is the brand of these push-up handles? | Answer: AmazonBasics
# Processed 220/1000 products
# Processed: Item_ID: B07VY9X7SY | Image_ID: 61kFvkMueML | Question: What is the design featured on this phone case? | Answer: Heart
# Processed: Item_ID: B07VYB2P7B | Image_ID: 71FPb0t-GJL | Question: What is the case material? | Answer: Plastic
# Processed: Item_ID: B07VYL8Y5H | Image_ID: 91KD1IW5TUL | Question: What is the color of the TV mount? | Answer: Black
# Processed: Item_ID: B07VYMN28P | Image_ID: 81bA40UzhkL | Question: Is assembly required? | Answer: No
# Processed: Item_ID: B07VZL4YQH | Image_ID: 715i5BOuPZL | Question: What is the color of the chair? | Answer: Black
# Processed: Item_ID: B07VZWYC4G | Image_ID: 71Bi+5qdGIL | Question: How many pens are included? | Answer: Ten
# Processed: Item_ID: B07VZZF9K3 | Image_ID: 51p3JwLo7nL | Question: What color is the case? | Answer: Black
# Processed: Item_ID: B07W13Q89B | Image_ID: 71n2KnvG0GL | Question: What type of peeler is this? | Answer: Julienne
# Processed: Item_ID: B07W1KNY8K | Image_ID: 71ZHO71dpWL | Question: What is the hamper's color? | Answer: Black
# Processed: Item_ID: B07W34DD5Z | Image_ID: 71Xcwsb7vNL | Question: How many markers are included? | Answer: Forty
# Processed 230/1000 products
# Processed: Item_ID: B07W421Z13 | Image_ID: 61Zj78Iu43L | Question: What is the table's shape? | Answer: Square
# Processed: Item_ID: B07W48G2LN | Image_ID: 811ZxOj8pZL | Question: What is the brand of this staple pack? | Answer: AmazonBasics
# Processed: Item_ID: B07W4L2L9B | Image_ID: 71mVFTEAIqL | Question: What is the shoe's color? | Answer: Black
# Error processing row 3262: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/ed4323d1.jpg'
# Processed: Item_ID: B07W5KWY15 | Image_ID: 71vmVEr+7YL | Question: What is the color of the sneaker? | Answer: Black
# Processed: Item_ID: B07W5Q6D8K | Image_ID: 619goV0E0iL | Question: What color are the shoes? | Answer: Black
# Processed: Item_ID: B07W5TC5NB | Image_ID: 61cqG3cpjNL | Question: What is the yogurt's flavor? | Answer: Plain
# Processed: Item_ID: B07W681TS1 | Image_ID: 71Okow-w9ZL | Question: Is this filter lead-free? | Answer: Yes
# Processed: Item_ID: B07W6HW46Z | Image_ID: 91GBoEQLyQL | Question: What is the brand of these speakers? | Answer: AmazonBasics
# Processed: Item_ID: B07W6ZQKDF | Image_ID: 81QvyC-PJLL | Question: What is the ice cream flavor? | Answer: RockyRoad
# Processed: Item_ID: B07W6ZR7XF | Image_ID: 818dVYMwqyL | Question: What is the ice cream's flavor? | Answer: Neapolitan
# Processed 240/1000 products
# Processed: Item_ID: B07W7TT617 | Image_ID: 71k8+4RMw5L | Question: What is the color of the shoes? | Answer: Brown
# Processed: Item_ID: B07W8QYQ2Z | Image_ID: 61weQOjtSmL | Question: How many light bulbs are included? | Answer: Two
# Processed: Item_ID: B07W93PRMY | Image_ID: 61xyYj41C1L | Question: What color are the shoes? | Answer: Black
# Processed: Item_ID: B07W9955XS | Image_ID: 71vj-pLMhML | Question: How many soaps are in this pack? | Answer: Three
# Processed: Item_ID: B07WC6LZ34 | Image_ID: 71WeLgY9GzL | Question: Is a bulb included? | Answer: Yes
# Processed: Item_ID: B07WD8LYK3 | Image_ID: 71l3YjWUPfL | Question: Is this shoe a slip-on? | Answer: Yes
# Processed: Item_ID: B07WDJN6KK | Image_ID: 61U2QEiVTCL | Question: What color are the pumps? | Answer: Navy
# Processed: Item_ID: B07WDRDWRR | Image_ID: 713zqYmfVSL | Question: What is the color of the Centrino Men's 5535 Mouse Sneakers? | Answer: Brown
# Processed: Item_ID: B07WDY5NBJ | Image_ID: 71ewX6O7pFL | Question: What is the diaper size? | Answer: 3
# Error processing row 3279: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb171c5e.jpg'
# Processed: Item_ID: B07WFPCQ5F | Image_ID: 71a7sKU1Q8L | Question: What is the toe shape? | Answer: Round
# Processed 250/1000 products
# Processed: Item_ID: B07WG3V8ZL | Image_ID: 91Nq7-6SM4L | Question: What is the color of the shoes? | Answer: Brown
# Processed: Item_ID: B07WG3V92H | Image_ID: 91Nq7-6SM4L | Question: What is the shoe's color? | Answer: Brown
# Processed: Item_ID: B07WGFGG88 | Image_ID: 71ds7HC5BzL | Question: Is this a dishwasher-safe set? | Answer: Yes
# Processed: Item_ID: B07WGPBBTV | Image_ID: 61FngxG+eEL | Question: What is the toe style of these sandals? | Answer: Open
# Processed: Item_ID: B07WH14DNN | Image_ID: 51GRTFFPslL | Question: Is the glue washable? | Answer: Yes
# Processed: Item_ID: B07WH3VBY5 | Image_ID: 81w8r-DBJCL | Question: What is the closure type of this shoe? | Answer: Lace-Up
# Processed: Item_ID: B07WHRS1P5 | Image_ID: 61dHrVEXTuL | Question: What is the color of the sandals? | Answer: Beige
# Processed: Item_ID: B07WJ5SQ4D | Image_ID: 71ejfQTZXUL | Question: What is the sofa's seating capacity? | Answer: Three
# Processed: Item_ID: B07WJJGNFZ | Image_ID: 71I84cKCkYL | Question: What is the material of the boot's upper? | Answer: Leather
# Processed: Item_ID: B07WJYKK3N | Image_ID: 71ifzzdXJKL | Question: What material is the shoe made of? | Answer: Leather
# Processed 260/1000 products
# Processed: Item_ID: B07WMR7ZZQ | Image_ID: 71P9USHujjL | Question: What is the color of the shoes? | Answer: Green
# Processed: Item_ID: B07WN6FT9J | Image_ID: 71jJD37UJeL | Question: What is the closure type of these shoes? | Answer: Lace-Up
# Processed: Item_ID: B07WNNY3TL | Image_ID: 91dE5w5vV8L | Question: What is the color of the handbag? | Answer: Pink
# Processed: Item_ID: B07WNNY3XR | Image_ID: 81Rfh5wmAHL | Question: What is the color of the handbag? | Answer: Black
# Processed: Item_ID: B07WNNYM4L | Image_ID: 8174Pe9FRRL | Question: What is the primary material of the Flavia handbag? | Answer: Leather
# Processed: Item_ID: B07WP5NM6P | Image_ID: 61Oyl0GJOCL | Question: What letter is prominently displayed on the case? | Answer: T
# Processed: Item_ID: B07WPDPT8Y | Image_ID: 71kcBOOMnaL | Question: What is the sandal's color? | Answer: Gold
# Processed: Item_ID: B07WPKTXFX | Image_ID: 81cF5ae3BIL | Question: What is the closure type of these sneakers? | Answer: SlipOn
# Processed: Item_ID: B07WPL2HGC | Image_ID: 91+BwtL4SQL | Question: What is the color of the hangers? | Answer: Pink
# Processed: Item_ID: B07WQFGNRM | Image_ID: 51Exf46KjeL | Question: What color is the filament? | Answer: Gold
# Processed 270/1000 products
# Processed: Item_ID: B07WQGJTFS | Image_ID: 81RNJa9Q1rL | Question: What is the color of the shoes? | Answer: Olive
# Processed: Item_ID: B07WR33WT7 | Image_ID: 7150zpOn42L | Question: What color is the handbag? | Answer: Blue
# Processed: Item_ID: B07WR35SL6 | Image_ID: 71ZfnNicKfL | Question: What is the handbag's color? | Answer: Pink
# Processed: Item_ID: B07WR36GYD | Image_ID: 81+JGaFJxNL | Question: What color is the handbag? | Answer: Black
# Processed: Item_ID: B07WRJF7V3 | Image_ID: 917hhbd8C1L | Question: What is the color of the Flavia clutch? | Answer: Pink
# Processed: Item_ID: B07WRJFGR6 | Image_ID: 91fTVgzUAtL | Question: What is the handbag's material? | Answer: Leather
# Processed: Item_ID: B07WRPJJS8 | Image_ID: 81TGJoO7GWL | Question: What is the pasta shape? | Answer: Rotini
# Processed: Item_ID: B07WS88NM8 | Image_ID: 71Yze9KnazL | Question: What is the style of the find. Women's sandals? | Answer: Darling
# Processed: Item_ID: B07WSBR61J | Image_ID: 71eSPe18I0L | Question: What is the weight of the cauliflower florets in ounces? | Answer: 12
# Processed: Item_ID: B07WSNKN8W | Image_ID: 816i3mNMZ3L | Question: What color is the handbag? | Answer: Black
# Processed 280/1000 products
# Processed: Item_ID: B07WSQK2YV | Image_ID: 61b2KzXAv2L | Question: What is the timer's cycle length? | Answer: 24-hour
# Processed: Item_ID: B07WSRKF93 | Image_ID: 715KKre+scL | Question: What is the heel type? | Answer: Block
# Processed: Item_ID: B07WSWVNZT | Image_ID: 81LoN2RmgML | Question: Is this mouthwash antiseptic? | Answer: Yes
# Processed: Item_ID: B07WT2VGMX | Image_ID: 51AbYbblgmL | Question: Is this case compatible with the Samsung Galaxy S4? | Answer: Yes
# Processed: Item_ID: B07WT31P6Z | Image_ID: 71MK88bp83L | Question: What city is featured on the phone case? | Answer: Mumbai
# Processed: Item_ID: B07WT489JN | Image_ID: 71oAwZAjeTL | Question: What is the material of the cup? | Answer: Paper
# Processed: Item_ID: B07WTMZ8P1 | Image_ID: 81RrbEntx2L | Question: What is the clutch's color? | Answer: Pink
# Processed: Item_ID: B07WTMZ91W | Image_ID: 913cS4dQggL | Question: Is this a handbag? | Answer: Yes
# Processed: Item_ID: B07WTN3XJ1 | Image_ID: 81VVdiewwML | Question: What is the color of the Flavia clutch? | Answer: Black
# Processed: Item_ID: B07WV2DVKN | Image_ID: 61vqGdm2BrL | Question: What is the phone model compatibility? | Answer: Xperia M5
# Processed 290/1000 products
# Processed: Item_ID: B07WV2PS41 | Image_ID: 51AbYbblgmL | Question: What is the case material? | Answer: Plastic
# Processed: Item_ID: B07WVSDHMF | Image_ID: 715M2zvqoyL | Question: What is the color of the shoes? | Answer: Navy
# Processed: Item_ID: B07WW8QVYD | Image_ID: 61MW3GB3MZL | Question: Is this case compatible with Motorola Moto X Play? | Answer: Yes
# Processed: Item_ID: B07WX982LY | Image_ID: 61GmCVQ3wLL | Question: Is this phone case compatible with the Xiaomi Redmi 2 Prime? | Answer: Yes
# Processed: Item_ID: B07WXM3C7Y | Image_ID: 81uK3PJGaRL | Question: What color are the sandals? | Answer: Black
# Processed: Item_ID: B07WXNLT3K | Image_ID: 71KfODD6-TL | Question: What is the color of the laundry basket? | Answer: Gray
# Processed: Item_ID: B07WY63265 | Image_ID: 51AbYbblgmL | Question: Is this case compatible with the Motorola Moto E2? | Answer: Yes
# Processed: Item_ID: B07WY65NRX | Image_ID: 61SVQ6t5obL | Question: What is the phone model this case is compatible with? | Answer: LeEco
# Processed: Item_ID: B07WY6GYSK | Image_ID: 61QbcfDL7sL | Question: Is this case compatible with the Lenovo A7000? | Answer: Yes
# Error processing row 3330: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f7bc8eb0.jpg'
# Processed: Item_ID: B07WYYCMN9 | Image_ID: 81eBtTEXvvL | Question: What is the size of the relish jar? | Answer: 10-ounce
# Processed 300/1000 products
# Processed: Item_ID: B07WZMDJJ9 | Image_ID: 613-T3MMkYL | Question: What is the heel type? | Answer: Flats
# Processed: Item_ID: B07WZSNCRQ | Image_ID: 61YORareCNL | Question: What color are the bookends? | Answer: White
# Processed: Item_ID: B07X1XG3KP | Image_ID: 61Tb0gIaq3L | Question: How many canvases are included? | Answer: Two
# Processed: Item_ID: B07X1XGC4Z | Image_ID: 61UHsyITdKL | Question: What color is the canvas? | Answer: White
# Processed: Item_ID: B07X2TFL2F | Image_ID: 71gA2sPOt7L | Question: What color are the shoes? | Answer: Grey
# Processed: Item_ID: B07X2X85QL | Image_ID: 61EjflSMF1L | Question: How many canvas panels are included? | Answer: Five
# Processed: Item_ID: B07X3L2FSQ | Image_ID: 81gZyqR8KmL | Question: What type of tea is this? | Answer: Earl Grey
# Processed: Item_ID: B07X3LPXYB | Image_ID: 61js-Js-1mL | Question: How many tea bags are included? | Answer: Twenty
# Processed: Item_ID: B07X3PL9MJ | Image_ID: 71h6rhvKH9L | Question: How many bulbs are included? | Answer: Two
# Processed: Item_ID: B07X3ZD49J | Image_ID: 71ybM8tMMkL | Question: Is this a collapsible storage bin set? | Answer: Yes
# Processed 310/1000 products
# Processed: Item_ID: B07X48PKPZ | Image_ID: 51X9Q9BKPQL | Question: What is the color of the file folders? | Answer: Manila
# Error processing row 3343: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ff/ff0d87b7.jpg'
# Processed: Item_ID: B07X5Y9C6N | Image_ID: 7159VJbGpEL | Question: What is the color of the labels? | Answer: White
# Processed: Item_ID: B07X6XJCHX | Image_ID: 61FGoJerWCL | Question: What is the color of the labels? | Answer: White
# Processed: Item_ID: B07X7PNH8C | Image_ID: 61tGqxyCkML | Question: How many hooks are included in this set? | Answer: Three
# Error processing row 3347: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/ebb693af.jpg'
# Processed: Item_ID: B07X9ZQ3BD | Image_ID: 91p6LbThDUL | Question: What is the number of compartments in this sling bag? | Answer: One
# Processed: Item_ID: B07XB1GMS8 | Image_ID: 81AcwU0s6IL | Question: What is the heel type? | Answer: Flats
# Processed: Item_ID: B07XB1GQNT | Image_ID: 71uFunwaVQL | Question: What is the heel type? | Answer: Flats
# Processed: Item_ID: B07XBR6CN5 | Image_ID: 81gPYjOdUrL | Question: What is the closure type of the Klepe men's running shoes? | Answer: SlipOn
# Processed: Item_ID: B07XC1DW5P | Image_ID: 71NGvQ-xKlL | Question: What is the color of the Flavia women's slippers? | Answer: Pink
# Processed: Item_ID: B07XC1GYFR | Image_ID: 81W+Cebm7oL | Question: What is the closure type of the Flavia sandals? | Answer: SlipOn
# Processed 320/1000 products
# Processed: Item_ID: B07XC3WK3N | Image_ID: 817n-JZVVSL | Question: What is the material of this plant stand? | Answer: Metal
# Processed: Item_ID: B07XCDYJTG | Image_ID: 91jkqShfq0L | Question: What is the color of the chairs? | Answer: Tan
# Processed: Item_ID: B07XCLXY3G | Image_ID: 61uEsM84wML | Question: What is the material of this utensil holder? | Answer: Metal
# Processed: Item_ID: B07XCVN37Y | Image_ID: 71KfODD6-TL | Question: What is the color of the laundry hamper? | Answer: Grey
# Processed: Item_ID: B07XDQN6MC | Image_ID: 91n2skSxLPL | Question: Is the clock included? | Answer: Yes
# Processed: Item_ID: B07XDQWFMX | Image_ID: 81xc-Ld2wVL | Question: What is the color of the sconce? | Answer: Black
# Processed: Item_ID: B07XDR82G2 | Image_ID: 61FZm26oJRL | Question: What is the color of the binder clips? | Answer: Black
# Processed: Item_ID: B07XDZ8X8G | Image_ID: 71dri1elBUL | Question: What is the closure type of this wallet? | Answer: Snap
# Processed: Item_ID: B07XF79NHS | Image_ID: 71U5XXiWsPL | Question: What is the heel type? | Answer: Flats
# Processed: Item_ID: B07XFLQLMH | Image_ID: 81OHKep0-3L | Question: What is the closure type of the Klepe Men's Navy Flyknit Running Shoes? | Answer: SlipOn
# Processed 330/1000 products
# Processed: Item_ID: B07XG438V3 | Image_ID: 81eBEMWPb9L | Question: What is the handbag's material? | Answer: Leather
# Processed: Item_ID: B07XGW4G72 | Image_ID: 71YIVS7hNCL | Question: What is the color of the loafers? | Answer: Black
# Processed: Item_ID: B07XH3RHS7 | Image_ID: 71Nyr1qzqoL | Question: What is the heel type? | Answer: Flats
# Processed: Item_ID: B07XHV2Z57 | Image_ID: 91bpVlYz3VL | Question: What is the color of the extension cord? | Answer: Green
# Error processing row 3368: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f44bac4f.jpg'
# Processed: Item_ID: B07XJRZXG5 | Image_ID: 81C7eL6kD1L | Question: Is this a renewed product? | Answer: Yes
# Processed: Item_ID: B07XJZBHCH | Image_ID: 617rc07tWSL | Question: What color are these shoes? | Answer: Silver
# Processed: Item_ID: B07XL31NP6 | Image_ID: 71B2u3vJ2wL | Question: What is the shoe's color? | Answer: Gold
# Processed: Item_ID: B07XL35L8B | Image_ID: 51-W6IKbrfL | Question: What is the product's type? | Answer: Cleaner
# Processed: Item_ID: B07XL39SF7 | Image_ID: 61g-rlWYK8L | Question: What is the scent of this air freshener? | Answer: Lavender
# Processed: Item_ID: B07XL3BNK8 | Image_ID: 51YGqT7CzqL | Question: What is the scent of this odor eliminator? | Answer: White_Tea
# Processed 340/1000 products
# Processed: Item_ID: B07XL3C6FR | Image_ID: 51-W6IKbrfL | Question: What is the size of this enzyme cleaner container? | Answer: Gallon
# Error processing row 3376: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f9f7cc94.jpg'
# Processed: Item_ID: B07XLSXMS4 | Image_ID: 71TFka5cjqL | Question: What is the color of the AmazonBasics TV mount? | Answer: Schwarz
# Processed: Item_ID: B07XM64NZK | Image_ID: 614J30R-R6L | Question: What material is the OnePlus 5T phone case made of? | Answer: Plastic
# Error processing row 3379: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07XPH5T9F | Image_ID: 818Ic1jgswL | Question: What is the color of the boots? | Answer: Brown
# Processed: Item_ID: B07XQNS1WB | Image_ID: 816e0SpnoqL | Question: What is the shoe's toe shape? | Answer: Round
# Processed: Item_ID: B07XR2517T | Image_ID: 613hFElstdL | Question: What style of boot is this? | Answer: Chelsea
# Processed: Item_ID: B07XRGCLYV | Image_ID: 71+zokS4gjL | Question: What is the closure type of these sneakers? | Answer: Lace-Up
# Processed: Item_ID: B07XRPS59H | Image_ID: 713b7HDccSL | Question: How many packets of oatmeal are included? | Answer: Twenty
# Processed: Item_ID: B07XRYX21K | Image_ID: 81jHVfIWPQL | Question: What is the color of the shoe's upper? | Answer: Black
# Processed: Item_ID: B07XRYXY9Q | Image_ID: 81PLJVGmhYL | Question: What is the closure type of these shoes? | Answer: SlipOn
# Error processing row 3387: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fbfc09b0.jpg'
# Processed 350/1000 products
# Processed: Item_ID: B07XRZD1BG | Image_ID: 618gA2kidqL | Question: What is the heel type? | Answer: Flats
# Processed: Item_ID: B07XS35KS4 | Image_ID: 61zD5m2LfdL | Question: What is the cable's length in feet? | Answer: 3
# Processed: Item_ID: B07XS5M5VW | Image_ID: 51cZso-JgqL | Question: What is the cable's color? | Answer: Black
# Processed: Item_ID: B07XT19LYD | Image_ID: 61sAc25G8JL | Question: Is the bulb dimmable? | Answer: Yes
# Processed: Item_ID: B07XTPNWG6 | Image_ID: 91GR72JIRZL | Question: What is the color of the mat? | Answer: Negro
# Processed: Item_ID: B07XTZNCBZ | Image_ID: 714SVZVncYL | Question: What is the closure type of the Fusefit Aura running shoes? | Answer: Lace-Up
# Processed: Item_ID: B07XTZNJMG | Image_ID: 81DBwhKgEHL | Question: What is the closure type of the Fusefit Ray running shoes? | Answer: SlipOn
# Error processing row 3395: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f5954695.jpg'
# Processed: Item_ID: B07XW1TNXZ | Image_ID: 81GhOkcAuVL | Question: What is the weight of the potatoes? | Answer: Five
# Error processing row 3397: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f4d02f2e.jpg'
# Processed: Item_ID: B07XY4FMVZ | Image_ID: 61u20f-PtzL | Question: Is this case compatible with the Xiaomi Redmi Y3? | Answer: Yes
# Processed: Item_ID: B07XY5YT7G | Image_ID: 61cexFvhDFL | Question: What material is this phone case made of? | Answer: Plastic
# Processed 360/1000 products
# ...
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Error processing row 3847: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Error processing row 3848: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Error processing row 3849: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Error processing row 3850: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Error processing row 3851: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Error processing row 3852: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# Error processing row 3853: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Error processing row 3854: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
# Error processing row 3855: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Error processing row 3856: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Error processing row 3857: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Error processing row 3858: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Error processing row 3859: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Error processing row 3860: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# Error processing row 3861: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Error processing row 3862: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error processing row 3863: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Error processing row 3864: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Error processing row 3865: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb9c421e.jpg'
# Error processing row 3866: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error processing row 3867: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 69
#      67 with open(json_file, "r", encoding="utf-8") as f:
#      68     for line in f:
# ---> 69         doc = json.loads(line)
#      70         if doc.get("item_id") == item_id:
#      71             metadata = doc
#
# File ~/miniconda3/envs/research1/lib/python3.13/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniconda3/envs/research1/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File ~/miniconda3/envs/research1/lib/python3.13/json/decoder.py:361, in JSONDecoder.raw_decode(self, s, idx)
#     352 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     353 a JSON document) and return a 2-tuple of the Python
#     354 representation and the index in ``s`` where the document ended.
#    (...)    358
#     359 """
#     360 try:
# --> 361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
#     363     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
""" API Keys """
key_1 = "AIzaSyDRYg1bgxG-Yv77yqV5RmJuRFAsplOyLg0"
key_2 = "AIzaSyCk-3tjAx3U33d0hdXiYmKP-7m0_kHOFqk"
key_3 = "AIzaSyC8YBijcN_xFfST2Y4KB3YVR7DNnI-FFz8"

# %%
""" API call with refined instruction prompt and filtered json metadata """

import time
import json
import os
import glob
import pandas as pd
from PIL import Image
import google.generativeai as genai

# Set your Gemini API key
api_key = "AIzaSyCk-3tjAx3U33d0hdXiYmKP-7m0_kHOFqk"
genai.configure(api_key=api_key)

# Define the starting index (can be changed before running)
start_index = 2500  # Change this value to continue from where you left off

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Filter to get one image per product, preferring "main" role
unique_products_df = pd.DataFrame()

# Group by item_id
grouped = merged_df.groupby("item_id")

# For each product, get the "main" image or the first one if no main exists
for item_id, group in grouped:
    main_images = group[group["role"] == "main"]
    if len(main_images) > 0:
        # Take the first main image
        unique_products_df = pd.concat([unique_products_df, main_images.iloc[[0]]])
    else:
        # If no main image, take the first image
        unique_products_df = pd.concat([unique_products_df, group.iloc[[0]]])

# Reset index
unique_products_df = unique_products_df.reset_index(drop=True)

# Initialize model
model = genai.GenerativeModel("gemini-1.5-flash")

# Create counter for progress tracking
total_products = len(unique_products_df)
processed_count = 0
error_count = 0
max_api_calls = 500  # Limit to 1000 API calls

print(f"Found {total_products} unique products")
print(f"Starting processing from index {start_index} up to {max_api_calls} products...")

# Process each row in the filtered DataFrame, starting from the specified index
for index, row in unique_products_df.iloc[start_index:].iterrows():
    # Check if we've reached the API call limit
    if processed_count + error_count >= max_api_calls:
        print(f"\nReached limit of {max_api_calls} API calls.")
        print(f"Stopped at index {index}, Item_ID: {row['item_id']}")
        print(f"To continue processing, set start_index = {index}")
        break
        
    try:
        # Extract image information
        image_id = row["image_id"]
        image_dir = "Datasets/small"
        image_path = os.path.join(image_dir, row["path"])
        item_id = row["item_id"]
        
        # Load the image
        image = Image.open(image_path)
        
        # Search all JSON files for metadata of the item_id
        metadata = None
        for json_file in glob.glob("Datasets/listings_*.json"):
            with open(json_file, "r", encoding="utf-8") as f:
                for line in f:
                    doc = json.loads(line)
                    if doc.get("item_id") == item_id:
                        metadata = doc
                        break
            if metadata:
                break
        
        if metadata is None:
            print(f"Warning: Metadata for item_id {item_id} not found. Skipping.")
            error_count += 1
            continue
        
        # Filter metadata to include only specified fields
        filtered_metadata = {}
        for field in ["product_type", "style", "item_keywords", "bullet_point", "color"]:
            if field in metadata:
                filtered_metadata[field] = metadata[field]
        
        # Prepare prompt for customer question and service rep answer generation
        prompt = f"""Based on the provided product image and metadata, the objective is to generate:
1. A specific question that a customer might ask about this product that can be answered with a single word
2. A concise, professional single-word answer that a customer service representative would give

The question should be realistic - something a typical online shopper might ask about this specific product.
The answer should be professional, helpful, and accurate based on the product details.

Format your response exactly like this:
Question: [your customer question here]
Answer: [single word answer from customer service]

Metadata: {json.dumps(filtered_metadata, indent=2)}"""
        
        # Gemini API call
        response = model.generate_content(
            [prompt, image],
            stream=False
        )
        
        # Extract question and answer
        response_text = response.text
        question = None
        answer = None
        
        for line in response_text.split("\n"):
            if line.startswith("Question:"):
                question = line[len("Question:"):].strip()
            elif line.startswith("Answer:"):
                answer = line[len("Answer:"):].strip()
        
        if question and answer:
            # Create a dictionary with the data to save
            data = {
                'Image_ID': [image_id],
                'Item_ID': [item_id],
                'Question': [question],
                'Answer': [answer]
            }
            
            # Convert to DataFrame
            df = pd.DataFrame(data)
            
            # Check if file exists
            file_exists = os.path.isfile('qna.csv')
            
            # Save to CSV (append if file exists, create with header if it doesn't)
            if file_exists:
                df.to_csv('qna2.csv', mode='a', header=False, index=False)
            else:
                df.to_csv('qna2.csv', index=False)
        
        # Update progress
        processed_count += 1
        if processed_count % 10 == 0:
            print(f"Processed {processed_count}/{max_api_calls} products")
        
        # Short summary of the current item
        print(f"Processed: Item_ID: {item_id} | Image_ID: {image_id}")
        print(f"Q: {question}")
        print(f"A: {answer}")
        print("-" * 50)
        
        # Pause between API calls to avoid rate limits
        time.sleep(1.0)  # 1 second pause between calls
        
    except Exception as e:
        error_count += 1
        print(f"Error processing row {index}: {str(e)}")
        # Continue with the next image even if there's an error
        continue

print(f"\nProcessing complete!")
print(f"Total products processed: {processed_count}")
print(f"Errors: {error_count}")
print(f"Results saved to qna2.csv")
print(f"Next start_index to continue: {start_index + processed_count + error_count}")
# Out:
# Found 4923 unique products
# Starting processing from index 2500 up to 500 products...
# Error processing row 2500: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TCWSQTQ | Image_ID: 81vp+RIx+SL
# Q: Is this case compatible with the LG Stylus 2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWSTTP | Image_ID: 61EMcRL3paL
# Q: Is this case compatible with the Samsung Galaxy J4 Core?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWSWP1 | Image_ID: 81MPdjCfBKL
# Q: Is this case compatible with the Samsung Galaxy C7 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWSWYN | Image_ID: 71L4ynn0A1L
# Q: Is this case compatible with the Samsung Galaxy J6 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWSXHQ | Image_ID: 817-R3GwBJL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TCWSXJY | Image_ID: 81vXyCXENeL
# Q: Is this case slim?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWSXWC | Image_ID: 81tzHYdSOgL
# Q: Is this case compatible with the LG Stylus 2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWSXXG | Image_ID: 71njGvFQynL
# Q: Is this case compatible with a Vivo V9 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWT1KJ | Image_ID: 71JlVgo9rzL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2510: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 10/500 products
# Processed: Item_ID: B07TCWT1X3 | Image_ID: 71ohtnlbkTL
# Q: Is this case compatible with the Redmi 3S Prime?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWT1Y6 | Image_ID: 71plpl9dzRL
# Q: Is this case compatible with the Asus Zenfone Max Pro M1 ZB601KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWT4PH | Image_ID: 811b5djIdsL
# Q: Is this case compatible with the Vivo Y95?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWT54L | Image_ID: 7152xYjDNlL
# Q: Is this case compatible with a Huawei P9 Lite?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWT6FZ | Image_ID: 715kVcWtzYL
# Q: Is this case compatible with the Asus Zenfone Max M1 ZB555KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWT6H9 | Image_ID: 71TnWcTycHL
# Q: Is this case compatible with the Motorola One Power?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWTGPN | Image_ID: 71mbzOf+pNL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TCWTHBK | Image_ID: 716K4NRkrTL
# Q: Is this case compatible with a Vivo Y95?
# A: Yes
# --------------------------------------------------
# Error processing row 2519: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TCWTQRR | Image_ID: 71JmgQxtr-L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TCWTRDK | Image_ID: 71-FpiDjIML
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 20/500 products
# Processed: Item_ID: B07TCWTRDR | Image_ID: 71mJ-6BpmSL
# Q: Is this case slim?
# A: Yes
# --------------------------------------------------
# Error processing row 2523: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f8350330.jpg'
# Processed: Item_ID: B07TCWTZ7Y | Image_ID: 81K6C7JX7kL
# Q: Is this case compatible with the Vivo V7 Plus?
# A: Yes
# --------------------------------------------------
# Error processing row 2525: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2526: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/ed504900.jpg'
# Error processing row 2527: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/ed2e392b.jpg'
# Processed: Item_ID: B07TCWV4XC | Image_ID: 81y5WVjCu1L
# Q: Is this case compatible with the Huawei P9 Lite?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWVJ6G | Image_ID: 61Xce1Hq7DL
# Q: Is this case compatible with the Gionee Elife S7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TCWX5Z6 | Image_ID: 71o4jXiKD3L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TD3QGLZ | Image_ID: 71Mp5v67qnL
# Q: Is this case compatible with Oppo F1s?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TD95DG1 | Image_ID: 71tYSXnEJzL
# Q: Is this case compatible with the Vivo V1 Max?
# A: Yes
# --------------------------------------------------
# Error processing row 2533: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TD95DK9 | Image_ID: 713JAUHSTTL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TD95DT7 | Image_ID: 81dldClk6QL
# Q: Is this case compatible with the Honor 5c?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TD993M6 | Image_ID: 81T2fCEe3uL
# Q: Is this case compatible with Micromax Canvas Nitro 4G E455?
# A: Yes
# --------------------------------------------------
# Error processing row 2537: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 30/500 products
# Processed: Item_ID: B07TD9KW6X | Image_ID: 71sSrh5BL4L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2539: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f2/f2d756da.jpg'
# Processed: Item_ID: B07TDKY2JG | Image_ID: 71vrBlmsxEL
# Q: What is the shoe's closure type?
# A: Lace-Up
# --------------------------------------------------
# Processed: Item_ID: B07TDTH48L | Image_ID: 81qlvKMvhLL
# Q: Are these gloves reusable?
# A: Yes
# --------------------------------------------------
# Error processing row 2542: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f4aff67b.jpg'
# Processed: Item_ID: B07TF19NHR | Image_ID: 61IgjPrKKFL
# Q: Is this case compatible with Samsung Z3?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF19QF6 | Image_ID: 71yO59ltZwL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF19QHB | Image_ID: 71yU02KpBbL
# Q: Is this case compatible with the LG V20?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF19TDT | Image_ID: 71A44JL7N1L
# Q: Is this case compatible with Lenovo A7700?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1B6WJ | Image_ID: 717ukQnVjNL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1B9CC | Image_ID: 81yJh7ucUUL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2549: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f4197cca.jpg'
# Error processing row 2550: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1BJBD | Image_ID: 81KcfQwIw9L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 40/500 products
# Processed: Item_ID: B07TF1BJJC | Image_ID: 716m8rAHE9L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1BJJT | Image_ID: 71tAoFUEihL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1BJLC | Image_ID: 61YjHVo-HCL
# Q: Is this case compatible with Samsung Galaxy J2 Prime?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1BJS5 | Image_ID: 71TyHW1l9ML
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2556: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1BKPL | Image_ID: 613ab9Ga+8L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1BRMZ | Image_ID: 81NU3RXufPL
# Q: Is this case compatible with the LG Stylus 2?
# A: Yes
# --------------------------------------------------
# Error processing row 2559: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f3/f3cc652b.jpg'
# Processed: Item_ID: B07TF1BZJ9 | Image_ID: 71e5zDRR+xL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1C2F9 | Image_ID: 71-4kywwfaL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1C2T7 | Image_ID: 81uZlkwwDpL
# Q: Is this case compatible with the Vivo Y55L?
# A: Yes
# --------------------------------------------------
# Error processing row 2563: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1C6VW | Image_ID: 61V6VSPVOZL
# Q: Is this case compatible with a Samsung Galaxy Note 4?
# A: Yes
# --------------------------------------------------
# Processed 50/500 products
# Processed: Item_ID: B07TF1C71G | Image_ID: 81afOIh7djL
# Q: Is this case compatible with the Vivo Y55L?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1C7MD | Image_ID: 711fcxG26EL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1C7RB | Image_ID: 71a3UttH7RL
# Q: Is this case compatible with the Vivo Y55L?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CCL4 | Image_ID: 71dU71uJ4LL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1CCQ5 | Image_ID: 811DNipf8ZL
# Q: Is this case compatible with a Vivo V3 Max?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CCZ5 | Image_ID: 71idapSZQ4L
# Q: Is this case compatible with InFocus M2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CCZJ | Image_ID: 819VOVnYtRL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1CDKX | Image_ID: 61NUqO6hQGL
# Q: Is this case compatible with a Vivo Y31?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CFQD | Image_ID: 81LOHeeGp3L
# Q: Is this case compatible with a Vivo V3 Max?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CFRW | Image_ID: 71ZHk6tSHAL
# Q: Is this case compatible with the Vivo V3 Max?
# A: Yes
# --------------------------------------------------
# Error processing row 2575: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 60/500 products
# Processed: Item_ID: B07TF1CFYY | Image_ID: 71SC71KVYdL
# Q: Is this case compatible with Samsung Galaxy S2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CPSJ | Image_ID: 710GECp17GL
# Q: Is this case compatible with the InFocus M2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1CPX6 | Image_ID: 61fznbcFb-L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1CXT2 | Image_ID: 818msT05BwL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1CY7R | Image_ID: 71v4MUb84rL
# Q: Is this case compatible with the Nokia 5?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1D1WK | Image_ID: 81brqzYtMML
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1D1XH | Image_ID: 81EV3sYIXrL
# Q: Is this case compatible with Samsung Galaxy S8 Plus?
# A: Yes
# --------------------------------------------------
# Error processing row 2583: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2584: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1D2JK | Image_ID: 71QsniJHcIL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2586: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2587: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1D8TL | Image_ID: 81R7ZZee8uL
# Q: Is this case compatible with the Gionee Marathon M5 lite?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1D8XD | Image_ID: 71I3NW5PTzL
# Q: Is this case compatible with an iPhone 7 Plus?
# A: Yes
# --------------------------------------------------
# Processed 70/500 products
# Processed: Item_ID: B07TF1D96K | Image_ID: 81FF86bZKEL
# Q: Is this case compatible with the Vivo Y66?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1D9B5 | Image_ID: 71Y1LUDWCRL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2592: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1DF35 | Image_ID: 81AvMnekYeL
# Q: Is this case compatible with the Samsung Galaxy S8 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1DF5J | Image_ID: 71c5z9x15CL
# Q: Is this case compatible with iPhone 7 Plus?
# A: Yes
# --------------------------------------------------
# Error processing row 2595: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1DFN4 | Image_ID: 71rSGtzrIrL
# Q: Is this case compatible with the Vivo Y27L?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1DFQG | Image_ID: 819Q2ZsjBSL
# Q: Is this case compatible with Samsung Galaxy J7 Duo?
# A: Yes
# --------------------------------------------------
# Error processing row 2598: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee27b589.jpg'
# Error processing row 2599: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ef/ef0cd032.jpg'
# Processed: Item_ID: B07TF1DMWQ | Image_ID: 81JQEndIs6L
# Q: Is this case hard?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1DN49 | Image_ID: 612W7cew27L
# Q: Is this case compatible with the Sony Xperia L2?
# A: Yes
# --------------------------------------------------
# Error processing row 2602: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2603: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f1/f1cc2d89.jpg'
# Processed: Item_ID: B07TF1DW38 | Image_ID: 81vAQzCgYcL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2605: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2606: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1DZ3F | Image_ID: 716SW1a7Y0L
# Q: Is this case compatible with a Gionee A1 Lite?
# A: Yes
# --------------------------------------------------
# Processed 80/500 products
# Processed: Item_ID: B07TF1DZ93 | Image_ID: 71qRbaefIHL
# Q: Is this case compatible with the Vivo Y21L?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1DZJ1 | Image_ID: 71YlRCDQHUL
# Q: Is this case compatible with an iPhone XS Max?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F1V4 | Image_ID: 81lZ25MUixL
# Q: Is this case slim?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F1V9 | Image_ID: 71g86SXceCL
# Q: Is this case compatible with Samsung Galaxy J7 Duo?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F1WC | Image_ID: 71Ll2kGC6xL
# Q: Is this case compatible with the Gionee A1 Lite?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F1Z4 | Image_ID: 81lciL8Q8-L
# Q: Is this case compatible with the Vivo Y21L?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F22V | Image_ID: 718Bsib1LfL
# Q: Is this case compatible with the Samsung Galaxy J2 Core?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F23D | Image_ID: 61pTG-42sdL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1F2C9 | Image_ID: 71imqE39E2L
# Q: Is this case compatible with a Samsung Galaxy J4 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F2CK | Image_ID: 81p7FTwD7tL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 90/500 products
# Processed: Item_ID: B07TF1F2HH | Image_ID: 71E9SxUTXBL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1F2Q6 | Image_ID: 81VC7K2sP7L
# Q: Is this case compatible with the Vivo Y53?
# A: Yes
# --------------------------------------------------
# Error processing row 2620: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f744f62a.jpg'
# Processed: Item_ID: B07TF1F2YG | Image_ID: 710mtzt0AqL
# Q: Is this case compatible with the Motorola Moto G4 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F32Q | Image_ID: 71ePHMmOpUL
# Q: Is this case compatible with a Samsung Galaxy C7 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F35M | Image_ID: 811capfpsvL
# Q: Is this case compatible with a Samsung Galaxy J4 Plus?
# A: Yes
# --------------------------------------------------
# Error processing row 2624: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2625: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1F81Q | Image_ID: 71RIQlq2tfL
# Q: Is this case compatible with a Nokia 6.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F838 | Image_ID: 71VA5KNNIXL
# Q: Is this case compatible with the Nokia 6.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1F89Z | Image_ID: 71MabKcAncL
# Q: Is this case compatible with the Samsung Galaxy A9 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1FCHC | Image_ID: 71kEcpG8s8L
# Q: Is this case compatible with a Vivo V9 Pro?
# A: Yes
# --------------------------------------------------
# Error processing row 2630: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2631: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2632: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f2/f2af66cb.jpg'
# Error processing row 2633: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF1FFRZ | Image_ID: 71jhWIT0chL
# Q: Is this case compatible with Oppo A71?
# A: Yes
# --------------------------------------------------
# Processed 100/500 products
# Processed: Item_ID: B07TF1FFSQ | Image_ID: 81Zo4-v9uRL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2636: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe614237.jpg'
# Processed: Item_ID: B07TF1FK9N | Image_ID: 81j1b89wjfL
# Q: Is this case compatible with Nokia 6.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1FLS4 | Image_ID: 71eTemxugoL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1FNPR | Image_ID: 71GvJvUw9+L
# Q: Is this case compatible with Nokia 2.1?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1FVHK | Image_ID: 81yxfYnu4XL
# Q: Is this case compatible with the Asus Zenfone Max Pro M1 ZB601KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1G4K5 | Image_ID: 711ooitHddL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1G71K | Image_ID: 71BNMl8-IZL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1G743 | Image_ID: 71BhPLdtyPL
# Q: Is this case compatible with Nokia 6.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1GH99 | Image_ID: 71f-5PeSb8L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TF1GJT2 | Image_ID: 71BHlc5ULZL
# Q: Is this case compatible with a Lenovo P2?
# A: Yes
# --------------------------------------------------
# Error processing row 2646: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f43f9c03.jpg'
# Processed 110/500 products
# Processed: Item_ID: B07TF1HZ1R | Image_ID: 61Xce1Hq7DL
# Q: Is this case compatible with the Lenovo P2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF1HZCN | Image_ID: 71oiQGHY9UL
# Q: Is this case compatible with a Lenovo P2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TF7FYDT | Image_ID: 71-n69PfrwL
# Q: Is this case 3D printed?
# A: Yes
# --------------------------------------------------
# Error processing row 2650: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TF7PP88 | Image_ID: 81PATaeMsVL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2652: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/edaf82de.jpg'
# Processed: Item_ID: B07TFXSPRL | Image_ID: 91rBj+0DAmL
# Q: Are these gloves reusable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG1ZWP6 | Image_ID: 71ygwddlJLL
# Q: Is this case compatible with a Huawei Mate 9?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG1ZWPW | Image_ID: 71f18H4wD0L
# Q: Is this case compatible with the Lenovo A7700?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG2XB9Z | Image_ID: 815BOKF6HIL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG2XBMM | Image_ID: 71xH03b41IL
# Q: Is this case hard?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG37QGN | Image_ID: 71kFydKuDyL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 120/500 products
# Processed: Item_ID: B07TG38HZG | Image_ID: 81zTjt5g3gL
# Q: Is this case compatible with Lenovo A6600?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG38J1Q | Image_ID: 61vz-jIUUsL
# Q: Is this case compatible with the Huawei Mate 9?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG38J3N | Image_ID: 61C9RvhgSZL
# Q: Is this case compatible with Micromax Canvas Selfie 2 Q340?
# A: Yes
# --------------------------------------------------
# Error processing row 2662: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG3B5Q7 | Image_ID: 71VzDm1Y+IL
# Q: Is this case compatible with the Vivo Y66?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3B5QY | Image_ID: 71uDMHfJL-L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3FL4Z | Image_ID: 61KDiuTgbPL
# Q: Is this case compatible with an iPhone 7?
# A: Yes
# --------------------------------------------------
# Error processing row 2666: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb5ff187.jpg'
# Error processing row 2667: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ef/efb2eada.jpg'
# Processed: Item_ID: B07TG3GVMQ | Image_ID: 71hVDBLKYYL
# Q: Is this case compatible with a Samsung Galaxy Note 4?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3HR25 | Image_ID: 7138FkeyezL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3HR6Q | Image_ID: 61q7X+hzGlL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3HRDD | Image_ID: 71j+OIOGmXL
# Q: Is this case compatible with a Lenovo A7700?
# A: Yes
# --------------------------------------------------
# Processed 130/500 products
# Processed: Item_ID: B07TG3HRDM | Image_ID: 81lrzysb80L
# Q: Is this case compatible with the Huawei Mate 9?
# A: Yes
# --------------------------------------------------
# Error processing row 2673: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG3J1WK | Image_ID: 81tYE8NdpML
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3J1YW | Image_ID: 71JzP8svbaL
# Q: Is this case 3D printed?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3J27G | Image_ID: 71333G1N5QL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3JKK6 | Image_ID: 61wsefOr0hL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2678: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2679: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG3KV51 | Image_ID: 71X7EBKBJoL
# Q: Is this case compatible with a Vivo Y95?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3KV61 | Image_ID: 71oR1SKWO3L
# Q: Is this case compatible with a Vivo Y95?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3KVJ6 | Image_ID: 71ZGQSNCCZL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3MZGG | Image_ID: 71HcH-myidL
# Q: Is this case compatible with Samsung Z2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3MZWZ | Image_ID: 71FmP8ozfGL
# Q: Is this case compatible with the Samsung Galaxy J3 Pro?
# A: Yes
# --------------------------------------------------
# Error processing row 2685: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 140/500 products
# Processed: Item_ID: B07TG3N1PC | Image_ID: 81-cUSBwdwL
# Q: Is this case compatible with the Motorola Moto G4 Play?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3N1RW | Image_ID: 71wrwzHp5CL
# Q: Is this case compatible with the InFocus M350?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3NVYW | Image_ID: 71zyk0+rjEL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3NWDS | Image_ID: 71PM1M+XBXL
# Q: Is this case compatible with a Vivo V3 Max?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3NWJ1 | Image_ID: 71BKl3izgxL
# Q: Is this case compatible with a Samsung Galaxy Note 4?
# A: Yes
# --------------------------------------------------
# Error processing row 2691: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG3QYSK | Image_ID: 71hvpxfv3GL
# Q: Is this case compatible with the Asus Zenfone 3 Laser ZC551KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3QZ9W | Image_ID: 61ZRR1v9HNL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3R5G5 | Image_ID: 81sZplikWHL
# Q: Is this case compatible with the Motorola Moto G4 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3R5GF | Image_ID: 61AOuuav0bL
# Q: Is this case compatible with the Asus Zenfone 3S Max?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3R5J8 | Image_ID: 81iVlLZXNYL
# Q: Is this case compatible with the Samsung Galaxy J7 Duo?
# A: Yes
# --------------------------------------------------
# Error processing row 2697: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f97880ec.jpg'
# Error processing row 2698: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 150/500 products
# Processed: Item_ID: B07TG3RCMS | Image_ID: 71sW6qIh5CL
# Q: Is this case compatible with the Samsung Galaxy C9 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3TF5V | Image_ID: 71AlkJ+KvYL
# Q: Is this case compatible with the Lenovo P2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3TVBW | Image_ID: 71b6VPIJxyL
# Q: Is this case compatible with the Asus Zenfone 3 Laser ZC551KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3TVK7 | Image_ID: 81xvt8HC77L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG3TVVD | Image_ID: 71i46FlGZgL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2704: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f445edc2.jpg'
# Processed: Item_ID: B07TG3Y2FX | Image_ID: 71aJlLC3TgL
# Q: Is this case compatible with Lenovo K6 Note?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG3Z995 | Image_ID: 71eu9gQVvvL
# Q: Is this case compatible with a Vivo Y31?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG411D8 | Image_ID: 81KdMj8EoKL
# Q: Is this case compatible with Samsung Galaxy J5 Prime?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG411T7 | Image_ID: 71+TQNSYZEL
# Q: Is this case compatible with the Samsung Galaxy J3 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG41L9Q | Image_ID: 61c0XKYYkJL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 160/500 products
# Processed: Item_ID: B07TG41LFR | Image_ID: 71pvlHd1eDL
# Q: Is this case compatible with the Samsung Z3?
# A: Yes
# --------------------------------------------------
# Error processing row 2711: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG425HR | Image_ID: 71qSBeLxviL
# Q: Is this case compatible with the Vivo V7 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG425J3 | Image_ID: 81I7Ww3M5PL
# Q: Is this case compatible with the Huawei P9 lite?
# A: Yes
# --------------------------------------------------
# Error processing row 2714: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/eec5b349.jpg'
# Processed: Item_ID: B07TG42WVY | Image_ID: 81zTd3PUz3L
# Q: Is this case compatible with a Gionee Marathon M5 Plus?
# A: Yes
# --------------------------------------------------
# Error processing row 2716: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG44Q4F | Image_ID: 819wkAIdaAL
# Q: Is this case compatible with a Gionee Marathon M5 lite?
# A: Yes
# --------------------------------------------------
# Error processing row 2718: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f6f7d883.jpg'
# Processed: Item_ID: B07TG44QFZ | Image_ID: 71Or4SoU1tL
# Q: Is this case compatible with iPhone X?
# A: Yes
# --------------------------------------------------
# Error processing row 2720: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG44QNN | Image_ID: 71w2WvTIl8L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG45SSN | Image_ID: 71V4-JALSSL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG45T6V | Image_ID: 81at44pI3zL
# Q: Is this case compatible with the Lenovo Vibe X3?
# A: Yes
# --------------------------------------------------
# Error processing row 2724: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2725: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fed00df9.jpg'
# Processed: Item_ID: B07TG46J2X | Image_ID: 71La8AEdOtL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 170/500 products
# Processed: Item_ID: B07TG47RXW | Image_ID: 61+fsAmOTKL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG47SJ2 | Image_ID: 614YwjjXPzL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG49CFR | Image_ID: 81ccsWqXUIL
# Q: Is this case slim?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG49CFZ | Image_ID: 61gRWU0J7KL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG49CH3 | Image_ID: 71gzQ5EpToL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG49D4R | Image_ID: 81jLtuNmAaL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG49HWP | Image_ID: 71dougsPY0L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4B6FS | Image_ID: 71H6V74zANL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2735: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4BHZB | Image_ID: 71JTpgYE6-L
# Q: Is this case compatible with Motorola Moto E4?
# A: Yes
# --------------------------------------------------
# Error processing row 2737: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f841a4dd.jpg'
# Processed: Item_ID: B07TG4C6L5 | Image_ID: 71L9K9b1fML
# Q: Is this case 3D printed?
# A: Yes
# --------------------------------------------------
# Processed 180/500 products
# Processed: Item_ID: B07TG4C6ZW | Image_ID: 81bnJJog7AL
# Q: Is this case compatible with the Motorola Moto Z Play?
# A: Yes
# --------------------------------------------------
# Error processing row 2740: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/eeb995cb.jpg'
# Error processing row 2741: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4CTK9 | Image_ID: 81-hbo24rBL
# Q: Is this case 3D printed?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4CYDN | Image_ID: 71lZvnmtb3L
# Q: Is this case compatible with a Samsung Galaxy S8 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4CYFB | Image_ID: 71Yke0yX9mL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4CYLD | Image_ID: 71E-rZC4cDL
# Q: Is this case compatible with the Oppo F1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4CYNZ | Image_ID: 81f4J+f5ziL
# Q: Is this case compatible with the LG K10 (2017)?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4CYR8 | Image_ID: 71b7eXZueXL
# Q: Is this case compatible with iPhone 7 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4CYSH | Image_ID: 71pXoV2Bq1L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2749: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4FD74 | Image_ID: 81rM24Ue6qL
# Q: Is this case compatible with Samsung Z3?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4FD8K | Image_ID: 81VAKhXjCyL
# Q: Is this case compatible with Samsung Z3?
# A: Yes
# --------------------------------------------------
# Processed 190/500 products
# Processed: Item_ID: B07TG4FD9N | Image_ID: 71yhzX3mzTL
# Q: Is this case compatible with the Gionee Marathon M5 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4FDGJ | Image_ID: 71EFf2clHIL
# Q: Is this case compatible with the Asus Zenfone 3 Laser ZC551KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4FJ3S | Image_ID: 71gQz5hLbBL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2755: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2756: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb869b72.jpg'
# Processed: Item_ID: B07TG4FY62 | Image_ID: 71nt+8Kh4dL
# Q: Is this case compatible with a Lenovo A6600?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4FZ7Y | Image_ID: 71zBCD3GxlL
# Q: Is this case compatible with the Vivo Y31?
# A: Yes
# --------------------------------------------------
# Error processing row 2759: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4G462 | Image_ID: 81HaQ2a6U+L
# Q: Is this case compatible with the Samsung Z2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4GHY6 | Image_ID: 71aA6SN9yUL
# Q: Is this case compatible with the Lenovo A6600?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4GJ2D | Image_ID: 71mL6U-9gdL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4J1CD | Image_ID: 81dHnjG9-qL
# Q: Is this case compatible with the Vivo V5 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4J5JF | Image_ID: 71SXln0xUhL
# Q: Is this case compatible with a Samsung Galaxy J2 Prime?
# A: Yes
# --------------------------------------------------
# Error processing row 2765: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 200/500 products
# Processed: Item_ID: B07TG4J8F6 | Image_ID: 71iJndoux9L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4J8K2 | Image_ID: 71Hl0uHz6HL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2768: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4K25N | Image_ID: 81dyGciEwKL
# Q: Is this case compatible with iPhone 7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4K2H6 | Image_ID: 71Iy1eCkadL
# Q: Is this case compatible with the Asus Zenfone 3 Max ZC553KL?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4K2H8 | Image_ID: 81Zn0jl4aFL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4K2HL | Image_ID: 71vSXZOPbAL
# Q: Is this case compatible with a Lenovo A6600?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4KGN7 | Image_ID: 71j+GntaggL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4KGNX | Image_ID: 71K2ayjp6eL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2775: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0ccb672.jpg'
# Error processing row 2776: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4KYTJ | Image_ID: 81HAG+rAVbL
# Q: Is this case compatible with the Gionee A1 Lite?
# A: Yes
# --------------------------------------------------
# Error processing row 2778: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4KYXX | Image_ID: 71B2KCmr5+L
# Q: Is this case compatible with a Samsung Galaxy J7 Duo?
# A: Yes
# --------------------------------------------------
# Processed 210/500 products
# Processed: Item_ID: B07TG4KYYJ | Image_ID: 61oJOkOCiIL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2781: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4KZ3P | Image_ID: 71fTqS1FpPL
# Q: Is this case compatible with the Motorola Moto G4 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4KZ66 | Image_ID: 71a51Im2KjL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2784: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f1/f1a49a04.jpg'
# Processed: Item_ID: B07TG4LCND | Image_ID: 71S82F4CRLL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2786: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4LWNS | Image_ID: 716g35vrMXL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4M5ZC | Image_ID: 71CBQVkLy0L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4M66G | Image_ID: 71RSqkn6bUL
# Q: Is this case compatible with Samsung Galaxy A6s?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4M9N6 | Image_ID: 81DigKJQYNL
# Q: Is this case compatible with the Motorola Moto Z Play?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4M9W1 | Image_ID: 810W2Z6pD-L
# Q: Is this case compatible with Samsung Galaxy J3 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4MK7L | Image_ID: 71lBCEbYQSL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 220/500 products
# Processed: Item_ID: B07TG4MK8H | Image_ID: 71ssGqKZ8uL
# Q: Is this case compatible with the Vivo V3 Max?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4P73Q | Image_ID: 81xlGsnFiJL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2795: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4PDL9 | Image_ID: 71ZswohOKjL
# Q: Is this case compatible with a Samsung Galaxy A9 Pro?
# A: Yes
# --------------------------------------------------
# Error processing row 2797: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4PDSB | Image_ID: 71EHFwBLbuL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4QZ7B | Image_ID: 81G1p2doJsL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4QZ7C | Image_ID: 91iEZ40yDAL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4RFQ7 | Image_ID: 71stuf1SPjL
# Q: Is this case compatible with the Huawei G8?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4RXKZ | Image_ID: 81Hzx+NdxUL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4RXNN | Image_ID: 719ZF3J3XtL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4S6SC | Image_ID: 71JTmNBe3XL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2805: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed 230/500 products
# Processed: Item_ID: B07TG4SGYV | Image_ID: 71D9NZ+9DoL
# Q: Is this case compatible with the InFocus M2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4SJV8 | Image_ID: 71JGtMI4IaL
# Q: Is this case compatible with iPhone 7?
# A: Yes
# --------------------------------------------------
# Error processing row 2808: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f5833465.jpg'
# Error processing row 2809: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4SKZ9 | Image_ID: 71O0bAmFVaL
# Q: Is this case compatible with the Lenovo A6600?
# A: Yes
# --------------------------------------------------
# Error processing row 2811: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4SLRW | Image_ID: 81dIvtPhUtL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TG4SN2L | Image_ID: 71WhvfOTb8L
# Q: Is this case compatible with iPhone 7?
# A: Yes
# --------------------------------------------------
# ...
# Processed: Item_ID: B07TG4XKGG | Image_ID: 71JPiQ7PeOL
# Q: Is this case compatible with the Samsung Galaxy A9 Pro?
# A: Yes
# --------------------------------------------------
# Error processing row 2898: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4XXKZ | Image_ID: 71573VAnEGL
# Q: Is this case compatible with the Vivo V7 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4XXLN | Image_ID: 81emTGXQjHL
# Q: Is this case compatible with the Vivo V7 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TG4Y71H | Image_ID: 71lR85DGa9L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2902: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TG4Z4X7 | Image_ID: 71-3oXkjcHL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2904: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Error processing row 2905: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/febab309.jpg'
# Processed 310/500 products
# Processed: Item_ID: B07TGBRXW1 | Image_ID: 71gwvB0DBrL
# Q: Is this case easy to install?
# A: Yes
# --------------------------------------------------
# Error processing row 2907: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f3/f35325c0.jpg'
# Processed: Item_ID: B07TGZS6MZ | Image_ID: 81FmP4RTWnL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TGZS6S1 | Image_ID: 81O3BHfK43L
# Q: Is this case compatible with the Asus Zenfone 3 Laser ZC551KL?
# A: Yes
# --------------------------------------------------
# Error processing row 2910: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TGZWMYL | Image_ID: 61Iu6Qz8DQL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TGZWN5S | Image_ID: 71rVqLbVveL
# Q: Is this case compatible with a Redmi 3S?
# A: Yes
# --------------------------------------------------
# Error processing row 2913: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TGZY19W | Image_ID: 61FoglXsSQL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TGZY1FX | Image_ID: 71JLZilozYL
# Q: Is this case compatible with the Sony Xperia XZ Dual?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TGZZ73N | Image_ID: 71d1vG82uVL
# Q: Is this case compatible with the Nokia 5?
# A: Yes
# --------------------------------------------------
# Error processing row 2917: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH141SX | Image_ID: 71Xp-PgDMzL
# Q: Is this case hard?
# A: Yes
# --------------------------------------------------
# Error processing row 2919: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH1423R | Image_ID: 81TwwQQsHdL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed 320/500 products
# Processed: Item_ID: B07TH14261 | Image_ID: 71RkIEM9JGL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2922: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fb3f2ed1.jpg'
# Processed: Item_ID: B07TH142CW | Image_ID: 71+Vj769-2L
# Q: Is this case compatible with the iPhone XS Max?
# A: Yes
# --------------------------------------------------
# Error processing row 2924: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH15X2Q | Image_ID: 71nzz8VV+ML
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2926: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH1H6XJ | Image_ID: 71oVOTrI8bL
# Q: Is this case compatible with a Vivo Y95?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2422D | Image_ID: 71wMMU6kHQL
# Q: Is this case compatible with my Gionee Marathon M5 lite?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2QH8N | Image_ID: 71Moemd3i0L
# Q: Is this case compatible with a Samsung Galaxy J4 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2V4H8 | Image_ID: 81HaPJoP04L
# Q: Is this case compatible with Nokia 8.1?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2V4KV | Image_ID: 71MC5NEfw9L
# Q: Is this case compatible with a Vivo Y95?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2V4RX | Image_ID: 718TN27EvuL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2WD7Z | Image_ID: 71GfbhiZ0FL
# Q: Is this case compatible with the LG V20?
# A: Yes
# --------------------------------------------------
# Processed 330/500 products
# Processed: Item_ID: B07TH2XMZR | Image_ID: 71nYhMQk+BL
# Q: Is this case compatible with Oppo A7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2XMZS | Image_ID: 81dR3nuZ-1L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2XN33 | Image_ID: 717R1wjleyL
# Q: Is this case compatible with the Vivo V7 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2XN78 | Image_ID: 71NmCWOZ9tL
# Q: Is this case easy to install?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2XN9J | Image_ID: 71b2n2DK47L
# Q: Is this case compatible with the Vivo Y69?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2Y7VB | Image_ID: 71udJOOWKCL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2Y7X1 | Image_ID: 71Xx72A8JFL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2Y858 | Image_ID: 71UCI21n7yL
# Q: Is this case compatible with the Vivo Y55L?
# A: Yes
# --------------------------------------------------
# Error processing row 2942: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH2YZBL | Image_ID: 61kZ43SFMWL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2944: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f73caacd.jpg'
# Processed: Item_ID: B07TH2YZYD | Image_ID: 71se2CplBNL
# Q: Is this case compatible with Lenovo P2?
# A: Yes
# --------------------------------------------------
# Processed 340/500 products
# Processed: Item_ID: B07TH2ZG5L | Image_ID: 61eoS0J49vL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2ZG68 | Image_ID: 71FSX2V5QrL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2ZGB9 | Image_ID: 815v2OXwqkL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH2ZGC1 | Image_ID: 71jnCZv9vRL
# Q: Is this case compatible with the Sony Xperia XZ Dual?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2ZWZC | Image_ID: 81+Pt4QJLaL
# Q: Is this case compatible with a Samsung Galaxy A9 Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2ZX13 | Image_ID: 71y1LFLCA9L
# Q: Is this case compatible with the Vivo Y95?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH2ZX5P | Image_ID: 615lzoulzWL
# Q: Is this case compatible with a Nokia 3.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH324Z7 | Image_ID: 812tcZBV0rL
# Q: Is this case compatible with the LG V20?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH325C9 | Image_ID: 71b2nob9HDL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH325JW | Image_ID: 71ZpD8jE0EL
# Q: Is this case compatible with a Huawei Mate 9?
# A: Yes
# --------------------------------------------------
# Processed 350/500 products
# Processed: Item_ID: B07TH325PT | Image_ID: 71ru00sh+LL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH329M8 | Image_ID: 71Fbs363s7L
# Q: Is this case compatible with the LG Stylus 2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32B2S | Image_ID: 71B2+r73MbL
# Q: Is this case compatible with a Redmi 3S Prime?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32B63 | Image_ID: 71dEqab3dsL
# Q: Is this case compatible with my Nokia 3.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32B79 | Image_ID: 61HPjkfCAbL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH32B7F | Image_ID: 71msBwPgt4L
# Q: Is this case compatible with Nokia 3.1?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32B9Y | Image_ID: 71PpRgMyZmL
# Q: Is this case compatible with Samsung Galaxy A3 (2017)?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07TH32BBK | Image_ID: 71NxDy1UElL
# Q: Is this case compatible with my Nokia 6.1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32VXY | Image_ID: 71WAYK1m1hL
# Q: Is this case compatible with the Oppo A7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32VZL | Image_ID: 81jScL5NouL
# Q: Is this case compatible with the Oppo A7?
# A: Yes
# --------------------------------------------------
# Processed 360/500 products
# Processed: Item_ID: B07TH32WCT | Image_ID: 71VMQzlTPuL
# Q: Is this case compatible with the Vivo Y69?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH32WDL | Image_ID: 71LrfEP4vnL
# Q: Is this case compatible with a Vivo Y69?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH374MP | Image_ID: 81PoQg7Z2SL
# Q: Is this case compatible with a Samsung Galaxy A8 (2016)?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH374PK | Image_ID: 61NuG-EoOuL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH374WX | Image_ID: 71rdQPX88GL
# Q: Is this case compatible with the Samsung Galaxy J6 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH374ZZ | Image_ID: 81z+FsQON4L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2972: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH37582 | Image_ID: 71082uShNFL
# Q: Is this case compatible with a Huawei G8?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH3758P | Image_ID: 71YOsTGB1EL
# Q: Is this case compatible with the Motorola One Power?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH37KFK | Image_ID: 61gurDN-eUL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2976: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee801223.jpg'
# Error processing row 2977: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f2/f2c0a7e0.jpg'
# Processed: Item_ID: B07TH37L1H | Image_ID: 811xi+ecxOL
# Q: Is this case compatible with Vivo Y21L?
# A: Yes
# --------------------------------------------------
# Processed 370/500 products
# Processed: Item_ID: B07TH382TP | Image_ID: 71KPK2gc3RL
# Q: Is this case compatible with Oppo F1 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH382W9 | Image_ID: 81rxq3EZ41L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH382XQ | Image_ID: 61tunXorFQL
# Q: Is this case compatible with iPhone 7 Plus?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH38333 | Image_ID: 71qdoMd358L
# Q: Is this case hard plastic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH3833L | Image_ID: 71EKXnPEfkL
# Q: Is this case compatible with a Vivo Y27L?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH383CL | Image_ID: 71z9eURjG8L
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2985: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH38C4W | Image_ID: 716Q13YxXKL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Error processing row 2987: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/ed0e7b87.jpg'
# Processed: Item_ID: B07TH39LDJ | Image_ID: 61l9Ll7TljL
# Q: Is this case compatible with my Micromax Canvas Silver 5 Q450?
# A: Yes
# --------------------------------------------------
# Error processing row 2989: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f6389402.jpg'
# Processed: Item_ID: B07TH39LNS | Image_ID: 71qLhv0a-XL
# Q: Is this case compatible with the Huawei Mate 9?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH39LP2 | Image_ID: 71-8D6sTVYL
# Q: Is this case compatible with the Lenovo A7700?
# A: Yes
# --------------------------------------------------
# Processed 380/500 products
# Processed: Item_ID: B07TH39LZB | Image_ID: 716+5C3o0iL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH39M49 | Image_ID: 71YG+wde1WL
# Q: Is this case hard or soft?
# A: Hard
# --------------------------------------------------
# Processed: Item_ID: B07TH39M8G | Image_ID: 81a3SjwVNLL
# Q: Is this case compatible with the Gionee Marathon M5 Plus?
# A: Yes
# --------------------------------------------------
# Error processing row 2995: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
# Processed: Item_ID: B07TH3BPZP | Image_ID: 71f-SdFDtTL
# Q: Is this case hard plastic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH3BQK3 | Image_ID: 71GtYioN4SL
# Q: Is this case compatible with my Vivo Y53?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07TH3BQK9 | Image_ID: 71HMYG4UPBL
# Q: Is this case compatible with the Vivo Y53?
# A: Yes
# --------------------------------------------------
# Error processing row 2999: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee8ee952.jpg'
#
# Reached limit of 500 API calls.
# Stopped at index 3000, Item_ID: B07TH3BQLV
# To continue processing, set start_index = 3000
#
# Processing complete!
# Total products processed: 385
# Errors: 115
# Results saved to qna2.csv
# Next start_index to continue: 3000

# %%
""" API Keys """
key_1 = "AIzaSyDRYg1bgxG-Yv77yqV5RmJuRFAsplOyLg0"
key_2 = "AIzaSyCk-3tjAx3U33d0hdXiYmKP-7m0_kHOFqk"
key_3 = "AIzaSyC8YBijcN_xFfST2Y4KB3YVR7DNnI-FFz8"

# %%
""" API call with refined instruction prompt and complete json metadata """

import time
import json
import os
import glob
import pandas as pd
from PIL import Image
import google.generativeai as genai

# Set your Gemini API key
api_key = key_1
genai.configure(api_key=api_key)

# Define the starting index (can be changed before running)
start_index = 4000  # Change this value to continue from where you left off

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Filter to get one image per product, preferring "main" role
unique_products_df = pd.DataFrame()

# Group by item_id
grouped = merged_df.groupby("item_id")

# For each product, get the "main" image or the first one if no main exists
for item_id, group in grouped:
    main_images = group[group["role"] == "main"]
    if len(main_images) > 0:
        # Take the first main image
        unique_products_df = pd.concat([unique_products_df, main_images.iloc[[0]]])
    else:
        # If no main image, take the first image
        unique_products_df = pd.concat([unique_products_df, group.iloc[[0]]])

# Reset index
unique_products_df = unique_products_df.reset_index(drop=True)

# Initialize model
model = genai.GenerativeModel("gemini-1.5-flash")

# Create counter for progress tracking
total_products = len(unique_products_df)
processed_count = 0
error_count = 0
max_api_calls = 500  # Limit to 1000 API calls

print(f"Found {total_products} unique products")
print(f"Starting processing from index {start_index} up to {max_api_calls} products...")

# Process each row in the filtered DataFrame, starting from the specified index
for index, row in unique_products_df.iloc[start_index:].iterrows():
    # Check if we've reached the API call limit
    if processed_count + error_count >= max_api_calls:
        print(f"\nReached limit of {max_api_calls} API calls.")
        print(f"Stopped at index {index}, Item_ID: {row['item_id']}")
        print(f"To continue processing, set start_index = {index}")
        break
        
    try:
        # Extract image information
        image_id = row["image_id"]
        image_dir = "Datasets/small"
        image_path = os.path.join(image_dir, row["path"])
        item_id = row["item_id"]
        
        # Load the image
        image = Image.open(image_path)
        
        # Search all JSON files for metadata of the item_id
        metadata = None
        for json_file in glob.glob("Datasets/listings_*.json"):
            with open(json_file, "r", encoding="utf-8") as f:
                for line in f:
                    doc = json.loads(line)
                    if doc.get("item_id") == item_id:
                        metadata = doc
                        break
            if metadata:
                break
        
        if metadata is None:
            print(f"Warning: Metadata for item_id {item_id} not found. Skipping.")
            error_count += 1
            continue
        
        # Using the entire metadata instead of filtering it
        
        # Prepare prompt for customer question and service rep answer generation with improved few-shot examples
        prompt = f"""Based on the provided product image and metadata, your object is to generate:
1. A realistic, specific question that a customer might ask about THIS PARTICULAR product that can be answered with a single word
2. A concise, professional single-word answer that a customer service representative would give

IMPORTANT: 
- Your question MUST be specific to the product shown in the image - consider its category, appearance, and features
- DO NOT generate generic questions or repeat the same type of question for different products
- Vary your questions based on what's most relevant to the specific product category
- Focus on what a real customer would want to know about this specific item

Here are examples of the expected format across DIFFERENT product categories:

Example 1 (Electronics):
Question: Which Android version does this device support?
Answer: Android12

Example 2 (Furniture):
Question: What type of assembly does this table require?
Answer: Flatpack



Format your response exactly like this:
Question: [your customer question here that's specific to this product]
Answer: [single word answer from customer service]

Metadata: {json.dumps(metadata, indent=2)}"""
        
        # Gemini API call
        response = model.generate_content(
            [prompt, image],
            stream=False
        )
        
        # Extract question and answer
        response_text = response.text
        question = None
        answer = None
        
        for line in response_text.split("\n"):
            if line.startswith("Question:"):
                question = line[len("Question:"):].strip()
            elif line.startswith("Answer:"):
                answer = line[len("Answer:"):].strip()
        
        if question and answer:
            # Create a dictionary with the data to save
            data = {
                'Image_ID': [image_id],
                'Item_ID': [item_id],
                'Question': [question],
                'Answer': [answer]
            }
            
            # Convert to DataFrame
            df = pd.DataFrame(data)
            
            # Check if file exists
            file_exists = os.path.isfile('qna3.csv')
            
            # Save to CSV (append if file exists, create with header if it doesn't)
            if file_exists:
                df.to_csv('qna3.csv', mode='a', header=False, index=False)
            else:
                df.to_csv('qna3.csv', index=False)
        
        # Update progress
        processed_count += 1
        if processed_count % 10 == 0:
            print(f"Processed {processed_count}/{max_api_calls} products")
        
        # Short summary of the current item
        print(f"Processed: Item_ID: {item_id} | Image_ID: {image_id}")
        print(f"Q: {question}")
        print(f"A: {answer}")
        print("-" * 50)
        
        # Pause between API calls to avoid rate limits
        time.sleep(1.0)  # 1 second pause between calls
        
    except Exception as e:
        error_count += 1
        print(f"Error processing row {index}: {str(e)}")
        # Continue with the next image even if there's an error
        continue

print(f"\nProcessing complete!")
print(f"Total products processed: {processed_count}")
print(f"Errors: {error_count}")
print(f"Results saved to qna3.csv")
print(f"Next start_index to continue: {start_index + processed_count + error_count}")
# Out:
# Found 4923 unique products
# Starting processing from index 4000 up to 500 products...
# Processed: Item_ID: B0853WSD6V | Image_ID: 71uILyygfnL
# Q: Is this case compatible with the Poco X2?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0853WSD9Z | Image_ID: 717wEPIxQuL
# Q: Is this OnePlus 7 case made of hard plastic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0853WSH1G | Image_ID: 71rlHMYuu6L
# Q: Is this case made of silicone?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0853WSSWH | Image_ID: 81oQG6AzhsL
# Q: Is this case made of silicone?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0853WT5NG | Image_ID: 714rpinTCIL
# Q: Is this case compatible with a Gionee X1?
# A: Yes
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 78
#      76 for line in f:
#      77     doc = json.loads(line)
# ---> 78     if doc.get("item_id") == item_id:
#      79         metadata = doc
#      80         break
#
# KeyboardInterrupt:

# %%
""" API call with refined instruction prompt and complete json metadata using chain-of-thought """

import time
import json
import os
import glob
import pandas as pd
from PIL import Image
import google.generativeai as genai

# Set your Gemini API key
api_key = "AIzaSyC8YBijcN_xFfST2Y4KB3YVR7DNnI-FFz8"
genai.configure(api_key=api_key)

# Define the starting index (can be changed before running)
start_index = 3500  # Change this value to continue from where you left off

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Filter to get one image per product, preferring "main" role
unique_products_df = pd.DataFrame()

# Group by item_id
grouped = merged_df.groupby("item_id")

# For each product, get the "main" image or the first one if no main exists
for item_id, group in grouped:
    main_images = group[group["role"] == "main"]
    if len(main_images) > 0:
        # Take the first main image
        unique_products_df = pd.concat([unique_products_df, main_images.iloc[[0]]])
    else:
        # If no main image, take the first image
        unique_products_df = pd.concat([unique_products_df, group.iloc[[0]]])

# Reset index
unique_products_df = unique_products_df.reset_index(drop=True)

# Initialize model
model = genai.GenerativeModel("gemini-1.5-flash")

# Create counter for progress tracking
total_products = len(unique_products_df)
processed_count = 0
error_count = 0
max_api_calls = 1000  # Limit to 1000 API calls

print(f"Found {total_products} unique products")
print(f"Starting processing from index {start_index} up to {max_api_calls} products...")

# Process each row in the filtered DataFrame, starting from the specified index
for index, row in unique_products_df.iloc[start_index:].iterrows():
    # Check if we've reached the API call limit
    if processed_count + error_count >= max_api_calls:
        print(f"\nReached limit of {max_api_calls} API calls.")
        print(f"Stopped at index {index}, Item_ID: {row['item_id']}")
        print(f"To continue processing, set start_index = {index}")
        break
        
    try:
        # Extract image information
        image_id = row["image_id"]
        image_dir = "Datasets/small"
        image_path = os.path.join(image_dir, row["path"])
        item_id = row["item_id"]
        
        # Load the image
        image = Image.open(image_path)
        
        # Search all JSON files for metadata of the item_id
        metadata = None
        for json_file in glob.glob("Datasets/listings_*.json"):
            with open(json_file, "r", encoding="utf-8") as f:
                for line in f:
                    doc = json.loads(line)
                    if doc.get("item_id") == item_id:
                        metadata = doc
                        break
            if metadata:
                break
        
        if metadata is None:
            print(f"Warning: Metadata for item_id {item_id} not found. Skipping.")
            error_count += 1
            continue
        
        prompt = f"""Based on the provided product image and metadata, I want you to generate a specific customer question about this product that can be answered with a single descriptive word. The answer must describe an attribute, material, style, or feature of the product. Let's think through this step by step:

Step 1: Analyze what type of product this is.
Look carefully at the image and examine the metadata. What category does this product belong to? What are its key features, materials, and purpose?

Step 2: Consider what aspects customers typically care about for this product category.
Based on the product type identified in Step 1, what are the top 3-4 concerns or questions that customers typically have? Consider aspects like material, style, functionality, brand, origin, or special features.

Step 3: Determine which question would be most relevant and specific to THIS PARTICULAR product, avoiding generic Yes/No questions.
From the aspects identified in Step 2, choose the one that’s most important to a customer considering this specific product. Formulate a clear, specific question that can be answered with a single descriptive word (e.g., "What is the style of shoe?" or "What is the metal of this necklace?"). Avoid any Yes/No questions.

Step 4: Determine the most accurate, single-word descriptive answer based on what's visible in the image and described in the metadata.
Based on the product details available, provide the most precise answer to the question formulated in Step 3. Ensure the answer is a single word and specific to this product (e.g., "Moccasin" for shoe style, "Silver" for necklace material).

Step 5: Verify that your question and answer pair meets the following requirements:
- The question must not be answerable with Yes/No.
- The answer must be a **single word** describing an attribute or feature of the product (e.g., material, style, brand, origin).
- Avoid asking about phone case compatibility with specific models.

Based on this analysis, provide your final output in exactly this format:
Question: [your specific, relevant customer question]
Answer: [single-word descriptive answer]

        Metadata: {json.dumps(metadata, indent=2)}"""
        
        # Gemini API call
        response = model.generate_content(
            [prompt, image],
            stream=False
        )
        
        # Extract just the question and answer from the response
        response_text = response.text
        question = None
        answer = None
        
        # Process the response to extract just the final Q&A
        in_final_output = False
        for line in response_text.split("\n"):
            if "Question:" in line and "Answer:" not in line:  # Ensure we're not capturing "Question:" from the prompt
                question = line[line.find("Question:") + len("Question:"):].strip()
                in_final_output = True
            elif "Answer:" in line and in_final_output:
                answer = line[line.find("Answer:") + len("Answer:"):].strip()
                break
        
        # If direct extraction failed, try a more general approach
        if question is None or answer is None:
            for line in response_text.split("\n"):
                if line.startswith("Question:"):
                    question = line[len("Question:"):].strip()
                elif line.startswith("Answer:"):
                    answer = line[len("Answer:"):].strip()
        
        if question and answer:
            # Create a dictionary with the data to save
            data = {
                'Image_ID': [image_id],
                'Item_ID': [item_id],
                'Question': [question],
                'Answer': [answer]
            }
            
            # Convert to DataFrame
            df = pd.DataFrame(data)
            
            # Check if file exists
            file_exists = os.path.isfile('qna4.csv')
            
            # Save to CSV (append if file exists, create with header if it doesn't)
            if file_exists:
                df.to_csv('qna4.csv', mode='a', header=False, index=False)
            else:
                df.to_csv('qna4.csv', index=False)
        
        # Update progress
        processed_count += 1
        if processed_count % 10 == 0:
            print(f"Processed {processed_count}/{max_api_calls} products")
        
        # Short summary of the current item
        print(f"Processed: Item_ID: {item_id} | Image_ID: {image_id}")
        print(f"Q: {question}")
        print(f"A: {answer}")
        print("-" * 50)
        
        # Pause between API calls to avoid rate limits
        time.sleep(1.0)  # 1 second pause between calls
        
    except Exception as e:
        error_count += 1
        print(f"Error processing row {index}: {str(e)}")
        # Continue with the next image even if there's an error
        continue

print(f"\nProcessing complete!")
print(f"Total products processed: {processed_count}")
print(f"Errors: {error_count}")
print(f"Results saved to qna4.csv")
print(f"Next start_index to continue: {start_index + processed_count + error_count}")
# Out:
# Found 4923 unique products
# Starting processing from index 3500 up to 1000 products...
# Processed: Item_ID: B07ZKPZ5M9 | Image_ID: 817tVD0fJLL
# Q: What is the scent of this Presto! cleaner?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B07ZKQ3MPG | Image_ID: 71LHp-xRq5L
# Q: What is the scent of this cleaner?
# A: Citrus
# --------------------------------------------------
# Error processing row 3502: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/ebc3ed5b.jpg'
# Processed: Item_ID: B07ZL1Q3PY | Image_ID: 61e-hSPKcjL
# Q: What is the color of the AmazonBasics bungee cord?
# A: Green
# --------------------------------------------------
# Processed: Item_ID: B07ZL1Q56Z | Image_ID: 517h6BqDeKL
# Q: What is the color of the ratchet tie-down straps?
# A: Yellow
# --------------------------------------------------
# Processed: Item_ID: B07ZL1ZYN8 | Image_ID: 61rPasB575L
# Q: What is the material of these bungee cords?
# A: Rubber
# --------------------------------------------------
# Processed: Item_ID: B07ZL44QQC | Image_ID: 51+jBq6YC7L
# Q: What is the material of these plates?
# A: Compostable
# --------------------------------------------------
# Processed: Item_ID: B07ZL4D41W | Image_ID: 6156Wdjk3uL
# Q: What is the disposability of these plates?
# A: Compostable
# --------------------------------------------------
# Processed: Item_ID: B07ZL4STKH | Image_ID: 71nu4j7HpLL
# Q: What is the material of these food containers?
# A: Paper
# --------------------------------------------------
# Processed: Item_ID: B07ZNTQC4S | Image_ID: 616kVz7NLQL
# Q: What is the frame material of the UMI Essentials handcart?
# A: Steel
# --------------------------------------------------
# Processed 10/1000 products
# Processed: Item_ID: B07ZPGQYPF | Image_ID: 61FFd6PlwLL
# Q: What is the scent of the wax strips?
# A: Calendula
# --------------------------------------------------
# Processed: Item_ID: B07ZPQGY67 | Image_ID: 71I0UEI+H-L
# Q: What is the material composition of these baby bodysuits?
# A: Cotton
# --------------------------------------------------
# Processed: Item_ID: B07ZQFCTT2 | Image_ID: 81e0ylIQ2YL
# Q: What is the style of chain on this necklace?
# A: Herringbone
# --------------------------------------------------
# Processed: Item_ID: B07ZQG1WRB | Image_ID: 71brqKNB99L
# Q: What is the plating of the necklace's sterling silver?
# A: RoseGold
# --------------------------------------------------
# Processed: Item_ID: B07ZQG5L4Q | Image_ID: 71Yby8ErsWL
# Q: What is the metal of this necklace?
# A: Sterling
# --------------------------------------------------
# Error processing row 3515: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe3ce325.jpg'
# Processed: Item_ID: B07ZQW8BS3 | Image_ID: 71PAJBb7r2L
# Q: What is the material of these food pans?
# A: StainlessSteel
# --------------------------------------------------
# Processed: Item_ID: B07ZQY6KRT | Image_ID: 61+Q+Bq7q9L
# Q: What is the material of these steam table covers?
# A: StainlessSteel
# --------------------------------------------------
# Processed: Item_ID: B07ZSR454X | Image_ID: 71xxJr51KCL
# Q: What material is the top surface of this monitor stand?
# A: Glass
# --------------------------------------------------
# Processed: Item_ID: B07ZTFC41S | Image_ID: 1168jc-5r1L
# Q: What is the material of the glasses and pitcher?
# A: Glass
# --------------------------------------------------
# Processed: Item_ID: B07ZTVWSNG | Image_ID: 71FkMWPZfAL
# Q: What is the coating material of the straightening plates?
# A: Ceramic
# --------------------------------------------------
# Processed 20/1000 products
# Processed: Item_ID: B07ZVK5GW1 | Image_ID: 71UZhoi1MpL
# Q: What is the material of the water bottle's body?
# A: StainlessSteel
# --------------------------------------------------
# Processed: Item_ID: B07ZVM8FJH | Image_ID: 91o5OvRVsUL
# Q: What is the material of the planter box?
# A: Resin
# --------------------------------------------------
# Processed: Item_ID: B07ZW5HL6F | Image_ID: 51lxpd8cMxL
# Q: What is the style of these sandals?
# A: Roman
# --------------------------------------------------
# Processed: Item_ID: B07ZX4G5KT | Image_ID: 816wiBOpwBL
# Q: What is the type of tortilla offered?
# A: Flour
# --------------------------------------------------
# Processed: Item_ID: B0811QRMCN | Image_ID: 518YuSwmy0L
# Q: What is the metal of these earrings?
# A: Gold
# --------------------------------------------------
# Processed: Item_ID: B0812BNQ8H | Image_ID: 71LdNB0HDvL
# Q: What is the style of these men's shoes?
# A: Moccasin
# --------------------------------------------------
# Processed: Item_ID: B0812BR27V | Image_ID: 71b8yXcfaWL
# Q: What is the material of the upper of these boat shoes?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B0812BR7RR | Image_ID: 71YIbGvDiOL
# Q: What is the material of these men's loafers?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B0812BSVSB | Image_ID: 71HwlYLjllL
# Q: What is the style of these men's shoes?
# A: Moccasin
# --------------------------------------------------
# Processed: Item_ID: B0812BVZ72 | Image_ID: 91GVX3vxotL
# Q: What is the material of the find. Desert Boots?
# A: Suede
# --------------------------------------------------
# Processed 30/1000 products
# Processed: Item_ID: B0812BXP23 | Image_ID: 51bXHaefTpL
# Q: What is the origin of these almonds?
# A: Spanish
# --------------------------------------------------
# Processed: Item_ID: B0812C4MTY | Image_ID: 718GyxKkEOL
# Q: What is the style of these men's loafers?
# A: SaddleDriver
# --------------------------------------------------
# Processed: Item_ID: B0812C9HX1 | Image_ID: 81Ub7-sfhuL
# Q: What is the material of the upper of these boat shoes?
# A: Suede
# --------------------------------------------------
# Error processing row 3534: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f830eb7a.jpg'
# Processed: Item_ID: B0812CJM6M | Image_ID: 81OnnkNH8tL
# Q: What is the material of these men's loafers?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B0812CM3FM | Image_ID: 71jmQxZolKL
# Q: What is the style of these shoes?
# A: Moccasins
# --------------------------------------------------
# Error processing row 3537: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f830eb7a.jpg'
# Processed: Item_ID: B0812DBKCX | Image_ID: 81S0VjXrV2L
# Q: What is the style of these women's boots?
# A: Moccasin
# --------------------------------------------------
# Processed: Item_ID: B0812JQ46D | Image_ID: 716XdpdgtJL
# Q: What is the primary material of the included geometric tools?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B0813HP9SB | Image_ID: 71ZtBt7YjBL
# Q: What is the sole material of these espadrille sandals?
# A: Espadrille
# --------------------------------------------------
# Processed: Item_ID: B0813JH5M5 | Image_ID: 61fDlUFSUhL
# Q: What is the heel style of these sandals?
# A: Block
# --------------------------------------------------
# Processed: Item_ID: B0813LXH8J | Image_ID: 617zijefB4L
# Q: What material is the UMI laundry basket made of?
# A: Cotton
# --------------------------------------------------
# Processed 40/1000 products
# Processed: Item_ID: B0813YNP1K | Image_ID: 61BSvdyg0oL
# Q: What is the primary color of this Iris shelving unit?
# A: Brown
# --------------------------------------------------
# Processed: Item_ID: B0813ZM38S | Image_ID: 61GS0OyT5+L
# Q: What is the nozzle's spray pattern type?
# A: 3-way
# --------------------------------------------------
# Processed: Item_ID: B0813ZVFXD | Image_ID: 71jlnNZ1pzL
# Q: What is the finish of this cast iron Dutch oven?
# A: Matte
# --------------------------------------------------
# Processed: Item_ID: B0814HY2TT | Image_ID: 61NqFSgswUL
# Q: What material is the UMI water bottle constructed from?
# A: StainlessSteel
# --------------------------------------------------
# Processed: Item_ID: B0817D2DL8 | Image_ID: 61-uDAVYwXL
# Q: What is the style of these women's shoes?
# A: Slingback
# --------------------------------------------------
# Processed: Item_ID: B081BG2RSN | Image_ID: 71BPjzfVkcL
# Q: What is the material of the AmazonBasics garden hose?
# A: PVC
# --------------------------------------------------
# Processed: Item_ID: B081D8DC93 | Image_ID: 71rs6zRJjLL
# Q: What is the color of the AmazonBasics charcoal grill?
# A: Black
# --------------------------------------------------
# Processed: Item_ID: B081D8JP3M | Image_ID: 713TZ3mKJnL
# Q: What is the grill's primary material?
# A: Steel
# --------------------------------------------------
# Processed: Item_ID: B081DXCCW2 | Image_ID: 51tHBVaymxL
# Q: What is the material of the staple remover jaws?
# A: Steel
# --------------------------------------------------
# Processed: Item_ID: B081FG2CPK | Image_ID: 61vVPo2QnlL
# Q: What is the material of these storage boxes?
# A: Fabric
# --------------------------------------------------
# Processed 50/1000 products
# Processed: Item_ID: B081FGFJYC | Image_ID: 71BreB7y3KL
# Q: What is the pattern on the storage box?
# A: Chevron
# --------------------------------------------------
# Processed: Item_ID: B081FGFJZN | Image_ID: 61vVPo2QnlL
# Q: What is the primary material of these storage boxes?
# A: Fabric
# --------------------------------------------------
# Processed: Item_ID: B081FGFK31 | Image_ID: 61KkWQ1gtLL
# Q: What is the primary material of this storage box?
# A: Fabric
# --------------------------------------------------
# Processed: Item_ID: B081FGJK6P | Image_ID: 51mYG3MjmVL
# Q: What is the color of the Solimo fabric storage boxes?
# A: Blue
# --------------------------------------------------
# Processed: Item_ID: B081FGSKFM | Image_ID: 51abUYujc0L
# Q: What is the primary material of these storage boxes?
# A: Fabric
# --------------------------------------------------
# Processed: Item_ID: B081FGSS2M | Image_ID: 71h7A8YYIHL
# Q: What is the pattern of the storage boxes?
# A: Chevron
# --------------------------------------------------
# Processed: Item_ID: B081FGTPB7 | Image_ID: 611gWsnH0KL
# Q: What is the size of these AmazonBasics batteries?
# A: AA
# --------------------------------------------------
# Processed: Item_ID: B081FGVB85 | Image_ID: 5107124VfYL
# Q: What is the color of the Solimo fabric storage boxes?
# A: Blue
# --------------------------------------------------
# Error processing row 3561: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0f42ac6.jpg'
# Processed: Item_ID: B081FHWVZ6 | Image_ID: 61DSm2MzlML
# Q: What is the pattern on the storage boxes?
# A: Geometric
# --------------------------------------------------
# Processed: Item_ID: B081HJXG86 | Image_ID: 61dWU0wvW2L
# Q: What is the primary dried fruit in this trail mix?
# A: Cranberry
# --------------------------------------------------
# Processed 60/1000 products
# Processed: Item_ID: B081HKBNTM | Image_ID: 81ne3WaR5JL
# Q: What is the material of the FIND. Flynn Chelsea boots?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B081HLWDKR | Image_ID: 61PdxhLperL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Error processing row 3566: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f9fca95f.jpg'
# Processed: Item_ID: B081HMDF9F | Image_ID: 61jYqFvOE5L
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMG2HV | Image_ID: 61OJs0kgvkL
# Q: What is the primary design feature of this phone case?
# A: Monogram
# --------------------------------------------------
# Error processing row 3569: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/eef17f89.jpg'
# Processed: Item_ID: B081HMJRHB | Image_ID: 61fKwykt6WL
# Q: What is the phone case design?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B081HML6MB | Image_ID: 61-T8p4TbSL
# Q: What is the phone case's design style?
# A: Whimsical
# --------------------------------------------------
# Processed: Item_ID: B081HMLPX1 | Image_ID: 61mluKLZzrL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMLRVQ | Image_ID: 61e4qyIN7GL
# Q: What is the case's design style?
# A: Teddy
# --------------------------------------------------
# Processed: Item_ID: B081HMLS5N | Image_ID: 51AbYbblgmL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMLT3L | Image_ID: 61VdWJIJInL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed 70/1000 products
# Processed: Item_ID: B081HMN5YH | Image_ID: 61lLIMaKmFL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMNN2W | Image_ID: 61M7ZbzmaAL
# Q: What is the phone case's design style?
# A: Multicolored
# --------------------------------------------------
# Processed: Item_ID: B081HMNVCN | Image_ID: 51AbYbblgmL
# Q: What is the case's design style?
# A: Girl
# --------------------------------------------------
# Processed: Item_ID: B081HMNZ9T | Image_ID: 61vUIvTalAL
# Q: What is the primary material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMPF9N | Image_ID: 51StPCWRyEL
# Q: What is the phone case's primary material?
# A: Plastic
# --------------------------------------------------
# Error processing row 3581: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/ed7b60d5.jpg'
# Processed: Item_ID: B081HMPJ7D | Image_ID: 71Ydg9NKL2L
# Q: What is the design style of this phone case?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HMQFY4 | Image_ID: 610O72K+ukL
# Q: What is the design style of this phone case?
# A: Cupcakes
# --------------------------------------------------
# Processed: Item_ID: B081HMQG93 | Image_ID: 61HWL9ruyxL
# Q: What is the phone case's design style?
# A: Ornate
# --------------------------------------------------
# Processed: Item_ID: B081HMTNW1 | Image_ID: 61WI2bZEvHL
# Q: What is the design style of this phone case?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HMTVT5 | Image_ID: 61MeUZfeIyL
# Q: What is the case's design style?
# A: Floral
# --------------------------------------------------
# Processed 80/1000 products
# Processed: Item_ID: B081HMVS3H | Image_ID: 61bteHacz9L
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMWBWT | Image_ID: 61YfJZ-u2qL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMWSW7 | Image_ID: 71AAH0+vs2L
# Q: What is the primary design feature of this phone case?
# A: Denim
# --------------------------------------------------
# Processed: Item_ID: B081HMX73H | Image_ID: 71y1-Kv6tCL
# Q: What is the primary material of this handbag?
# A: PU
# --------------------------------------------------
# Processed: Item_ID: B081HMXDWP | Image_ID: 61-Rlr9E6jL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HMXSWJ | Image_ID: 51AbYbblgmL
# Q: What is the phone case's printing style?
# A: 3D
# --------------------------------------------------
# Processed: Item_ID: B081HMY5FJ | Image_ID: 7144s7C87ML
# Q: What is the style of the phone case's design?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HMZFNG | Image_ID: 51AbYbblgmL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN1J9V | Image_ID: 611d6Nmuw0L
# Q: What is the design featured on this phone case?
# A: Libra
# --------------------------------------------------
# Processed: Item_ID: B081HN1LZ3 | Image_ID: 61myyuvTzUL
# Q: What is the case's design?
# A: Multicolored
# --------------------------------------------------
# Error processing row 3597: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fb5a3514.jpg'
# Processed 90/1000 products
# Processed: Item_ID: B081HN2K4V | Image_ID: 61oFSxHBFLL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN319M | Image_ID: 61pWyk2QYeL
# Q: What is the print style of this phone case?
# A: Birds
# --------------------------------------------------
# Processed: Item_ID: B081HN3SZB | Image_ID: 61Ru2nI5IIL
# Q: What is the design style of this phone case?
# A: Whimsical
# --------------------------------------------------
# Processed: Item_ID: B081HN3T22 | Image_ID: 61HUWRLvlbL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B081HN4FB3 | Image_ID: 61tIox+nwgL
# Q: What is the design style of this phone case?
# A: Ornate
# --------------------------------------------------
# Processed: Item_ID: B081HN4FQQ | Image_ID: 61c6ak3hJSL
# Q: What is the material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN4FRG | Image_ID: 81bXC6SIidL
# Q: What is the design featured on this phone case?
# A: Denim
# --------------------------------------------------
# Processed: Item_ID: B081HN57Y5 | Image_ID: 61xQ1Cn0UML
# Q: What is the material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN584G | Image_ID: 51AbYbblgmL
# Q: What is the design of the phone case?
# A: Heart
# --------------------------------------------------
# Processed: Item_ID: B081HN6DBZ | Image_ID: 61K0caWOb1L
# Q: What is the phone case's design style?
# A: Multicolored
# --------------------------------------------------
# Processed 100/1000 products
# Processed: Item_ID: B081HN6XH6 | Image_ID: 71JGP3jdSAL
# Q: What is the design of this phone case?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HN6Z56 | Image_ID: 61MpJbhKMuL
# Q: What is the design style of this phone case?
# A: Monogram
# --------------------------------------------------
# Processed: Item_ID: B081HN79PK | Image_ID: 618XLIjI4sL
# Q: What is the design style of the phone case?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B081HN7FD5 | Image_ID: 51xHQxEtHmL
# Q: What is the material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN7Q9J | Image_ID: 51tV+mkVweL
# Q: What is the design of the phone case?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B081HN7QW1 | Image_ID: 614VGZdoDdL
# Q: What is the design style of this phone case?
# A: Ornate
# --------------------------------------------------
# Processed: Item_ID: B081HN7XMZ | Image_ID: 618lVgaJkJL
# Q: What is the design featured on this phone case?
# A: Scorpio
# --------------------------------------------------
# Processed: Item_ID: B081HN7XQQ | Image_ID: 51AbYbblgmL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN7XVG | Image_ID: 61oB9hVCprL
# Q: What is the phone case's design style?
# A: Monogram
# --------------------------------------------------
# Processed: Item_ID: B081HN7ZGS | Image_ID: 51AbYbblgmL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed 110/1000 products
# Processed: Item_ID: B081HN86G9 | Image_ID: 616W-bjUyeL
# Q: What is the phone case's design style?
# A: Graphic
# --------------------------------------------------
# Processed: Item_ID: B081HN8KW3 | Image_ID: 61GMyhX2diL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN8Z9R | Image_ID: 61O-qi9UDZL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B081HN92BJ | Image_ID: 51AbYbblgmL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HN9MKW | Image_ID: 61k7tDi5thL
# Q: What is the phone case's design style?
# A: 3D-Printed
# --------------------------------------------------
# Error processing row 3623: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f9bfa0ed.jpg'
# Processed: Item_ID: B081HNBQBD | Image_ID: 61G9U-xthsL
# Q: What is the design featured on this phone case?
# A: Butterfly
# --------------------------------------------------
# Processed: Item_ID: B081HNC3QX | Image_ID: 71PSaj49wmL
# Q: What is the case's design style?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HNCCLL | Image_ID: 71Wh5yEDeOL
# Q: What is the pattern on the phone case?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HNDTFT | Image_ID: 71-+-PpBD4L
# Q: What is the design featured on this phone case?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HNDTGQ | Image_ID: 61zMr3AQCkL
# Q: What is the phone case's design style?
# A: Cancer
# --------------------------------------------------
# Processed 120/1000 products
# Processed: Item_ID: B081HNDVY6 | Image_ID: 61LY1MaKoaL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNDW7S | Image_ID: 51AbYbblgmL
# Q: What is the case's design style?
# A: 3D
# --------------------------------------------------
# Processed: Item_ID: B081HNDZ1P | Image_ID: 51AbYbblgmL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNG17Q | Image_ID: 71ic2I4pE7L
# Q: What is the design featured on this phone case?
# A: Peacock
# --------------------------------------------------
# Processed: Item_ID: B081HNG1MW | Image_ID: 61aK8BQPYEL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B081HNGK4Y | Image_ID: 61Yy-Xbj51L
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNGRB1 | Image_ID: 61q+05hk1gL
# Q: What is the design of the phone case?
# A: Multi-colored
# --------------------------------------------------
# Processed: Item_ID: B081HNJ14F | Image_ID: 61muFhCAmPL
# Q: What is the design style of this phone case?
# A: 3D
# --------------------------------------------------
# Processed: Item_ID: B081HNK63W | Image_ID: 61q2DfhD81L
# Q: What is the phone case's design?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HNLMYS | Image_ID: 71eglL5Sg1L
# Q: What is the design featured on this phone case?
# A: Denim
# --------------------------------------------------
# Processed 130/1000 products
# Processed: Item_ID: B081HNLN8L | Image_ID: 61Bl7rxTNDL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B081HNLWFG | Image_ID: 615elSKxqJL
# Q: What is the case's printing style?
# A: 3D
# --------------------------------------------------
# Processed: Item_ID: B081HNLXBR | Image_ID: 6127Qax6ugL
# Q: What is the design of this phone case?
# A: Donuts
# --------------------------------------------------
# Processed: Item_ID: B081HNLXGT | Image_ID: 61YEoHf4DQL
# Q: What is the case's design style?
# A: Artistic
# --------------------------------------------------
# Processed: Item_ID: B081HNM23X | Image_ID: 61UItdmn2XL
# Q: What is the design of the phone case?
# A: Donuts
# --------------------------------------------------
# Processed: Item_ID: B081HNMXQ2 | Image_ID: 61Y1FsSb7OL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNMXRS | Image_ID: 51AbYbblgmL
# Q: What is the phone case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNN7DS | Image_ID: 612uqLDUwBL
# Q: What is the case's design style?
# A: 3D
# --------------------------------------------------
# Processed: Item_ID: B081HNN7K2 | Image_ID: 61lJXQK2JoL
# Q: What is the design style of this phone case?
# A: Ornate
# --------------------------------------------------
# Processed: Item_ID: B081HNQ364 | Image_ID: 71I4XTm3wTL
# Q: What is the design style of this phone case?
# A: Denim
# --------------------------------------------------
# Processed 140/1000 products
# Processed: Item_ID: B081HNQ3CQ | Image_ID: 61nTQuANY5L
# Q: What is the design of the phone case?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HNQDJ1 | Image_ID: 51AbYbblgmL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNQDMQ | Image_ID: 61CPGyyQx1L
# Q: What is the design style of this phone case?
# A: Heart
# --------------------------------------------------
# Processed: Item_ID: B081HNQJ2B | Image_ID: 71uxrJszxmL
# Q: What is the design style of this phone case?
# A: Denim
# --------------------------------------------------
# Processed: Item_ID: B081HNQJC5 | Image_ID: 61EIj+U1NdL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNQM9M | Image_ID: 51Sefb1o6OL
# Q: What is the case's design style?
# A: Girly
# --------------------------------------------------
# Processed: Item_ID: B081HNQQSV | Image_ID: 61YC20zDxnL
# Q: What is the case's design?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HNQQZB | Image_ID: 61hqfO07W+L
# Q: What is the case's design style?
# A: Mandala
# --------------------------------------------------
# Processed: Item_ID: B081HNQR96 | Image_ID: 61YoBCTRerL
# Q: What is the material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNQRWN | Image_ID: 51AbYbblgmL
# Q: What is the case's design style?
# A: Abstract
# --------------------------------------------------
# Processed 150/1000 products
# Processed: Item_ID: B081HNQS5V | Image_ID: 51AbYbblgmL
# Q: What is the phone case's design style?
# A: Bicycle
# --------------------------------------------------
# Processed: Item_ID: B081HNRB4H | Image_ID: 610fJdkQwBL
# Q: What is the design style of this phone case?
# A: Ornate
# --------------------------------------------------
# Error processing row 3661: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f42374ef.jpg'
# Processed: Item_ID: B081HNSNM2 | Image_ID: 61pITiNnt6L
# Q: What is the phone case's design style?
# A: 3D-printed
# --------------------------------------------------
# Processed: Item_ID: B081HNSP8R | Image_ID: 61-yp1ZPdxL
# Q: What is the design style of this phone case?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B081HNV99Y | Image_ID: 61UWEYf1ErL
# Q: What is the case's design theme?
# A: Indian
# --------------------------------------------------
# Processed: Item_ID: B081HNV9G8 | Image_ID: 71+4OoM0jGL
# Q: What is the phone case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNV9JS | Image_ID: 61gSxPkO6gL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HNV9LP | Image_ID: 51HXmFR5goL
# Q: What is the case's design style?
# A: Heart
# --------------------------------------------------
# Processed: Item_ID: B081HNXJY8 | Image_ID: 614xkAh4yPL
# Q: What is the design pattern of this phone case?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HNXKGV | Image_ID: 61cUjpY0mWL
# Q: What is the design of the phone case?
# A: Butterfly
# --------------------------------------------------
# Processed 160/1000 products
# Processed: Item_ID: B081HNZTHL | Image_ID: 71IUYJgY8eL
# Q: What is the design style of this phone case?
# A: Denim
# --------------------------------------------------
# Processed: Item_ID: B081HNZVVM | Image_ID: 51AbYbblgmL
# Q: What is the phone case's design pattern?
# A: Heart
# --------------------------------------------------
# Processed: Item_ID: B081HP1J1K | Image_ID: 61K1cjzsoeL
# Q: What is the design featured on this phone case?
# A: Butterfly
# --------------------------------------------------
# Processed: Item_ID: B081HP24PG | Image_ID: 61ekdc4tAJL
# Q: What is the material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B081HP24WH | Image_ID: 616LjEWv2LL
# Q: What is the print style of this phone case?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HP25FT | Image_ID: 71qfrKSJIiL
# Q: What is the pattern of this phone case?
# A: Hearts
# --------------------------------------------------
# Processed: Item_ID: B081HP5VWV | Image_ID: 51AbYbblgmL
# Q: What is the case material?
# A: Plastic
# --------------------------------------------------
# Error processing row 3677: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f593a507.jpg'
# Processed: Item_ID: B081HP6VDW | Image_ID: 61PTkPf1etL
# Q: What is the phone case design?
# A: Birds
# --------------------------------------------------
# Processed: Item_ID: B081HP6VPW | Image_ID: 71gnsDz5xcL
# Q: What is the design style of this phone case?
# A: Auto-rickshaw
# --------------------------------------------------
# Processed: Item_ID: B081HP6VV1 | Image_ID: 71vYX+MOaHL
# Q: What is the design style of this phone case?
# A: Teddy
# --------------------------------------------------
# Processed 170/1000 products
# Processed: Item_ID: B081HPMVVQ | Image_ID: 615CHy7-d9L
# Q: What is the design style of this phone case?
# A: Abstract
# --------------------------------------------------
# Processed: Item_ID: B081HYWD2D | Image_ID: 81j8Hyy928L
# Q: What is the material of this ski bag?
# A: Polyester
# --------------------------------------------------
# Processed: Item_ID: B081KWLRPD | Image_ID: 71mVFTEAIqL
# Q: What is the heel type of these mules?
# A: Low
# --------------------------------------------------
# Processed: Item_ID: B081M678HT | Image_ID: 71WubxLfwJL
# Q: What is the material of these boat shoes?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B081MC7WPL | Image_ID: 718GyxKkEOL
# Q: What is the style of these men's shoes?
# A: Moccasins
# --------------------------------------------------
# Processed: Item_ID: B081NTCG2D | Image_ID: 818oCQD6F7L
# Q: What is the plating of the Disney Mickey Mouse charm necklace?
# A: Silver
# --------------------------------------------------
# Processed: Item_ID: B081PPL149 | Image_ID: 71ZemQd-ieL
# Q: What is the surface texture of these interlocking foam tiles?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B081Q2XHXW | Image_ID: 816Qoy3J1eL
# Q: What is the finish of the AmazonBasics TV mount?
# A: Black
# --------------------------------------------------
# Processed: Item_ID: B081Q77S4V | Image_ID: 81bYwzjAH0L
# Q: What is the flavor of these cookies?
# A: Snickerdoodle
# --------------------------------------------------
# Processed: Item_ID: B081Q815YN | Image_ID: 81NXSsXvZuL
# Q: What is the color of the AmazonBasics folding shopping cart?
# A: Blue
# --------------------------------------------------
# Processed 180/1000 products
# Processed: Item_ID: B081Q8SF44 | Image_ID: 811ZQWd4fPL
# Q: What is the material of the shopping cart's bag?
# A: Polyester
# --------------------------------------------------
# Processed: Item_ID: B081QPW3GJ | Image_ID: 61oESNCskNL
# Q: What is the cover material of the AmazonBasics lever arch file?
# A: PP
# --------------------------------------------------
# Processed: Item_ID: B081QQ46C4 | Image_ID: 81j02tbOsNL
# Q: What is the cover material of the AmazonBasics lever arch file?
# A: PP
# --------------------------------------------------
# Processed: Item_ID: B081QQW37Y | Image_ID: 91aAefdT3uL
# Q: What is the grain type of these flakes?
# A: Buckwheat
# --------------------------------------------------
# Processed: Item_ID: B081QSX295 | Image_ID: 716CUfwp19L
# Q: What is the type of washing machine this detergent is for?
# A: Top-load
# --------------------------------------------------
# Error processing row 3696: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f965f606.jpg'
# Processed: Item_ID: B081SDZG2N | Image_ID: 91muT5JY08L
# Q: What is the material of these Chelsea boots?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B081SFGP67 | Image_ID: 7177g4zPxyL
# Q: What is the heel type of these sandals?
# A: Wedge
# --------------------------------------------------
# Processed: Item_ID: B081SW7YZJ | Image_ID: 7120WANe16L
# Q: What is the material of these desert boots?
# A: Suede
# --------------------------------------------------
# Processed: Item_ID: B081TPWFQ1 | Image_ID: 71OIghUxZKL
# Q: What material are these gardening gloves primarily made of?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B081W6M2ZC | Image_ID: 714R68PgH1L
# Q: What is the primary flavor profile of this salmon?
# A: Teriyaki
# --------------------------------------------------
# Processed 190/1000 products
# Processed: Item_ID: B081WRKZMW | Image_ID: 81lQ0u3CxSL
# Q: What is the material of this men's wallet?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B081YQ4Z1G | Image_ID: 71A63TuLykL
# Q: What is the type of plastic used in this filament?
# A: PLA
# --------------------------------------------------
# Processed: Item_ID: B081ZGRL6C | Image_ID: 81sFZyHGI-L
# Q: What is the gazebo's canopy color?
# A: Green
# --------------------------------------------------
# Processed: Item_ID: B0821CZG4J | Image_ID: 71coj5IoFyL
# Q: What is the phone case's material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B0821D2H5P | Image_ID: 816fZqCqVfL
# Q: What is the phone case's primary design feature?
# A: Pattern
# --------------------------------------------------
# Error processing row 3707: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/ed1539e6.jpg'
# Processed: Item_ID: B0821DCZR9 | Image_ID: 61dwuRQUWML
# Q: What is the phone case's design style?
# A: Cartoon
# --------------------------------------------------
# Processed: Item_ID: B0821DF23H | Image_ID: 71WamKgHYtL
# Q: What is the case material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B0821DQ1KC | Image_ID: 717wFrJJ7UL
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B0821DR8RG | Image_ID: 71Rxb-bMQVL
# Q: What is the case material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B0821FCYW3 | Image_ID: 611NYoyh6lL
# Q: What is the phone case material?
# A: Silicon
# --------------------------------------------------
# Processed 200/1000 products
# Processed: Item_ID: B0821ZMPBF | Image_ID: 71mQOCmXftL
# Q: What is the metal of these hoop earrings?
# A: StainlessSteel
# --------------------------------------------------
# Processed: Item_ID: B0822CQN2M | Image_ID: 91HRsW1PNZL
# Q: What is the origin of this rice?
# A: Hokkaido
# --------------------------------------------------
# Processed: Item_ID: B0822Q3VZT | Image_ID: 611XWWeyW4L
# Q: What is the material of the AmazonBasics clipboards?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B08237C6YL | Image_ID: 61f4+XOycTL
# Q: What is the overall design pattern of the Movian Archar rug?
# A: Geometric
# --------------------------------------------------
# Processed: Item_ID: B0823VK923 | Image_ID: 51TofVnlDfL
# Q: What is the primary material of these winter gloves?
# A: Polyester
# --------------------------------------------------
# Error processing row 3718: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f1/f1a1e3c3.jpg'
# Processed: Item_ID: B0824G2GWM | Image_ID: 41aWHajDwIL
# Q: What is the finish of the lamp's base?
# A: Brushed
# --------------------------------------------------
# Processed: Item_ID: B0825DN9JL | Image_ID: 51hSY6izd8L
# Q: What is the lamp's base material?
# A: Glass
# --------------------------------------------------
# Error processing row 3721: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f9215895.jpg'
# Processed: Item_ID: B08285WGD4 | Image_ID: 61H0Nk9zrVL
# Q: What is the color of the tape dispenser?
# A: White
# --------------------------------------------------
# Processed: Item_ID: B0828YRP1Q | Image_ID: 71pLAiVzH7L
# Q: What is the material of this iPad case?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B0829G49XL | Image_ID: 71KY0XT0lcL
# Q: What is the material of this cord cover?
# A: Rubber
# --------------------------------------------------
# Processed 210/1000 products
# Processed: Item_ID: B0829Q3BSN | Image_ID: 61cbAei8wCL
# Q: What is the light color temperature of this bulb?
# A: Daylight
# --------------------------------------------------
# Processed: Item_ID: B082B9FCY4 | Image_ID: 71RpsPeYp7L
# Q: What is the pattern of the ironing board cover?
# A: Chevron
# --------------------------------------------------
# Processed: Item_ID: B082BF5TJR | Image_ID: 91AnxOiwm5L
# Q: What is the primary material of this fire pit cover?
# A: Polyester
# --------------------------------------------------
# Processed: Item_ID: B082D42V1X | Image_ID: 718-Ypd0-KL
# Q: What is the primary material of this TV wall mount?
# A: Steel
# --------------------------------------------------
# Processed: Item_ID: B082D9CWMV | Image_ID: 61gzyzRciyL
# Q: What is the outer material of these gloves?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B082DLBNMM | Image_ID: 618HikPqerL
# Q: What is the design printed on the back of this phone case?
# A: Teddy
# --------------------------------------------------
# Processed: Item_ID: B082DMWHGW | Image_ID: 61213ZOWI6L
# Q: What is the dominant color of the phone case design?
# A: Blue
# --------------------------------------------------
# Processed: Item_ID: B082DP5M9X | Image_ID: 41QwrBhi8tL
# Q: What is the case's transparency?
# A: Transparent
# --------------------------------------------------
# Processed: Item_ID: B082DPXR37 | Image_ID: 71sRNdpNrCL
# Q: What is the finish of the wall sconce's metal base?
# A: Bronze
# --------------------------------------------------
# Processed: Item_ID: B082DS1NPT | Image_ID: 711qGA6lnsL
# Q: What is the frame material of this Solimo wall clock?
# A: Plastic
# --------------------------------------------------
# Processed 220/1000 products
# Processed: Item_ID: B082DVJGTF | Image_ID: 71iXNmx9WbL
# Q: What is the finish of the Solimo Piton toothbrush tumbler?
# A: Chrome
# --------------------------------------------------
# Processed: Item_ID: B082DZ859L | Image_ID: 61GcymDBx-L
# Q: What is the material of this screen protector?
# A: Glass
# --------------------------------------------------
# Processed: Item_ID: B082F2LFTC | Image_ID: 617kB4h76qL
# Q: What is the light bulb's color temperature?
# A: Daylight
# --------------------------------------------------
# Processed: Item_ID: B082FL5GQM | Image_ID: 61qFmRIsfAL
# Q: What is the primary color of this rice cooker?
# A: Maroon
# --------------------------------------------------
# Processed: Item_ID: B082JH6LSF | Image_ID: 71S7YSK7N+L
# Q: What is the veneer of this file cabinet?
# A: Pine
# --------------------------------------------------
# Processed: Item_ID: B082JHJKGM | Image_ID: 71Hu9MZ3uoL
# Q: What is the shade material of this pendant light?
# A: Twine
# --------------------------------------------------
# Processed: Item_ID: B082KNYKZB | Image_ID: 61emzBCeBzL
# Q: What is the hat's brim style?
# A: Wide
# --------------------------------------------------
# Processed: Item_ID: B082LC3SHX | Image_ID: 71b-uAGUSXL
# Q: What is the type of deodorant provided in this pack?
# A: Gas
# --------------------------------------------------
# Processed: Item_ID: B082LL29SC | Image_ID: 61iIIKaYukL
# Q: What is the style of this boys' sneaker?
# A: Alba
# --------------------------------------------------
# Processed: Item_ID: B082MCKMCB | Image_ID: 61neRc0jzVL
# Q: What is the plating of this necklace?
# A: RoseGold
# --------------------------------------------------
# Processed 230/1000 products
# Processed: Item_ID: B082MDFPDF | Image_ID: 61PAn+y-SEL
# Q: What is the plating of this ring?
# A: Gold
# --------------------------------------------------
# Processed: Item_ID: B082MTDCKX | Image_ID: 71fBiHRj9KL
# Q: What is the toe style of these ballet flats?
# A: Closed
# --------------------------------------------------
# Processed: Item_ID: B082MV25XQ | Image_ID: 719En2++SnL
# Q: What is the heel type of these shoes?
# A: Kitten
# --------------------------------------------------
# Processed: Item_ID: B082MV5Y2W | Image_ID: 81Eemk0hxUL
# Q: What is the material of these heels?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B082MV768H | Image_ID: 71J99bhg75L
# Q: What is the material of the find. Ruth Court heels?
# A: Synthetic
# --------------------------------------------------
# Processed: Item_ID: B082MVG2PP | Image_ID: 71gEm7BeR2L
# Q: What is the style of these heels?
# A: Pumps
# --------------------------------------------------
# Processed: Item_ID: B082MZVQ31 | Image_ID: 81JrgP7sSYL
# Q: What is the pattern of the AmazonBasics anti-fatigue mat?
# A: Geometric
# --------------------------------------------------
# Processed: Item_ID: B082N5G44K | Image_ID: 81LhaphYzPL
# Q: What is the texture of these pizza crusts?
# A: Crispy
# --------------------------------------------------
# Processed: Item_ID: B082N5N842 | Image_ID: 81It3TwdcTL
# Q: What type of bread is this?
# A: Sprouted
# --------------------------------------------------
# Processed: Item_ID: B082P4T762 | Image_ID: 71NaDSbtJbL
# Q: What is the configuration of outlets in this surge protector?
# A: 9-Outlet
# --------------------------------------------------
# Processed 240/1000 products
# Processed: Item_ID: B082PLPNBF | Image_ID: 71QXkrg-k3L
# Q: What is the material of the Amazon Essentials Amelia Rain Boot?
# A: Rubber
# --------------------------------------------------
# Processed: Item_ID: B082PLRVH8 | Image_ID: 71Qv1vngB9L
# Q: What is the material of these rain boots?
# A: Rubber
# --------------------------------------------------
# Processed: Item_ID: B082PM2KBB | Image_ID: 71T6YtLgXUL
# Q: What is the upper material of this sandal?
# A: Leather
# --------------------------------------------------
# Processed: Item_ID: B082PMRGJJ | Image_ID: 71ObNkntvlL
# Q: What is the upper material of this ballet flat?
# A: Knit
# --------------------------------------------------
# Processed: Item_ID: B082PMRGJW | Image_ID: 71DpcaHV8NL
# Q: What is the upper material of this ballet flat?
# A: Knit
# --------------------------------------------------
# Processed: Item_ID: B082PMWV2S | Image_ID: 71DpcaHV8NL
# Q: What is the upper material of this ballet flat?
# A: Knit
# --------------------------------------------------
# Processed: Item_ID: B082PMX2QM | Image_ID: 71Bb8jnOizL
# Q: What is the upper material of this ballet flat?
# A: Knit
# --------------------------------------------------
# Processed: Item_ID: B082PMYR9R | Image_ID: 61CROuWRV2L
# Q: What is the upper material of this ballet flat?
# A: Knit
# --------------------------------------------------
# Processed: Item_ID: B082PN2QCF | Image_ID: 71ObNkntvlL
# Q: What is the pattern of these ballet flats?
# A: Leopard
# --------------------------------------------------
# Processed: Item_ID: B082PNBG96 | Image_ID: 71ObNkntvlL
# Q: What is the pattern of these ballet flats?
# A: Leopard
# --------------------------------------------------
# Processed 250/1000 products
# Processed: Item_ID: B082PP39GK | Image_ID: 71UTDnRTl5L
# Q: What is the material composition of these curtains?
# A: Polyester
# --------------------------------------------------
# Processed: Item_ID: B082PRFCWZ | Image_ID: 51-22J1j05L
# Q: What is the cut of the cubic zirconia in these earrings?
# A: Baguette
# --------------------------------------------------
# Processed: Item_ID: B082PRGJMH | Image_ID: 61dpLRKgrrL
# Q: What is the plating of these earrings?
# A: Gold
# --------------------------------------------------
# Processed: Item_ID: B082PV2QC2 | Image_ID: 61wUklCw4WL
# Q: What is the plating of these earrings?
# A: Rose Gold
# --------------------------------------------------
# Processed: Item_ID: B082Q2PJTQ | Image_ID: 61wzI84iCaL
# Q: What is the color of the AmazonCommercial surge protector?
# A: White
# --------------------------------------------------
# Processed: Item_ID: B082QG4JTD | Image_ID: 61FhkBmO4DL
# Q: What is the material of the sandal's upper?
# A: Fauxleather
# --------------------------------------------------
# Processed: Item_ID: B082QGDFFB | Image_ID: 61zCaj7J2wL
# Q: What is the upper material of this sandal?
# A: Polyurethane
# --------------------------------------------------
# Processed: Item_ID: B082QJYDZN | Image_ID: 81n5NoqHT+L
# Q: What is the type of juice?
# A: Prune
# --------------------------------------------------
# Processed: Item_ID: B082QL5BQV | Image_ID: 516eCtuZjLL
# Q: What is the upper material of this ballet flat?
# A: Mesh
# --------------------------------------------------
# Processed: Item_ID: B082SLPL98 | Image_ID: 71mseHjqkhL
# Q: What is the material of this wallet?
# A: Leather
# --------------------------------------------------
# Processed 260/1000 products
# Processed: Item_ID: B082SZ1NG4 | Image_ID: 51P5axgCh2L
# Q: What is the shape of the lightbulb?
# A: A19
# --------------------------------------------------
# Processed: Item_ID: B082V2QHJ5 | Image_ID: 81N2CKeRCKL
# Q: What is the style of these sandals?
# A: Ivy
# --------------------------------------------------
# Processed: Item_ID: B082VKXXN2 | Image_ID: 91oZoSBNq2L
# Q: What is the chair's upholstery trim material?
# A: Brass
# --------------------------------------------------
# Processed: Item_ID: B082VRVBTT | Image_ID: 51QJyeyy2xL
# Q: What is the type of nut offered in this product?
# A: Pecan
# --------------------------------------------------
# Error processing row 3779: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f4c43145.jpg'
# Processed: Item_ID: B082VT4WGX | Image_ID: 51-sEJEPk6L
# Q: What type of nuts are these?
# A: Macadamia
# --------------------------------------------------
# Processed: Item_ID: B082VZN75G | Image_ID: 61HrrXYWsML
# Q: What is the size of these brownies?
# A: Two-Bite
# --------------------------------------------------
# Processed: Item_ID: B082WN2HYS | Image_ID: 91sSBti-QqL
# Q: What is the upholstery color of the Stone & Beam Hillman Ottoman?
# A: Fog
# --------------------------------------------------
# Processed: Item_ID: B082XBGYNQ | Image_ID: 91U+IR5wYIL
# Q: What is the style of this wall art?
# A: Modern
# --------------------------------------------------
# Processed: Item_ID: B082XLGHKK | Image_ID: 61AHX9W03-L
# Q: What is the lamp's shade material?
# A: Metal
# --------------------------------------------------
# Processed: Item_ID: B082YNJ1N1 | Image_ID: 51YD1Wnk7XL
# Q: What is the finish of the Movian desk?
# A: Melamine
# --------------------------------------------------
# Error processing row 3786: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe04d775.jpg'
# Processed 270/1000 products
# Processed: Item_ID: B082ZQDRN4 | Image_ID: 61zFy70KXQL
# Q: What is the base type of this LED light bulb?
# A: B11
# --------------------------------------------------
# Processed: Item_ID: B0831RWSXX | Image_ID: 91IjC0-JviL
# Q: What is the color of the AmazonBasics Lightning to USB A cable?
# A: White
# --------------------------------------------------
# Processed: Item_ID: B0831Y1G6Y | Image_ID: 91sqcLcDy-L
# Q: What is the upholstery material of the Stone & Beam Lyon chair?
# A: Polyester
# --------------------------------------------------
# Processed: Item_ID: B08331JSDD | Image_ID: 61eN9yGEsjL
# Q: What is the preparation of the apples in this container?
# A: Sliced
# --------------------------------------------------
# Processed: Item_ID: B08337TLFH | Image_ID: 71RKxeYv8qL
# Q: What is the finish of the AmazonCommercial door closer?
# A: Bronze
# --------------------------------------------------
# Processed: Item_ID: B08339HG8X | Image_ID: 71DUxYy1MnL
# Q: What is the type of sole on these sandals?
# A: Flatform
# --------------------------------------------------
# ...
# --------------------------------------------------
# Processed: Item_ID: B08563PDP3 | Image_ID: 61hwn90PSvL
# Q: What is the primary color of the phone case design?
# A: Blue
# --------------------------------------------------
# Processed: Item_ID: B08563PLH5 | Image_ID: 618HYiLsOQL
# Q: What is the design of the phone case?
# A: Floral
# --------------------------------------------------
# Processed 850/1000 products
# Processed: Item_ID: B08563QCZS | Image_ID: 61kYwKmj3oL
# Q: What is the material of this phone case?
# A: TPU
# --------------------------------------------------
# Processed: Item_ID: B08563QRVQ | Image_ID: 61xYh32hfCL
# Q: What is the design of the phone case?
# A: DJ
# --------------------------------------------------
# Processed: Item_ID: B08563R6YC | Image_ID: 71cosLEFniL
# Q: What is the design style of this phone case?
# A: Wooden
# --------------------------------------------------
# Processed: Item_ID: B08563RQ1R | Image_ID: 61LznUZmFnL
# Q: What is the design printed on this phone case?
# A: DJ
# --------------------------------------------------
# Processed: Item_ID: B08563SR9L | Image_ID: 51Qsar7jqwL
# Q: What is the phone case's design style?
# A: King
# --------------------------------------------------
# Processed: Item_ID: B08563SR9P | Image_ID: 617ZyI3YI5L
# Q: What material is the Realme C3 phone case made of?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08563SRX5 | Image_ID: 61K-85pYVqL
# Q: What is the design printed on the phone case?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B08563T1XQ | Image_ID: 61kbPn+xNBL
# Q: What is the phone case's design?
# A: Eiffeltower
# --------------------------------------------------
# Processed: Item_ID: B08563T1ZV | Image_ID: 613X+3ujqDL
# Q: What is the design featured on this phone case?
# A: Monogram
# --------------------------------------------------
# Processed: Item_ID: B08563T4VS | Image_ID: 61GfKd7ldtL
# Q: What is the design printed on this phone case?
# A: Floral
# --------------------------------------------------
# Processed 860/1000 products
# Processed: Item_ID: B08563VVYZ | Image_ID: 61y78Mr3ZOL
# Q: What is the phone case design?
# A: Cupcakes
# --------------------------------------------------
# Error processing row 4416: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f3/f3c7f672.jpg'
# Processed: Item_ID: B08563W5Q5 | Image_ID: 51q0FacF0XL
# Q: What is the phone case's design style?
# A: Multicolored
# --------------------------------------------------
# Processed: Item_ID: B08563WRPC | Image_ID: 61JtnotA7GL
# Q: What is the phone case's design style?
# A: Girlie
# --------------------------------------------------
# Processed: Item_ID: B08563XL1H | Image_ID: 61gKqRv3U+L
# Q: What is the phone case's design style?
# A: Colorful
# --------------------------------------------------
# Processed: Item_ID: B08563XYR1 | Image_ID: 51vvsxIhzBL
# Q: What is the phone case's design style?
# A: Geometric
# --------------------------------------------------
# Processed: Item_ID: B08563Y4Y5 | Image_ID: 71H-HeuA6SL
# Q: What is the design of the phone case's back?
# A: Alphabet
# --------------------------------------------------
# Processed: Item_ID: B0856411BF | Image_ID: 71iAqSrxWTL
# Q: What is the style of the phone case design?
# A: Illustrated
# --------------------------------------------------
# Processed: Item_ID: B085641D4Y | Image_ID: 61jozQcrSBL
# Q: What material is the Poco X2 phone case made of?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B085642621 | Image_ID: 51uJ1PeORZL
# Q: What is the design style of this phone case?
# A: Girlie
# --------------------------------------------------
# Processed: Item_ID: B085643GS9 | Image_ID: 61zDSUB3lJL
# Q: What is the phone case's design style?
# A: Multicolored
# --------------------------------------------------
# Processed 870/1000 products
# Processed: Item_ID: B085643LK1 | Image_ID: 71oF9zrLqkL
# Q: What is the primary design feature of this phone case?
# A: Denim
# --------------------------------------------------
# Processed: Item_ID: B08564437S | Image_ID: 61hnNiqbvLL
# Q: What is the phone case's design?
# A: Multicolored
# --------------------------------------------------
# Error processing row 4428: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ff/ffc956a9.jpg'
# Processed: Item_ID: B085649FLX | Image_ID: 61xg7Z7qcaL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B08568M3M4 | Image_ID: 51wiRu6gT9L
# Q: What is the design pattern of the phone case?
# A: Butterfly
# --------------------------------------------------
# Processed: Item_ID: B08568SRTV | Image_ID: 7108qXMQYqL
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B08568STWD | Image_ID: 71ArsDKqabL
# Q: What is the platform material of this scale?
# A: Aluminium
# --------------------------------------------------
# Processed: Item_ID: B08568ZZG3 | Image_ID: 81+ySIzdeLL
# Q: What is the case's material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B0856918GR | Image_ID: 61+woWTqkwL
# Q: What is the material of this phone case?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569219F | Image_ID: 71yVXgZusSL
# Q: What is the design style of the phone case?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B0856921KD | Image_ID: 51wiRu6gT9L
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Error processing row 4437: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f7b424a1.jpg'
# Processed 880/1000 products
# Processed: Item_ID: B085695JZ3 | Image_ID: 81M-5Yju4zL
# Q: What is the design of the phone case?
# A: Marble
# --------------------------------------------------
# Processed: Item_ID: B085695K3G | Image_ID: 61+woWTqkwL
# Q: What is the primary design feature of this phone case?
# A: Pattern
# --------------------------------------------------
# Processed: Item_ID: B085695K5T | Image_ID: 51wiRu6gT9L
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B0856963SR | Image_ID: 81OcEyKsibL
# Q: What is the phone case's design style?
# A: Glitter
# --------------------------------------------------
# Processed: Item_ID: B0856966Y2 | Image_ID: 71eBUYFKP6L
# Q: What is the print style of this phone case?
# A: Pattern
# --------------------------------------------------
# Processed: Item_ID: B08569673H | Image_ID: 71MeAQMqeZL
# Q: What is the design of this phone case?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B08569676K | Image_ID: 71hP64fsYpL
# Q: What is the print style of the phone case?
# A: Pattern
# --------------------------------------------------
# Processed: Item_ID: B0856967RS | Image_ID: 61KxmdnZd9L
# Q: What is the phone case material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B0856972GC | Image_ID: 71oRDuMuRqL
# Q: What is the pattern on the phone case?
# A: Butterfly
# --------------------------------------------------
# Processed: Item_ID: B085697CR3 | Image_ID: 71o3+LmZIVL
# Q: What is the design style of the phone case?
# A: Rangoli
# --------------------------------------------------
# Processed 890/1000 products
# Processed: Item_ID: B085697D3G | Image_ID: 71ZhxSPHKzL
# Q: What is the phone case material?
# A: Silicone
# --------------------------------------------------
# Error processing row 4449: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ed/edf34437.jpg'
# Processed: Item_ID: B08569916Z | Image_ID: 51wiRu6gT9L
# Q: What is the case's primary material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B085699LST | Image_ID: 61+woWTqkwL
# Q: What is the case's material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B085699LVQ | Image_ID: 71LJFDcoduL
# Q: What is the design featured on this phone case?
# A: Punisher
# --------------------------------------------------
# Processed: Item_ID: B085699VBL | Image_ID: 719nCF4cjgL
# Q: What is the design style of the phone case?
# A: Floral
# --------------------------------------------------
# Error processing row 4454: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ef/ef509415.jpg'
# Processed: Item_ID: B08569BCC5 | Image_ID: 71xPv55lgJL
# Q: What is the case material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569BCR1 | Image_ID: 710Uwk1p96L
# Q: What is the phone case material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569BFFJ | Image_ID: 81W0pBkKdXL
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569BGZQ | Image_ID: 81GFTbYG7RL
# Q: What is the case's primary design theme?
# A: Motorcycle
# --------------------------------------------------
# Processed: Item_ID: B08569BHD9 | Image_ID: 61+woWTqkwL
# Q: What is the phone case's material?
# A: Silicon
# --------------------------------------------------
# Processed 900/1000 products
# Processed: Item_ID: B08569BLD8 | Image_ID: 61+woWTqkwL
# Q: What is the material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569BPYB | Image_ID: 71Lw8ZXhKOL
# Q: What is the case material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569CWLB | Image_ID: 71MbNyWz3+L
# Q: What is the design featured on this phone case?
# A: Butterflies
# --------------------------------------------------
# Processed: Item_ID: B08569CWTW | Image_ID: 61+woWTqkwL
# Q: What is the phone case's primary material?
# A: Silicon
# --------------------------------------------------
# Error processing row 4464: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f1/f16e6924.jpg'
# Processed: Item_ID: B08569DDMR | Image_ID: 61+woWTqkwL
# Q: What is the design printed on this phone case?
# A: Butterflies
# --------------------------------------------------
# Processed: Item_ID: B08569DJS9 | Image_ID: 61+woWTqkwL
# Q: What is the primary material of this phone case?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569DK2X | Image_ID: 61+woWTqkwL
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569DWLL | Image_ID: 71NVydU3FfL
# Q: What is the case's material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569DZ8K | Image_ID: 71K2+Ch-SlL
# Q: What is the phone case's design style?
# A: Printed
# --------------------------------------------------
# Processed: Item_ID: B08569FR43 | Image_ID: 71p6n6xT00L
# Q: What is the design style of the phone case?
# A: Multicolor
# --------------------------------------------------
# Processed 910/1000 products
# Processed: Item_ID: B08569FRG7 | Image_ID: 710gxCy5w6L
# Q: What is the design style of the phone case?
# A: Amethyst
# --------------------------------------------------
# Processed: Item_ID: B08569GJ1Y | Image_ID: 51wiRu6gT9L
# Q: What is the primary material of this phone case?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B08569GPKW | Image_ID: 81fnCckeR3L
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569J9YG | Image_ID: 81mqLuCbrmL
# Q: What is the primary material of this phone case?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569JHYD | Image_ID: 613R9v6NRjL
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569KBBC | Image_ID: 81+puzZAtvL
# Q: What is the printed design on this phone case?
# A: Wooden
# --------------------------------------------------
# Processed: Item_ID: B08569KRV9 | Image_ID: 61+woWTqkwL
# Q: What is the phone case's primary design feature?
# A: Pattern
# --------------------------------------------------
# Processed: Item_ID: B08569KTB7 | Image_ID: 7182mtI6hJL
# Q: What is the print style of the phone case?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B08569KVW9 | Image_ID: 71waP6G4UmL
# Q: What is the material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569L4MV | Image_ID: 81lKWvwFcFL
# Q: What is the printed design on the phone case?
# A: Wooden
# --------------------------------------------------
# Processed 920/1000 products
# Processed: Item_ID: B08569L691 | Image_ID: 81hAIXq-TEL
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569L6D5 | Image_ID: 71huwW25fpL
# Q: What is the primary material of this phone case?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569LD5P | Image_ID: 818-ohQvysL
# Q: What is the case's material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569LDFM | Image_ID: 51wiRu6gT9L
# Q: What is the case's material?
# A: Plastic
# --------------------------------------------------
# Processed: Item_ID: B08569LGYD | Image_ID: 71ZMv0q-aBL
# Q: What is the design of this phone case?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B08569LGZJ | Image_ID: 71gT-7U8-vL
# Q: What is the case's print design?
# A: Floral
# --------------------------------------------------
# Processed: Item_ID: B08569LLKL | Image_ID: 61F4TPCU1rL
# Q: What is the phone case's design pattern?
# A: Stars
# --------------------------------------------------
# Processed: Item_ID: B08569LTMS | Image_ID: 71ihc3+nVFL
# Q: What is the design style of this phone case?
# A: Vector
# --------------------------------------------------
# Processed: Item_ID: B08569LTQN | Image_ID: 719IKAMSVpL
# Q: What is the design style of the phone case?
# A: Scenic
# --------------------------------------------------
# Error processing row 4490: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fb474a46.jpg'
# Processed: Item_ID: B08569MFYF | Image_ID: 715XtczRIKL
# Q: What is the design style of the phone case?
# A: Wooden
# --------------------------------------------------
# Processed 930/1000 products
# Processed: Item_ID: B08569MFYJ | Image_ID: 712+ka0HsnL
# Q: What is the print design on this phone case?
# A: Peacock
# --------------------------------------------------
# Processed: Item_ID: B08569MGDM | Image_ID: 71zMb0bfMLL
# Q: What is the case material?
# A: Silicon
# --------------------------------------------------
# Processed: Item_ID: B08569MGF7 | Image_ID: 61+woWTqkwL
# Q: What is the phone case's print design?
# A: Butterflies
# --------------------------------------------------
# Processed: Item_ID: B08569MHS1 | Image_ID: 61+woWTqkwL
# Q: What is the phone case material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569MHVH | Image_ID: 71FP7S1vmbL
# Q: What is the phone case's material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569MJY4 | Image_ID: 71xkhY6B6zL
# Q: What is the case material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569MS5W | Image_ID: 61+woWTqkwL
# Q: What is the phone case material?
# A: Silicone
# --------------------------------------------------
# Processed: Item_ID: B08569MVJN | Image_ID: 61+woWTqkwL
# Q: What is the print design on the phone case?
# A: Butterflies
# --------------------------------------------------
#
# Reached limit of 1000 API calls.
# Stopped at index 4500, Item_ID: B08569N14Q
# To continue processing, set start_index = 4500
#
# Processing complete!
# Total products processed: 937
# Errors: 63
# Results saved to qna4.csv
# Next start_index to continue: 4500

# %%
import pandas as pd

# Load the CSV file
file_path = "qna4.csv"
df = pd.read_csv(file_path)

# Remove the last 3 rows
df = df[:-3]

# Save the updated dataframe back to the CSV file
df.to_csv(file_path, index=False)

print("Last 3 lines have been deleted from qna4.csv.")
# Out:
# Last 3 lines have been deleted from qna4.csv.

# %%
""" API call with refined instruction prompt and complete json metadata using chain-of-thought """

import time
import json
import os
import glob
import pandas as pd
from PIL import Image
import google.generativeai as genai

# Set your Gemini API key
api_key = "AIzaSyC70OLGkkGuIwHnMzjPTOt2Bd44MHu9tAA"
genai.configure(api_key=api_key)

# Define the starting index (can be changed before running)
start_index = 0  # Change this value to continue from where you left off

# Load merged CSV
merged_path = "Datasets/filtered_merged_output.csv"
merged_df = pd.read_csv(merged_path)

# Filter to get one image per product, preferring "main" role
unique_products_df = pd.DataFrame()

# Group by item_id
grouped = merged_df.groupby("item_id")

# For each product, get the "main" image or the first one if no main exists
for item_id, group in grouped:
    main_images = group[group["role"] == "main"]
    if len(main_images) > 0:
        # Take the first main image
        unique_products_df = pd.concat([unique_products_df, main_images.iloc[[0]]])
    else:
        # If no main image, take the first image
        unique_products_df = pd.concat([unique_products_df, group.iloc[[0]]])

# Reset index
unique_products_df = unique_products_df.reset_index(drop=True)

# Initialize model
model = genai.GenerativeModel("gemini-1.5-flash")

# Create counter for progress tracking
total_products = len(unique_products_df)
processed_count = 0
error_count = 0
max_api_calls = 1000  # Limit to 1000 API calls

print(f"Found {total_products} unique products")
print(f"Starting processing from index {start_index} up to {max_api_calls} products...")

# Process each row in the filtered DataFrame, starting from the specified index
for index, row in unique_products_df.iloc[start_index:].iterrows():
    # Check if we've reached the API call limit
    if processed_count + error_count >= max_api_calls:
        print(f"\nReached limit of {max_api_calls} API calls.")
        print(f"Stopped at index {index}, Item_ID: {row['item_id']}")
        print(f"To continue processing, set start_index = {index}")
        break
        
    try:
        # Extract image information
        image_id = row["image_id"]
        image_dir = "Datasets/small"
        image_path = os.path.join(image_dir, row["path"])
        item_id = row["item_id"]
        
        # Load the image
        image = Image.open(image_path)
        
        # Search all JSON files for metadata of the item_id
        metadata = None
        for json_file in glob.glob("Datasets/listings_*.json"):
            with open(json_file, "r", encoding="utf-8") as f:
                for line in f:
                    doc = json.loads(line)
                    if doc.get("item_id") == item_id:
                        metadata = doc
                        break
            if metadata:
                break
        
        if metadata is None:
            print(f"Warning: Metadata for item_id {item_id} not found. Skipping.")
            error_count += 1
            continue
        
        # Chain of thought prompting
        prompt = f"""Based on the provided product image and metadata, I want you to generate a specific customer question about this product that can be answered with a single word, along with the appropriate answer. Let's think through this step by step:

Step 1: Analyze what type of product this is.
Look carefully at the image and examine the metadata. What category does this product belong to? What are its key features, materials, and purpose?

Step 2: Consider what aspects customers typically care about for this product category.
Based on the product type identified in Step 1, what are the top 3-4 concerns or questions that customers typically have? Consider aspects like material, functionality, compatibility, care instructions, or special features.

Step 3: Determine which question would be most relevant and specific to THIS PARTICULAR product.
From the aspects identified in Step 2, which one would be most important to a customer considering this specific product? Formulate a clear, specific question that can be answered with a single word (typically Yes or No).

Step 4: Determine the most accurate answer based on what's visible in the image and described in the metadata.
Based on the product details available, what is the correct single-word answer to the question formulated in Step 3?

Step 5: Verify that your question is NOT about phone case compatibility with specific models.

Based on this analysis, provide your final output in exactly this format:
Question: [your specific, relevant customer question]
Answer: [single-word answer]

Metadata: {json.dumps(metadata, indent=2)}"""
        
        # Gemini API call
        response = model.generate_content(
            [prompt, image],
            stream=False
        )
        
        # Extract just the question and answer from the response
        response_text = response.text
        question = None
        answer = None
        
        # Process the response to extract just the final Q&A
        in_final_output = False
        for line in response_text.split("\n"):
            if "Question:" in line and "Answer:" not in line:  # Ensure we're not capturing "Question:" from the prompt
                question = line[line.find("Question:") + len("Question:"):].strip()
                in_final_output = True
            elif "Answer:" in line and in_final_output:
                answer = line[line.find("Answer:") + len("Answer:"):].strip()
                break
        
        # If direct extraction failed, try a more general approach
        if question is None or answer is None:
            for line in response_text.split("\n"):
                if line.startswith("Question:"):
                    question = line[len("Question:"):].strip()
                elif line.startswith("Answer:"):
                    answer = line[len("Answer:"):].strip()
        
        if question and answer:
            # Create a dictionary with the data to save
            data = {
                'Image_ID': [image_id],
                'Item_ID': [item_id],
                'Question': [question],
                'Answer': [answer]
            }
            
            # Convert to DataFrame
            df = pd.DataFrame(data)
            
            # Check if file exists
            file_exists = os.path.isfile('qna4.csv')
            
            # Save to CSV (append if file exists, create with header if it doesn't)
            if file_exists:
                df.to_csv('qna4.csv', mode='a', header=False, index=False)
            else:
                df.to_csv('qna4.csv', index=False)
        
        # Update progress
        processed_count += 1
        if processed_count % 10 == 0:
            print(f"Processed {processed_count}/{max_api_calls} products")
        
        # Short summary of the current item
        print(f"Processed: Item_ID: {item_id} | Image_ID: {image_id}")
        print(f"Q: {question}")
        print(f"A: {answer}")
        print("-" * 50)
        
        # Pause between API calls to avoid rate limits
        time.sleep(1.0)  # 1 second pause between calls
        
    except Exception as e:
        error_count += 1
        print(f"Error processing row {index}: {str(e)}")
        # Continue with the next image even if there's an error
        continue

print(f"\nProcessing complete!")
print(f"Total products processed: {processed_count}")
print(f"Errors: {error_count}")
print(f"Results saved to qna4.csv")
print(f"Next start_index to continue: {start_index + processed_count + error_count}")
# Out:
# Found 4923 unique products
# Starting processing from index 0 up to 1000 products...
# Processed: Item_ID: B00004SD6V | Image_ID: 51JKXD3XTJL
# Q: Is the trowel rustproof?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00005041B | Image_ID: 41ZZFRX9TXL
# Q: Are bulbs included?
# A: Yes
# --------------------------------------------------
# Error processing row 2: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/eeeea998.jpg'
# Error processing row 3: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fbf7478f.jpg'
# Processed: Item_ID: B000GXF4UC | Image_ID: 51jNv-Fzw6L
# Q: Is this sun lounger foldable?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B000HBVO5W | Image_ID: 516VDAEVA4L
# Q: Is this a set of two chairs?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000HVGJMK | Image_ID: 413YDDWEAEL
# Q: Is this table suitable for outdoor use?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000MCL43I | Image_ID: 713v9AKCvqS
# Q: Does this lopper have telescoping handles?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000NDMNM2 | Image_ID: 81f0OiJYMzS
# Q: Is the screwdriver set magnetic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000NLWQ8A | Image_ID: 81PCECJ1NJS
# Q: Does this impact driver include a battery?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B000QIZWZ4 | Image_ID: A1lP0-Be90S
# Q: Is this a throw blanket?
# A: Yes
# --------------------------------------------------
# Error processing row 11: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe3e0aea.jpg'
# Processed 10/1000 products
# Processed: Item_ID: B000S6MJ9Q | Image_ID: 71X7P5sJPdL
# Q: Are these chairs all-weather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000T2R958 | Image_ID: 910nH4EG9BS
# Q: Is it machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000T2UXLU | Image_ID: A1Ur9cRpreS
# Q: Is this bath rug machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000T38VF4 | Image_ID: 71HHXWZ5pvS
# Q: Are these pillows jumbo-sized?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000UD8EC8 | Image_ID: 81pHp40SARS
# Q: Is this bowl set dishwasher-safe?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000W4G3RS | Image_ID: 91CA9Pud25S
# Q: Is this a featherbed?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B000W7C7PC | Image_ID: 91TFZG1n+SS
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Error processing row 19: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ef/ef4943aa.jpg'
# Processed: Item_ID: B000W9F8F6 | Image_ID: 81OUleNhfnS
# Q: Is this coffee table suitable for outdoor use?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0010SSE0E | Image_ID: 91Wagj9HaJS
# Q: Is this cushion set fade-resistant?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0013EDQV2 | Image_ID: 81pMc4G8VaS
# Q: Is this a set of two pillowcases?
# A: Yes
# --------------------------------------------------
# Processed 20/1000 products
# Processed: Item_ID: B0013EE61G | Image_ID: 91tatUg6bxS
# Q: Is this sheet set made of 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0013TXCVG | Image_ID: A1T8kWgrQ5S
# Q: Is this sheet set pre-washed?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001719KE8 | Image_ID: 81k4AFpFPOS
# Q: Is this a set of two pillowcases?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001BQ3FXG | Image_ID: 61LVCnMvfDS
# Q: Does this wine rack have a flip-down work surface?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001CGMKA4 | Image_ID: 91vSGg5+OWL
# Q: Is this pasta maker made of stainless steel?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001CSCXCC | Image_ID: 81++lEoeBOL
# Q: Are these earrings made of gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001CZEWLU | Image_ID: 71Mbqw-tydL
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B001DA109Q | Image_ID: 51BYlMrob5L
# Q: Is this rug machine-washable?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B001E4T232 | Image_ID: 81M+S4Av7gS
# Q: Is this duvet set 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001LF4I6U | Image_ID: 91QYyWEPMbL
# Q: Is this rug machine washable?
# A: No
# --------------------------------------------------
# Processed 30/1000 products
# Processed: Item_ID: B001R23YG2 | Image_ID: 310GoXdHCyL
# Q: Is the cushion cover removable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001TH7GV4 | Image_ID: 81AE7--x3eL
# Q: Is this a USB 2.0 cable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B001TODUXA | Image_ID: 81lJaYh62qL
# Q: Are these DVD+R discs?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00200K8Q4 | Image_ID: 81iToPUK2hL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00200K954 | Image_ID: 71JNmxxeXbL
# Q: Is this bracelet made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0028K3CRI | Image_ID: 61USLFSsmeL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0028N6Q3C | Image_ID: 61OcPKD6gpL
# Q: Are these earrings made of sterling silver?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B0028N6SVC | Image_ID: 91rJEpNfR6L
# Q: Is it reversible?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B002BA5NLI | Image_ID: 71bqW7G2gZL
# Q: Are these earrings 8mm?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B002DMKKCG | Image_ID: 51p9GYrlolL
# Q: Are these earrings made of sterling silver?
# A: No
# --------------------------------------------------
# Processed 40/1000 products
# Processed: Item_ID: B002HEXKDQ | Image_ID: 613lQk1WRKL
# Q: Is this a twin-sized mattress pad?
# A: Yes
# --------------------------------------------------
# Error processing row 44: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f54c925e.jpg'
# Processed: Item_ID: B002SSU31S | Image_ID: 31lWkH5uqlL
# Q: Is this a cyan ink cartridge?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B002SSU354 | Image_ID: 410TfwzoI5L
# Q: Is this a remanufactured cartridge?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B002TLTE6Y | Image_ID: 41kLuvcfuYL
# Q: Does this mount support TVs from 34 to 65 inches?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B002TOL5WW | Image_ID: 71iTK-elOlL
# Q: Are these earrings made of sterling silver?
# A: No
# --------------------------------------------------
# Error processing row 49: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f9d2c8f6.jpg'
# Processed: Item_ID: B002VPE1XE | Image_ID: 81QGrQZfedL
# Q: Is this a waterproof camera case?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B002VPE21A | Image_ID: 8126R94nLNL
# Q: Is it leather?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B003BHLWX8 | Image_ID: 81quKVVB6YL
# Q: Is this peanut butter creamy?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B003DZ16MU | Image_ID: 71g6VYkrixL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B003JBHRCG | Image_ID: 41iQsxrNSKL
# Q: Is this mount suitable for a 42-inch TV?
# A: Yes
# --------------------------------------------------
# Processed 50/1000 products
# Processed: Item_ID: B003QP2ZBI | Image_ID: 81pEa1trlVL
# Q: Is this a duvet cover?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B003S9W4Y0 | Image_ID: 31SkolLRXXL
# Q: Is this a Queen-size sheet set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B004JZXQBC | Image_ID: 71Uh-qAxQFL
# Q: Is this necklace silver-toned?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B004LH885W | Image_ID: 418hEmkNgOL
# Q: Is this calculator solar-powered?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B005CGK7HS | Image_ID: 71KX1wKCOUL
# Q: Is this a set of pillow shams?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B005CGKANE | Image_ID: 91O4qdlRq7L
# Q: Is this a king-size pillow sham?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B005DJABUC | Image_ID: 71ToUR8CjpL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B005DJAE3G | Image_ID: 619w2uN+34L
# Q: Is this necklace 30 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B005DJCDDK | Image_ID: 71kWUIT0adL
# Q: Is this bracelet made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B005GU9WYO | Image_ID: 71xHMyh6xgL
# Q: Is this necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed 60/1000 products
# Processed: Item_ID: B005NXS5K6 | Image_ID: 71qqzH4OlvL
# Q: Are these cufflinks sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B006YQBKE4 | Image_ID: 81oeFt8DSlL
# Q: Does this bundle include a car charger?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0077W953C | Image_ID: 61JH-ADHBpL
# Q: Is this ring made of stainless steel?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B007K6SGE4 | Image_ID: 810Kj2rQvRL
# Q: Is this sheet set machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B007P0WNF8 | Image_ID: 71EeDQWVzRL
# Q: Is this towel machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B007VK6DPS | Image_ID: 71H3giEOYvL
# Q: Is this necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B008U4QR64 | Image_ID: 71OQeuqgv4L
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B008YRJRWS | Image_ID: 91xzijerDcL
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00933MTOA | Image_ID: 71v45ZaFdBL
# Q: Is this necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0093UQQKG | Image_ID: 71U7KhGt-OL
# Q: Are these earrings made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed 70/1000 products
# Processed: Item_ID: B009A6AVIQ | Image_ID: 517XC3JxuML
# Q: Are these cufflinks engravable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00A73FWTE | Image_ID: 710AKGWCMZL
# Q: Is this changing pad cover machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00ADGNVLG | Image_ID: 81pqKA1+zCL
# Q: Is this product machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00AH83EGW | Image_ID: 912EXwoZVtL
# Q: Are these kneepads for adults?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00BS55MEU | Image_ID: 81ECoZyj8BL
# Q: Is this sheet set machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00CF1LS94 | Image_ID: 71RB8g5fYVL
# Q: Is this tripod's maximum load capacity 5kg?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00CF5OHZ2 | Image_ID: 810LF3yyORL
# Q: Is this bag waterproof?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00D2VUOU0 | Image_ID: 71objFyTkEL
# Q: Is this cover waterproof?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00DHPCVQG | Image_ID: 71C6zJAsyDL
# Q: Is this tripod portable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00E5AORF0 | Image_ID: 81H9JPTN9pL
# Q: Is this quilt dry clean only?
# A: Yes
# --------------------------------------------------
# Processed 80/1000 products
# Processed: Item_ID: B00E7NQVS6 | Image_ID: 612SiLTE18L
# Q: Are napkins included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00EN9Q35A | Image_ID: 51DNUIUHSlL
# Q: Is the camera bag weatherproof?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00EQ5F3TI | Image_ID: A16ehge6dHL
# Q: Is this a duvet cover set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00EQ5FU28 | Image_ID: 81QgX+LlUWL
# Q: Is this bedding set made of 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00EQ5FVXG | Image_ID: 81QgX+LlUWL
# Q: Is this duvet cover set 100% cotton?
# A: Yes
# --------------------------------------------------
# Error processing row 90: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe5df387.jpg'
# Processed: Item_ID: B00EQ5J4WA | Image_ID: 41BN-15C6YL
# Q: Is this a 100% cotton towel set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00EQ5JETS | Image_ID: 51ChbcDaYNL
# Q: Is this a set of bath towels?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00FRIJAZ6 | Image_ID: 71Nl11r7lHL
# Q: Is this bracelet platinum plated?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00FXW73R8 | Image_ID: 6115aUrt-EL
# Q: Is this ring platinum?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00FXW78Q4 | Image_ID: 711Y9OtyXQL
# Q: Is this ring size 6?
# A: Yes
# --------------------------------------------------
# Processed 90/1000 products
# Processed: Item_ID: B00FXW78T6 | Image_ID: 81dLOcof99L
# Q: Is this ring size 7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00FXW7KFS | Image_ID: 818mkxbvzKL
# Q: Is this ring size 7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00GS5YDT0 | Image_ID: 71mYLRit-gL
# Q: Is this hub bus-powered?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00GYVBQU2 | Image_ID: 710OjSZwy6L
# Q: Is this product dishwasher safe?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00H7P1H2G | Image_ID: 71IYPIYj0jL
# Q: Is this garment rack mobile?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00IAGZ3VC | Image_ID: 911jqy7Ft2L
# Q: Is this a reversible coverlet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00IAGZ696 | Image_ID: 81pnsVDzFnL
# Q: Is this sham reversible?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00IAHJGJQ | Image_ID: 91gCwN7GNML
# Q: Is this pillow sham machine washable?
# A: Yes
# --------------------------------------------------
# Error processing row 104: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f86e86bd.jpg'
# Processed: Item_ID: B00JB7K332 | Image_ID: 71BJDK9aS+L
# Q: Is the necklace gold-toned?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00JNC6VJ0 | Image_ID: 61pJQ84OszL
# Q: Are these earrings made of 10k yellow gold?
# A: Yes
# --------------------------------------------------
# Processed 100/1000 products
# Processed: Item_ID: B00JO92GSM | Image_ID: 51PywSx5qRL
# Q: Is this a rigid phone case?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00JQFHS9Q | Image_ID: 61h6Z1OxhML
# Q: Are these earrings made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00JVEOFKW | Image_ID: 61h6Z1OxhML
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00KE2EWPI | Image_ID: 81n7x-dvbgL
# Q: Is this necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00L3KSP08 | Image_ID: 716uy5PewML
# Q: Does this product include a microphone?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00LD1L7K2 | Image_ID: 81IIo6jgI9L
# Q: Is it made of real leather?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00LFIZ8HG | Image_ID: 81AFnFZGwDL
# Q: Is this cover waterproof?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00LP8G4HE | Image_ID: 81CXCgIxmHL
# Q: Is this a twin-sized bed set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00M3E2BC6 | Image_ID: 81L4iacmoaL
# Q: Are these size 2 diapers?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00M92NIKQ | Image_ID: 81kvKlB2VhL
# Q: Is this fitted sheet made of 100% microfiber polyester?
# A: Yes
# --------------------------------------------------
# Processed 110/1000 products
# Processed: Item_ID: B00M92OHXS | Image_ID: 81kvKlB2VhL
# Q: Is this fitted sheet made of microfiber?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00M92Q182 | Image_ID: 91tXgMOPq6L
# Q: Is this fitted sheet made of microfiber?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MCK34HW | Image_ID: 81mqvUme1EL
# Q: Is this necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00ME4O092 | Image_ID: 81SV-DEd4kL
# Q: Are these boots made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MFQ4U9E | Image_ID: 91ZIp1MPQnL
# Q: Is this hoodie a unisex size?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MGSEZ9G | Image_ID: 81eiC7TMqsL
# Q: Is this a fitted sheet?
# A: Yes
# --------------------------------------------------
# Error processing row 123: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb5e031e.jpg'
# Processed: Item_ID: B00MGSJWZS | Image_ID: 81witFRk24L
# Q: Is this a fitted sheet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MGSKHS4 | Image_ID: 81witFRk24L
# Q: Is this sheet set made of 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MGSKP54 | Image_ID: 81PyVQ-9VxL
# Q: Is this fitted sheet 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MHUX6RK | Image_ID: A16besR2naL
# Q: Is this a fitted sheet?
# A: Yes
# --------------------------------------------------
# Processed 120/1000 products
# Processed: Item_ID: B00MHUZMO0 | Image_ID: A11iXjPIJxL
# Q: Is this a fitted sheet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MHV0PLO | Image_ID: A1AFTjFpqiL
# Q: Is this fitted sheet machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MIIDMR0 | Image_ID: A16besR2naL
# Q: Is this a king-size fitted sheet?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00MISYJ0O | Image_ID: 719FpBrhjZL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MJKZH7K | Image_ID: 41WRVs9OMDL
# Q: Is this a 3-pack?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MPFTE6Y | Image_ID: 91yTxs3q12L
# Q: Is this a fitted sheet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MPFTZ36 | Image_ID: 91yTxs3q12L
# Q: Is this a king-size fitted sheet?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00MPM1MKI | Image_ID: 81R-aDJNDvL
# Q: Is this a king-size fitted sheet?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00MPOB3Q4 | Image_ID: 910EuRVTK9L
# Q: Is this a fitted sheet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00MTKNKW4 | Image_ID: 711m4npForL
# Q: Is this duvet machine washable?
# A: Yes
# --------------------------------------------------
# Error processing row 138: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f7/f7e051bf.jpg'
# Processed 130/1000 products
# Processed: Item_ID: B00NFJPGMA | Image_ID: 71a1n+nymsL
# Q: Is this necklace gold-plated?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00NFSCVCE | Image_ID: 81NB9UHksTL
# Q: Are these earrings rose gold plated?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00NFSD1Z0 | Image_ID: 61BtfrIdq8L
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00NW6VT9A | Image_ID: 81J8yjhNpTL
# Q: Are these earrings imported?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00OZBNZD4 | Image_ID: 71-SesMqeRL
# Q: Is this necklace gold-plated?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00P11JFW2 | Image_ID: 71Pk1ckVXWL
# Q: Is it sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00P2ADDVG | Image_ID: 41fxVdHDCyL
# Q: Is this necklace made of K18YG gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00PBZ104O | Image_ID: 710DyaV81UL
# Q: Are these pearls real?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00Q4O1WJY | Image_ID: 61J8vyAV4fL
# Q: Is this a dual USB wall charger?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00Q69645E | Image_ID: 61xWqmPgFXL
# Q: Is this a king-size sheet?
# A: No
# --------------------------------------------------
# Error processing row 149: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f5d99ba7.jpg'
# Processed 140/1000 products
# Processed: Item_ID: B00Q6EYHW6 | Image_ID: 610xcVEOFsL
# Q: Is this quilt made of 100% polyester?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00Q7OATOK | Image_ID: 71ROFJE-8nL
# Q: Is this a King-size sheet set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00QQ3PSU2 | Image_ID: 81-n4HG6EOL
# Q: Is this duvet cover reversible?
# A: Yes
# --------------------------------------------------
# Error processing row 153: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb2d78ba.jpg'
# Processed: Item_ID: B00R5WABNW | Image_ID: 71twGQUiLpL
# Q: Is this a fitted sheet?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00S13D3GQ | Image_ID: 91AnxOiwm5L
# Q: Is this fire pit cover waterproof?
# A: Yes
# --------------------------------------------------
# Error processing row 156: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fb66d34b.jpg'
# Processed: Item_ID: B00TDNZUYG | Image_ID: 61taksip-+L
# Q: Are these earrings lever-back?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00U24CSZO | Image_ID: 81JUeC3wJ-L
# Q: Is this ring size 8?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00U24D1SM | Image_ID: 810ZxP1gslL
# Q: Is this ring set made of sterling silver?
# A: Yes
# --------------------------------------------------
# Error processing row 160: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0188829.jpg'
# Processed: Item_ID: B00UG9HB1Q | Image_ID: 718l03qCcJL
# Q: Does this safe include mounting hardware?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UYGOJDY | Image_ID: 81EGGDtCsmL
# Q: Are these earrings made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed 150/1000 products
# Processed: Item_ID: B00UYGOKUQ | Image_ID: 71ARUU3CVXL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UYGOMKY | Image_ID: 71LlC8-tnfL
# Q: Is this necklace made in the USA?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UYIHF2Y | Image_ID: 71-PmdvJrfL
# Q: Is this necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UYIHGVO | Image_ID: 71Lhj82OfUL
# Q: Is this necklace made of 14k gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UYIHGXC | Image_ID: 71uv9jxUnsL
# Q: Is this necklace made of 14k gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UZ6LP4E | Image_ID: 914k4jJCNIL
# Q: Is this bedding set made of 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UZ6OZVO | Image_ID: 816at25xySL
# Q: Is this duvet cover set 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00UZ7BYNU | Image_ID: 81cr0K7aTRL
# Q: Is this sheet made of 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00WTHJ5SU | Image_ID: 71Wml0M77qL
# Q: Is this umbrella automatic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00WU06YV2 | Image_ID: 71VHRNgvpqL
# Q: Are these headphones in-ear?
# A: Yes
# --------------------------------------------------
# Error processing row 173: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/ebbcdcaa.jpg'
# Processed 160/1000 products
# Processed: Item_ID: B00XJBH0Z0 | Image_ID: 91q++WbkDtL
# Q: Is this case made of genuine leather?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B00XM2MXK8 | Image_ID: 91Jd94x34uL
# Q: Is this foam roller extra firm?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B00XNMWZK0 | Image_ID: 61EUJ4GgtvL
# Q: Is this a 62mm UV filter?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B010S9N6OO | Image_ID: 613jL3B7XZL
# Q: Is this cable Apple MFi certified?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0111KMJS8 | Image_ID: 81GHDh+D26L
# Q: Is this ring made of metal?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0112W79N0 | Image_ID: 61Nv5S6m5qL
# Q: Are these hangers suitable for children's clothes?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B011YF1OCC | Image_ID: 61GhbiR2zwL
# Q: Are these earrings made of 10K white gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0123UK4JG | Image_ID: 51XnJfZ1mxL
# Q: Is this kadai induction compatible?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B012DAK41Y | Image_ID: 51JWbjb-ZEL
# Q: Is this wok dishwasher safe?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B013R5T9UQ | Image_ID: 41bK-J5aFVL
# Q: Does this blender have a glass jar?
# A: Yes
# --------------------------------------------------
# Processed 170/1000 products
# Processed: Item_ID: B013R5TCYY | Image_ID: 81W4G60iXgL
# Q: Is the carafe made of glass?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B013R5TK3M | Image_ID: 91wuLIZ2dFL
# Q: Is it cordless?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B013R5TNPC | Image_ID: 71R-0Ry6MOL
# Q: Is this blender dishwasher safe?
# A: Yes
# --------------------------------------------------
# Error processing row 187: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fe/fe51de3b.jpg'
# Processed: Item_ID: B013TGFTDY | Image_ID: 81wktL+Yh+L
# Q: Is this laptop sleeve suitable for a 13-inch MacBook Pro?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B013URKH1Q | Image_ID: 81jllsra22L
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0142RWGIK | Image_ID: 717YKcBjuhL
# Q: Is this a leather boot?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0142RX620 | Image_ID: 718iKXnpHGL
# Q: Is this a leather boot?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0142RYEAI | Image_ID: 71qa9wOSeKL
# Q: Are these boots made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01486Q884 | Image_ID: 81J2MUBkuyL
# Q: Is the pom-pom made of real fur?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B014GCABSI | Image_ID: 71BySStH9sL
# Q: Does this bed frame require tools for assembly?
# A: No
# --------------------------------------------------
# Processed 180/1000 products
# Processed: Item_ID: B014IID1P0 | Image_ID: 91b9p1-YdUL
# Q: Is this a 100% cotton towel set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B014RGOD3C | Image_ID: 41ez2qR7pPL
# Q: Is the bedding set 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B014VBGUCA | Image_ID: 71zr1Avln1L
# Q: Is this a set of four packing cubes?
# A: Yes
# --------------------------------------------------
# Error processing row 198: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/e8/e8d6b4b3.jpg'
# Processed: Item_ID: B014WC3CMY | Image_ID: 61cgNrJJ0jL
# Q: Is this ring size 5?
# A: Yes
# --------------------------------------------------
# Error processing row 200: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fb4021f2.jpg'
# Processed: Item_ID: B0152PBTRK | Image_ID: 51frkGfSm5L
# Q: Is the included cable 6 feet long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0152W544C | Image_ID: 51aHe07TufL
# Q: Is the case compatible with an iPhone 6?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015FNGR26 | Image_ID: 81I9A+lDruL
# Q: Is this a 100% silk pocket square?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015FWU5MK | Image_ID: 71uDw9bTBrL
# Q: Is this ring size 7?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015FWUD68 | Image_ID: 712ngRWlDGL
# Q: Is this ring made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015GJ25KC | Image_ID: 81XXqvhcB9L
# Q: Is this coffee organic?
# A: Yes
# --------------------------------------------------
# Processed 190/1000 products
# Processed: Item_ID: B015GK1AJI | Image_ID: 91vW8DEk2VL
# Q: Is this trail mix resealable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015GK1HFA | Image_ID: 81zMNzA8UJL
# Q: Is this bag resealable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015I37A9W | Image_ID: 71aPqwwhZuL
# Q: Is it MFi certified?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015N8FT5Y | Image_ID: 815iFdEfbyL
# Q: Is this tie made of silk?
# A: Yes
# --------------------------------------------------
# Error processing row 211: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0fb95df.jpg'
# Error processing row 212: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0fb95df.jpg'
# Processed: Item_ID: B015Q33BVU | Image_ID: 51f4CGncgaL
# Q: Is the phone case included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B015RIGXBY | Image_ID: 91VrzTNaiSL
# Q: Are these curtains machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B016APKQ16 | Image_ID: 61ivj4AeVyL
# Q: Is this bow tie made of 100% silk?
# A: Yes
# --------------------------------------------------
# Error processing row 216: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f67b85c5.jpg'
# Processed: Item_ID: B016RNUF9Y | Image_ID: 71DXlIUBs9L
# Q: Is the pendant letter a "B"?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B016RNUIWS | Image_ID: 61UfjtTCv7L
# Q: Is this necklace made in the USA?
# A: Yes
# --------------------------------------------------
# Error processing row 219: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f41b0a5a.jpg'
# Processed: Item_ID: B0179OIOIO | Image_ID: 71EZyTSd3ZL
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Error processing row 221: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f5bd825c.jpg'
# Processed 200/1000 products
# Processed: Item_ID: B017XDD21U | Image_ID: 71YqjiqFDlL
# Q: Are these earrings lab-created?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B0182R3G58 | Image_ID: A1NB8KPDpUL
# Q: Is this sheet set machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B018FCZBMG | Image_ID: 71Hkt93p6mL
# Q: Is this music stand foldable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B019NTE5YU | Image_ID: 81B4e0EI1FL
# Q: Is a storage bag included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B019OK5VHS | Image_ID: 41T6YINftVL
# Q: Is the case included Apple-certified?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01ABXUNKW | Image_ID: 81aoOQVCIBL
# Q: Is this cookware set induction compatible?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01ASW4122 | Image_ID: 71DjznAa-aL
# Q: Is this cover water-resistant?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01BDA170M | Image_ID: 61UrxEtAyaL
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01CFZI0GI | Image_ID: 71Bz+4y4LRL
# Q: Is this ring size 6?
# A: Yes
# --------------------------------------------------
# Error processing row 231: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/eea6cb50.jpg'
# Processed: Item_ID: B01CXY3UBQ | Image_ID: 51l4fVepltL
# Q: Are these earrings IGI certified?
# A: Yes
# --------------------------------------------------
# Error processing row 233: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/ee71b5e8.jpg'
# Error processing row 234: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fbf6e369.jpg'
# Processed 210/1000 products
# Processed: Item_ID: B01DFDQ764 | Image_ID: 91C8D7aB-aL
# Q: Is this a pair of curtains?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01DG9REQE | Image_ID: 71ceNP5PhXL
# Q: Does this kit include screen protectors?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01DK906WE | Image_ID: 71MFp50eLDL
# Q: Is this bag made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01DK90A3O | Image_ID: 81o43R-pbAL
# Q: Is this backpack made of genuine leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01DN8TG46 | Image_ID: 71WCn9phT5L
# Q: Does it stay securely in place on carpet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01DN8TN8K | Image_ID: 819VBOJB4mL
# Q: Are these markers waterproof?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01DOOEODC | Image_ID: 71tWHdpM+EL
# Q: Is this tie made of 100% silk?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01DTRW24M | Image_ID: 71gF0TvV8nL
# Q: Is the necklace 18 inches long?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01E5FI7L4 | Image_ID: 71RdW24BH9L
# Q: Is this casserole set BPA-free?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01EFMIL4U | Image_ID: 817u5zE7I+L
# Q: Is this laptop sleeve suitable for a 15.6-inch laptop?
# A: Yes
# --------------------------------------------------
# Processed 220/1000 products
# Processed: Item_ID: B01EK87A82 | Image_ID: 71AB2RWLveL
# Q: Is this a 3-foot cable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01F1QEXYQ | Image_ID: 61+BqAX0NXL
# Q: Are these earrings made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01F9RGWF0 | Image_ID: 71uMsNcCVuL
# Q: Is this cable MFi certified?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01FJACNHI | Image_ID: 81qYukVW9hL
# Q: Are the batteries pre-charged?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01FJC6692 | Image_ID: 81hkyX03LiL
# Q: Are the batteries pre-charged?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01GCRZ9LO | Image_ID: 611AH1RdrLL
# Q: Is this patio heater propane powered?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01GPY6NO6 | Image_ID: 71iey+Q0DrL
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01GPY6T7M | Image_ID: 61SJcRkDd+L
# Q: Are these earrings leverback?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01GPY6TFO | Image_ID: 61SJcRkDd+L
# Q: Are these earrings leverback style?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01GPY70Q6 | Image_ID: 81qLpTE-PKL
# Q: Are these earrings made of 10k gold?
# A: Yes
# --------------------------------------------------
# Processed 230/1000 products
# Processed: Item_ID: B01H2AYSHQ | Image_ID: 819XWZQQ8WL
# Q: Is this cayenne pepper organic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01HEQRIZ2 | Image_ID: 81x3YFwpDRL
# Q: Is this shoe cabinet assembled?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01HIF04LY | Image_ID: A1Y+q6kUVwL
# Q: Is this a full/queen size duvet cover set?
# A: Yes
# --------------------------------------------------
# Error processing row 258: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f4/f4796caa.jpg'
# Processed: Item_ID: B01ICR8H66 | Image_ID: 4125MOPM9uL
# Q: Are these AAA batteries?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01IPA4QDI | Image_ID: 61Qj2VDR5PL
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01JFV8BI2 | Image_ID: 713am4HyVLL
# Q: Is this ring size 6?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01JG8EIY0 | Image_ID: 51kui+JX-fL
# Q: Does this airbed include a built-in pump?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01JIRZAS2 | Image_ID: 717ArNddOLL
# Q: Is this ring size 8?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01JIWRSIC | Image_ID: 719ECIvE4iL
# Q: Is this ring size 6?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01JY95Y7G | Image_ID: 81OjF4+RiiL
# Q: Is this conditioner grapefruit-scented?
# A: Yes
# --------------------------------------------------
# Processed 240/1000 products
# Processed: Item_ID: B01KBEP4N2 | Image_ID: 81KQhp7HEXL
# Q: Are these boxes made from recycled material?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01L081OFK | Image_ID: 51SWJgOt-OL
# Q: Is this product vegan?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01L75PDG2 | Image_ID: 91G+N4mSBFL
# Q: Is this ring size 6?
# A: Yes
# --------------------------------------------------
# Error processing row 269: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f6a1052e.jpg'
# Processed: Item_ID: B01LR5RK0Y | Image_ID: 810L1CHPgQL
# Q: Are these dumbbells 4 lbs each?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LW47OW5 | Image_ID: 61JaVBjoLCL
# Q: Is this ring size 8?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LWTVFAW | Image_ID: 71rYreRgKmL
# Q: Is this bracelet made of 14k rose gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LWTWGEK | Image_ID: 81bCNwaS5oL
# Q: Are these earrings made of white gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LWXF89K | Image_ID: 61Xu4plaLUL
# Q: Is this a set of two bottles?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LX3MKKX | Image_ID: 51hLqa5+ROL
# Q: Are these storage boxes transparent?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LXGGR5L | Image_ID: 71Iwr0kxRFL
# Q: Is this laminator A3 sized?
# A: Yes
# --------------------------------------------------
# Processed 250/1000 products
# Processed: Item_ID: B01LXITX4Q | Image_ID: 61bz3XJdhaL
# Q: Is a warranty included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LXO2VN1 | Image_ID: 6183yz91COL
# Q: Are these earrings AGS certified?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LXUCQLB | Image_ID: 61BRQo8IFGL
# Q: Are these earrings made of K10 yellow gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LYHWMS4 | Image_ID: 61SUK6DZPuL
# Q: Is a warranty included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LYTKVEO | Image_ID: 51pi4SlVI-L
# Q: Are these earrings real pearls?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LZGUMWP | Image_ID: 616rDNldmCL
# Q: Is this ring size 6.5?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01LZJ699J | Image_ID: 41tWoY+74JL
# Q: Does this charger include batteries?
# A: Yes
# --------------------------------------------------
# Error processing row 284: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ee/eea9e772.jpg'
# Processed: Item_ID: B01M0G7U0A | Image_ID: 61t7kutdWIL
# Q: Is this bracelet made of 10K yellow gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01M3RWTY6 | Image_ID: 718Ua5XovyL
# Q: Is this ring hypoallergenic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01M4HLPU3 | Image_ID: 41gocDHJ4uL
# Q: Does this shredder include oil?
# A: Yes
# --------------------------------------------------
# Processed 260/1000 products
# Processed: Item_ID: B01M4J1DDP | Image_ID: 51ajqjMk6hL
# Q: Does this hub require additional power adapters?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01M642Q91 | Image_ID: 51E05X8GheL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01M72FSYH | Image_ID: 91FTZcQzdaL
# Q: Is this a set of seven burp cloths?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01M8I8KMH | Image_ID: 41G53jD0T-L
# Q: Is this hub compatible with USB 2.0?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MFAAAD3 | Image_ID: 71oZtHrq2TL
# Q: Is this necklace made of 10k yellow gold?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MFXI57Z | Image_ID: 61Q37Vx4jQL
# Q: Are these earrings sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MG98JTS | Image_ID: 51mpkeNoVLL
# Q: Is this patio heater made of stainless steel?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MR892ED | Image_ID: 61xR2xnMWvL
# Q: Is this a single cabinet handle?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B01MR893N0 | Image_ID: 51QsQpAweTL
# Q: Are mounting screws included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MR8942L | Image_ID: 61g8I-enfiL
# Q: Are screws included?
# A: Yes
# --------------------------------------------------
# Processed 270/1000 products
# Processed: Item_ID: B01MR894HU | Image_ID: 61gny+pXpoL
# Q: Is this a pack of 10 handles?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MRBTBXD | Image_ID: 81vuHQFu5yL
# Q: Is this sandal a platform sandal?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MRCS7U2 | Image_ID: 61BMn9WOzqL
# Q: Is this shoe made of suede?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MS6Y2FM | Image_ID: 716iphiFi3L
# Q: Is this necklace made of sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MS9NSET | Image_ID: 617TZAH0ozL
# Q: Does this include mounting screws?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MSZ5KII | Image_ID: 414fCvyK7qL
# Q: Does this shredder include lubricant sheets?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MT9QLNS | Image_ID: 81iVYYiY1dL
# Q: Are these sandals made of leather?
# A: Yes
# --------------------------------------------------
# Error processing row 305: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f3/f388847a.jpg'
# Processed: Item_ID: B01MTEIAQZ | Image_ID: 81-5Ka9a5fL
# Q: Are these sandals made of leather?
# A: Yes
# --------------------------------------------------
# Error processing row 307: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f5e2912d.jpg'
# Processed: Item_ID: B01MUEQ77K | Image_ID: 61DkAuiVY9L
# Q: Is this ring size 6?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MUHEJ6H | Image_ID: 61ax5CulfOL
# Q: Are these ballet flats made of suede?
# A: Yes
# --------------------------------------------------
# Error processing row 310: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f9/f9b0addb.jpg'
# Processed 280/1000 products
# Processed: Item_ID: B01MYEYBHI | Image_ID: 61ax5CulfOL
# Q: Are these flats made of suede?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MZ8FGLX | Image_ID: 71ixSV58FlL
# Q: Are these boat shoes made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01MZF9541 | Image_ID: 71-eMu0gN+L
# Q: Is this sandal made of suede?
# A: Yes
# --------------------------------------------------
# Error processing row 314: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f5/f5b869eb.jpg'
# Processed: Item_ID: B01N232Q8B | Image_ID: 81-vrE2ChTL
# Q: Are these shoes velcro closure?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01N27SNPO | Image_ID: 81wD7336REL
# Q: Is this sandal made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01N365R6A | Image_ID: 61Lcg5ssr4L
# Q: Are mounting screws included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01N3APCPF | Image_ID: 71vyjhYIo+L
# Q: Is this necklace sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01N3CKBKD | Image_ID: 61ofaJQbCGL
# Q: Are these flip-flops made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B01N3QGK1U | Image_ID: 71kYcOL6WfL
# ...
# Q: Are these shoes lace-up?
# A: Yes
# --------------------------------------------------
# Error processing row 894: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/ebb3ce4e.jpg'
# Processed 820/1000 products
# Processed: Item_ID: B079WWYFM3 | Image_ID: 810RuHJF8TL
# Q: Is this broth certified organic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B079XGGD2P | Image_ID: 613bJAY-vPL
# Q: Are these sticky notes designed for use in dispensers?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B079XHCTG5 | Image_ID: 71cTlBPfEGL
# Q: Is this a dimmable bulb?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B1LZQBQ | Image_ID: 41s3xoFwNvL
# Q: Is this a refrigerated item?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B1NTH99 | Image_ID: 71+MTCj4QxL
# Q: Is this a refrigerated item?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B1P28GK | Image_ID: 71+Z5-oyTOL
# Q: Is this a ready-to-eat meal?
# A: Yes
# --------------------------------------------------
# Error processing row 901: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f6e7dec7.jpg'
# Processed: Item_ID: B07B44G6PS | Image_ID: 51FE6dEnstL
# Q: Is this a single bungee cord?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B4FZG8Y | Image_ID: 91kjptnlhUL
# Q: Is the ottoman cover removable?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B4G5SY7 | Image_ID: A1US2nV79mL
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B4GXNJY | Image_ID: 918Y9BFEbDL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed 830/1000 products
# Processed: Item_ID: B07B4GXWZZ | Image_ID: B1W-Q+qXK3S
# Q: Does this recliner have a pop-up footrest?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4M35MF | Image_ID: 91-MGRymDwL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4MSP8F | Image_ID: 91dadCFbV3L
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B4MT2HV | Image_ID: A1k4Lajqm3L
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4SMR2G | Image_ID: A1DyjPnZrwL
# Q: Is this rug hand-woven?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4SMRBS | Image_ID: 81Fz3x+lNlL
# Q: Is this rug machine washable?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B4VSTF6 | Image_ID: 81HpMQ+l41L
# Q: Are bulbs included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4YS1QP | Image_ID: 71nvY8m-0xL
# Q: Is a lightbulb included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4YXWMS | Image_ID: 71sYkNr-AqL
# Q: Is this casserole dish non-stick?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B4Z2WDQ | Image_ID: 91L64ZBpL8L
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed 840/1000 products
# Processed: Item_ID: B07B4Z2YTC | Image_ID: 71iPB5af-sL
# Q: Is a bulb included?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B4Z32WP | Image_ID: 813LhZGBU2L
# Q: Is this headboard fully upholstered?
# A: Yes
# --------------------------------------------------
# Error processing row 918: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f1/f1ad733f.jpg'
# Processed: Item_ID: B07B51QMFH | Image_ID: 81RSpbBXDML
# Q: Is this rug a low pile?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B69QPD7 | Image_ID: 71uOZHJHz1L
# Q: Is this a T8 tube?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B6JVTMF | Image_ID: 71mxjcjxqoL
# Q: Are these sandals slip-on?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B6L9X61 | Image_ID: 71WMUxdAWrL
# Q: Are these sandals slip-on?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B6LJLQW | Image_ID: 81Op4BjWC4L
# Q: Is this keyboard and mouse set wireless?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B78RCTR | Image_ID: 81sc-1cmgxL
# Q: Does this kitchen island require assembly?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B7B5NZH | Image_ID: A1x5cY9DhWL
# Q: Does this bar stool require assembly?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B7B6W64 | Image_ID: 615BC2KRm4L
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed 850/1000 products
# Processed: Item_ID: B07B7B8KNR | Image_ID: 81fQ+TfKRKL
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07B7DMNZC | Image_ID: A1q591o1uCL
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Error processing row 929: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f0/f0478f7a.jpg'
# Error processing row 930: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/ebec60cd.jpg'
# Processed: Item_ID: B07B89FSPZ | Image_ID: 81CE9nuJmIL
# Q: Is this a baby hat and mitten set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07B8MWDC7 | Image_ID: 81GMI5pqSeL
# Q: Is this a fleece-lined hat and mitten set?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BDXC1B2 | Image_ID: 81e-Ize5g1L
# Q: Does this luggage rack fold down for storage?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BDY85D2 | Image_ID: 611dGQ309XL
# Q: Are these sneakers canvas?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BDYD4QL | Image_ID: 81R8nxOD7LL
# Q: Are these slip-on shoes?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BDZ3418 | Image_ID: 71U3Ih0K5vL
# Q: Are these sneakers lace-up?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BDZBMHX | Image_ID: 81mtye2K80L
# Q: Are these sneakers lace-up?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BDZLHD8 | Image_ID: 91Lnf1ZeWgL
# Q: Are these sneakers lace-up?
# A: Yes
# --------------------------------------------------
# Processed 860/1000 products
# Processed: Item_ID: B07BFR3XTR | Image_ID: 71i5Jf6XAaL
# Q: Is this product vegan?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BG59N25 | Image_ID: 81qkXp-KmlL
# Q: Is this backpack waterproof?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BG76NV2 | Image_ID: 91xRt-lhPbL
# Q: Is this meal kit ready in under 30 minutes?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHH1G7Z | Image_ID: 91OSggzZTtL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHH2ZVY | Image_ID: 91OSggzZTtL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHH92LH | Image_ID: 91OSggzZTtL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHR9TM9 | Image_ID: 71VklQPmi1L
# Q: Is this grilling tool set made of stainless steel?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHXL5PB | Image_ID: 711AKrHwnyL
# Q: Are these curtains machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHXM5V7 | Image_ID: 91322ZcP3oL
# Q: Are these curtains machine washable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BHXNQZX | Image_ID: 91aG5pPUqzL
# Q: Are these curtains machine washable?
# A: Yes
# --------------------------------------------------
# Processed 870/1000 products
# Processed: Item_ID: B07BK5NVPX | Image_ID: 71ewwrgzGxL
# Q: Is the bag blue?
# A: Yes
# --------------------------------------------------
# Error processing row 950: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ff/ff943107.jpg'
# Processed: Item_ID: B07BL5QBY6 | Image_ID: 81hmpCD9wiL
# Q: Does this vanity set require assembly?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BL69KQ3 | Image_ID: 81qqXrBkAhL
# Q: Is this suitcase red?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BL6CX6Y | Image_ID: 91vU8v5p0bL
# Q: Does this suitcase have a TSA-approved lock?
# A: Yes
# --------------------------------------------------
# Error processing row 954: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f8/f8b6aef7.jpg'
# Processed: Item_ID: B07BLC96G2 | Image_ID: 71dLSfNxstL
# Q: Is this saucepan dishwasher safe?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BLDWLS2 | Image_ID: 81YslYQfgHL
# Q: Is this speaker refurbished?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BLFLFSV | Image_ID: 71IGlLDcBRL
# Q: Does this case hold 24 Nintendo 3DS game cartridges?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BLFSL3B | Image_ID: 91-+7r6P6oL
# Q: Are these grips for dumbbells and barbells?
# A: Yes
# --------------------------------------------------
# Error processing row 959: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb076ee8.jpg'
# Error processing row 960: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/ebebc88c.jpg'
# Processed: Item_ID: B07BQ24ZYH | Image_ID: 81b-zP6y6uL
# Q: Is this laundry detergent non-biodegradable?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07BW8P2F7 | Image_ID: 81muzpodbiL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Error processing row 963: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/f6/f6b20712.jpg'
# Processed 880/1000 products
# Processed: Item_ID: B07BWJCBY2 | Image_ID: 817AhxzIWeL
# Q: Is this sofa made of 100% leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BWK7JV5 | Image_ID: 71ueNstGvVL
# Q: Is this sectional sofa made to order?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BWL4C2F | Image_ID: 71kzHlG5PVL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07BWMSQC3 | Image_ID: 81FoTwXu9KL
# Q: Is assembly required?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07BYBKK6S | Image_ID: 81Y0bXPQCrL
# Q: Is the leash reflective?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07C41SPN6 | Image_ID: 81izU8sWudL
# Q: Is this dressing certified organic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07C517XDC | Image_ID: 81QGQvHZNJL
# Q: Are these photo frames wall-mountable?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07C5F98NT | Image_ID: 810ywUcno-L
# Q: Is this conventional motor oil?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07C5PWFN1 | Image_ID: 71fOKSGfHzL
# Q: Is this a 6-pack of oil?
# A: Yes
# --------------------------------------------------
# Error processing row 973: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/fb/fb009f47.jpg'
# Processed: Item_ID: B07C7TPRB7 | Image_ID: 61QnXpi+8PL
# Q: Is this water bottle BPA-free?
# A: Yes
# --------------------------------------------------
# Processed 890/1000 products
# Processed: Item_ID: B07C81N8CH | Image_ID: 81KECA66++L
# Q: Is this water bottle BPA-free?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07C81V4QC | Image_ID: 611Z3SWX3nL
# Q: Is it BPA-free?
# A: Yes
# --------------------------------------------------
# Error processing row 977: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/ef/ef34d695.jpg'
# Processed: Item_ID: B07CBP6GYJ | Image_ID: 81BS-RG2wpL
# Q: Does this planter have drainage holes?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07CCW6VTN | Image_ID: 81ztOYcmnOL
# Q: Is this laundry detergent suitable for wool?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07CDRN3QJ | Image_ID: 81HQfBrfzKL
# Q: Is assembly required?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CDXJVFV | Image_ID: 716LQdaEp3L
# Q: Is this ankle brace made of neoprene?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CF8Q3BQ | Image_ID: 81B9X30SYcL
# Q: Is this coffee organic?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CGLGB1K | Image_ID: 512S7391MuL
# Q: Is this necklace sterling silver?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CJJQYZM | Image_ID: 91RNKg0Sl7L
# Q: Are these towels 100% cotton?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CJQQHZJ | Image_ID: 91+KIzLjUBL
# Q: Does this heating pad have multiple heat settings?
# A: Yes
# --------------------------------------------------
# Processed 900/1000 products
# Processed: Item_ID: B07CJW5G9S | Image_ID: 51hY+OIBWLL
# Q: Is it gluten-free?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CL2RV1H | Image_ID: 91ey2aSsb7L
# Q: Are these boots made of leather?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07CM5NZRC | Image_ID: 81vFhqlqGsL
# Q: Is this keyboard backlit?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07CMD9X29 | Image_ID: 81F7bCfMDOL
# Q: Are these shoes machine washable?
# A: No
# --------------------------------------------------
# Processed: Item_ID: B07CMHRZS2 | Image_ID: 71eCsEVpA7L
# Q: Are the bristles soft?
# A: Yes
# --------------------------------------------------
# Error processing row 991: [Errno 2] No such file or directory: '/home/saishruti/Research1/VR_Project/Datasets/small/eb/eb66697c.jpg'
# Processed: Item_ID: B07CNV92Q8 | Image_ID: 71hcAczTTzL
# Q: Are these toothbrushes soft-bristled?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CSCXJ3T | Image_ID: 816VP-arPsL
# Q: Is this sofa made of velvet?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CSCZKVQ | Image_ID: 91+rDNDy7WL
# Q: Is this recliner made of leather?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CSTTPTC | Image_ID: 612GeyyKS7L
# Q: Is this a fabric swatch?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CSX7HVY | Image_ID: 61gzwWjM4pL
# Q: Is this a hooded chair?
# A: Yes
# --------------------------------------------------
# Processed 910/1000 products
# Processed: Item_ID: B07CSY4LK8 | Image_ID: 61CVyYdpOvL
# Q: Is this a fabric swatch?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CSY4N1K | Image_ID: 61YggjZPO7L
# Q: Is this a fabric swatch?
# A: Yes
# --------------------------------------------------
# Processed: Item_ID: B07CSY4P16 | Image_ID: 61-WsUsvJLL
# Q: Is this a fabric swatch?
# A: Yes
# --------------------------------------------------
#
# Reached limit of 1000 API calls.
# Stopped at index 1000, Item_ID: B07CSY4P36
# To continue processing, set start_index = 1000
#
# Processing complete!
# Total products processed: 912
# Errors: 88
# Results saved to qna4.csv
# Next start_index to continue: 1000

# %%
""" API Keys """
key_1 = "AIzaSyDRYg1bgxG-Yv77yqV5RmJuRFAsplOyLg0"
key_2 = "AIzaSyCk-3tjAx3U33d0hdXiYmKP-7m0_kHOFqk"
key_3 = "AIzaSyC8YBijcN_xFfST2Y4KB3YVR7DNnI-FFz8"

# %%
""" Getting the final csv file """
""" Merging """
import pandas as pd

# List of input CSV files
csv_files = ["qna.csv", "qna2.csv", "qna3.csv", "qna4.csv"]

# Merge the CSV files
merged_df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# Remove duplicate questions within each Item_ID
merged_df = merged_df.drop_duplicates(subset=["Item_ID", "Question"])

# Save the merged DataFrame to qna_main.csv
merged_file_path = "qna_main.csv"
merged_df.to_csv(merged_file_path, index=False)
print(f"Merged file saved as {merged_file_path}")

# Count the number of "Yes" and "No" answers
yes_count = (merged_df["Answer"].str.strip().str.lower() == "yes").sum()
no_count = (merged_df["Answer"].str.strip().str.lower() == "no").sum()

# Print the results
print(f"Number of questions with 'Yes' as the answer: {yes_count}")
print(f"Number of questions with 'No' as the answer: {no_count}")
# Out:
# Merged file saved as qna_main.csv
# Number of questions with 'Yes' as the answer: 3186
# Number of questions with 'No' as the answer: 498

# %%
""" Removing additional yes/no's """

# %%
""" Adding the image paths and duplicating """
""" Only if its valid """
import pandas as pd
import os

# File paths
qna_main_path = "qna_main.csv"  # Input file
filtered_merged_path = "Datasets/filtered_merged_output.csv"  # File with image paths
qna_final_path = "qna_final.csv"  # Output file
small_directory = "Datasets/small"  # Directory where images are stored

# Load DataFrames
qna_main_df = pd.read_csv(qna_main_path)
filtered_merged_df = pd.read_csv(filtered_merged_path)

# Add a new column for the image path
qna_main_df["Image_Path"] = None

# Prepend the "small" directory path to each image path
filtered_merged_df["full_path"] = filtered_merged_df["path"].str.strip().apply(lambda p: os.path.join(small_directory, p))

# Create a dictionary of valid image paths for each Item_ID
valid_paths = filtered_merged_df[filtered_merged_df["full_path"].apply(os.path.isfile)]  # Check for valid paths
item_id_to_paths = valid_paths.groupby("item_id")["full_path"].apply(list).to_dict()

# Create a new DataFrame for the final output
final_rows = []

for _, row in qna_main_df.iterrows():
    item_id = row["Item_ID"]
    question = row["Question"]
    answer = row["Answer"]
    
    # Get all valid paths for this Item_ID
    image_paths = item_id_to_paths.get(item_id, [])
    
    # Add a row for each valid image path
    for image_path in image_paths:
        new_row = row.copy()
        new_row["Image_Path"] = image_path
        final_rows.append(new_row)

# Create the final DataFrame
qna_final_df = pd.DataFrame(final_rows)

# Save the final DataFrame to qna_final.csv
qna_final_df.to_csv(qna_final_path, index=False)
print(f"Final file saved as {qna_final_path}")
# Out:
# Final file saved as qna_final.csv

# %%
import pandas as pd

# Load the CSV file
qna_final_path = "qna_final.csv"
qna_final_df = pd.read_csv(qna_final_path)

# Print the column names
print("Column names in qna_final.csv:")
print(qna_final_df.columns.tolist())
# Out:
# Column names in qna_final.csv:
# ['Image_ID', 'Item_ID', 'Question', 'Answer', '61-HYrslQUL', 'B07CSY4P36', 'What color is the chair?', 'Brown', 'Image_Path']
